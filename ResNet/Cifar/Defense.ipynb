# %%
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader, Subset
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.amp import GradScaler, autocast
import os
import random
import pandas as pd
from scipy.special import comb

# %%
import random
from torch.utils.data import Subset, DataLoader
from torchvision import datasets, transforms

transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.ToTensor()
])

train_dataset = datasets.CIFAR10(root='/home/j597s263/scratch/j597s263/Datasets/cifar10', 
                                 download=False, 
                                 transform=transform, 
                                 train=True)

test_dataset = datasets.CIFAR10(root='/home/j597s263/scratch/j597s263/Datasets/cifar10', 
                                download=False, 
                                transform=transform, 
                                train=False)

random.seed(42)  
train_indices = list(range(len(train_dataset)))
random.shuffle(train_indices)

split_idx = int(0.9 * len(train_indices))  
train_indices, attack_indices = train_indices[:split_idx], train_indices[split_idx:]

train_data = Subset(train_dataset, train_indices)
attack_data = Subset(train_dataset, attack_indices)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)  # Shuffle within batches
attack_loader = DataLoader(attack_data, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(f"Original training samples: {len(train_dataset)}")
print(f"Training samples after split: {len(train_data)}")
print(f"Attack samples: {len(attack_data)}")
print(f"Testing samples: {len(test_dataset)}")
# Out:
# Original training samples: 50000
# Training samples after split: 45000
# Attack samples: 5000
# Testing samples: 10000

# %%
def get_pixel_coords(flat_indices, width):
    return [divmod(idx, width) for idx in flat_indices]

# %%
def calculate_pixel_frequencies_from_loader(data_loader, pixel_coords):
    """
    Calculate the frequency of pixel values at specific coordinates from a DataLoader.

    Args:
        data_loader (DataLoader): A DataLoader containing the image dataset.
        pixel_coords (list of tuples): A list of (x, y) pixel coordinates to evaluate.

    Returns:
        dict: A dictionary where keys are pixel coordinates, and values are dictionaries of RGB frequencies.
    """
    pixel_freq = {coord: {} for coord in pixel_coords}

    for batch_idx, (images, _) in enumerate(data_loader):
        # Move batch to CPU for processing if it's on GPU
        images = images.cpu()

        # Iterate through the batch of images
        for img_idx, img_tensor in enumerate(images):
            # Convert to numpy array for easy access
            img_array = img_tensor.permute(1, 2, 0).numpy()  # (height, width, 3)

            # Check and count each specified pixel coordinate
            for (i, j) in pixel_coords:
                if i < img_array.shape[0] and j < img_array.shape[1]:
                    pixel = tuple(img_array[i, j])  # Extract RGB tuple
                    if pixel not in pixel_freq[(i, j)]:
                        pixel_freq[(i, j)][pixel] = []
                    pixel_freq[(i, j)][pixel].append((batch_idx * len(images) + img_idx, pixel))

        print(f"Processed batch {batch_idx + 1}/{len(data_loader)}")

    return pixel_freq

# %%
top_22_coords = [
    (145, 87), (144, 87), (143, 87), (73, 131), (63, 105),
    (123, 81), (61, 107), (124, 81), (64, 105), (73, 132),
    (147, 87), (144, 89), (60, 111), (73, 133), (113, 103),
    (115, 101), (63, 107), (61, 111), (115, 143), (145, 89),
    (124, 83), (145, 67)
]

pixel_freq = calculate_pixel_frequencies_from_loader(train_loader, top_22_coords)
# Out:
# Processed batch 1/1407
# Processed batch 2/1407
# Processed batch 3/1407
# Processed batch 4/1407
# Processed batch 5/1407
# Processed batch 6/1407
# Processed batch 7/1407
# Processed batch 8/1407
# Processed batch 9/1407
# Processed batch 10/1407
# Processed batch 11/1407
# Processed batch 12/1407
# Processed batch 13/1407
# Processed batch 14/1407
# Processed batch 15/1407
# Processed batch 16/1407
# Processed batch 17/1407
# Processed batch 18/1407
# Processed batch 19/1407
# Processed batch 20/1407
# Processed batch 21/1407
# Processed batch 22/1407
# Processed batch 23/1407
# Processed batch 24/1407
# Processed batch 25/1407
# Processed batch 26/1407
# Processed batch 27/1407
# Processed batch 28/1407
# Processed batch 29/1407
# Processed batch 30/1407
# Processed batch 31/1407
# Processed batch 32/1407
# Processed batch 33/1407
# Processed batch 34/1407
# Processed batch 35/1407
# Processed batch 36/1407
# Processed batch 37/1407
# Processed batch 38/1407
# Processed batch 39/1407
# Processed batch 40/1407
# Processed batch 41/1407
# Processed batch 42/1407
# Processed batch 43/1407
# Processed batch 44/1407
# Processed batch 45/1407
# Processed batch 46/1407
# Processed batch 47/1407
# Processed batch 48/1407
# Processed batch 49/1407
# Processed batch 50/1407
# Processed batch 51/1407
# Processed batch 52/1407
# Processed batch 53/1407
# Processed batch 54/1407
# Processed batch 55/1407
# Processed batch 56/1407
# Processed batch 57/1407
# Processed batch 58/1407
# Processed batch 59/1407
# Processed batch 60/1407
# Processed batch 61/1407
# Processed batch 62/1407
# Processed batch 63/1407
# Processed batch 64/1407
# Processed batch 65/1407
# Processed batch 66/1407
# Processed batch 67/1407
# Processed batch 68/1407
# Processed batch 69/1407
# Processed batch 70/1407
# Processed batch 71/1407
# Processed batch 72/1407
# Processed batch 73/1407
# Processed batch 74/1407
# Processed batch 75/1407
# Processed batch 76/1407
# Processed batch 77/1407
# Processed batch 78/1407
# Processed batch 79/1407
# Processed batch 80/1407
# Processed batch 81/1407
# Processed batch 82/1407
# Processed batch 83/1407
# Processed batch 84/1407
# Processed batch 85/1407
# Processed batch 86/1407
# Processed batch 87/1407
# Processed batch 88/1407
# Processed batch 89/1407
# Processed batch 90/1407
# Processed batch 91/1407
# Processed batch 92/1407
# Processed batch 93/1407
# Processed batch 94/1407
# Processed batch 95/1407
# Processed batch 96/1407
# Processed batch 97/1407
# Processed batch 98/1407
# Processed batch 99/1407
# Processed batch 100/1407
# Processed batch 101/1407
# Processed batch 102/1407
# Processed batch 103/1407
# Processed batch 104/1407
# Processed batch 105/1407
# Processed batch 106/1407
# Processed batch 107/1407
# Processed batch 108/1407
# Processed batch 109/1407
# Processed batch 110/1407
# Processed batch 111/1407
# Processed batch 112/1407
# Processed batch 113/1407
# Processed batch 114/1407
# Processed batch 115/1407
# Processed batch 116/1407
# Processed batch 117/1407
# Processed batch 118/1407
# Processed batch 119/1407
# Processed batch 120/1407
# Processed batch 121/1407
# Processed batch 122/1407
# Processed batch 123/1407
# Processed batch 124/1407
# Processed batch 125/1407
# Processed batch 126/1407
# Processed batch 127/1407
# Processed batch 128/1407
# Processed batch 129/1407
# Processed batch 130/1407
# Processed batch 131/1407
# Processed batch 132/1407
# Processed batch 133/1407
# Processed batch 134/1407
# Processed batch 135/1407
# Processed batch 136/1407
# Processed batch 137/1407
# Processed batch 138/1407
# Processed batch 139/1407
# Processed batch 140/1407
# Processed batch 141/1407
# Processed batch 142/1407
# Processed batch 143/1407
# Processed batch 144/1407
# Processed batch 145/1407
# Processed batch 146/1407
# Processed batch 147/1407
# Processed batch 148/1407
# Processed batch 149/1407
# Processed batch 150/1407
# Processed batch 151/1407
# Processed batch 152/1407
# Processed batch 153/1407
# Processed batch 154/1407
# Processed batch 155/1407
# Processed batch 156/1407
# Processed batch 157/1407
# Processed batch 158/1407
# Processed batch 159/1407
# Processed batch 160/1407
# Processed batch 161/1407
# Processed batch 162/1407
# Processed batch 163/1407
# Processed batch 164/1407
# Processed batch 165/1407
# Processed batch 166/1407
# Processed batch 167/1407
# Processed batch 168/1407
# Processed batch 169/1407
# Processed batch 170/1407
# Processed batch 171/1407
# Processed batch 172/1407
# Processed batch 173/1407
# Processed batch 174/1407
# Processed batch 175/1407
# Processed batch 176/1407
# Processed batch 177/1407
# Processed batch 178/1407
# Processed batch 179/1407
# Processed batch 180/1407
# Processed batch 181/1407
# Processed batch 182/1407
# Processed batch 183/1407
# Processed batch 184/1407
# Processed batch 185/1407
# Processed batch 186/1407
# Processed batch 187/1407
# Processed batch 188/1407
# Processed batch 189/1407
# Processed batch 190/1407
# Processed batch 191/1407
# Processed batch 192/1407
# Processed batch 193/1407
# Processed batch 194/1407
# Processed batch 195/1407
# Processed batch 196/1407
# Processed batch 197/1407
# Processed batch 198/1407
# Processed batch 199/1407
# Processed batch 200/1407
# Processed batch 201/1407
# Processed batch 202/1407
# Processed batch 203/1407
# Processed batch 204/1407
# Processed batch 205/1407
# Processed batch 206/1407
# Processed batch 207/1407
# Processed batch 208/1407
# Processed batch 209/1407
# Processed batch 210/1407
# Processed batch 211/1407
# Processed batch 212/1407
# Processed batch 213/1407
# Processed batch 214/1407
# Processed batch 215/1407
# Processed batch 216/1407
# Processed batch 217/1407
# Processed batch 218/1407
# Processed batch 219/1407
# Processed batch 220/1407
# Processed batch 221/1407
# Processed batch 222/1407
# Processed batch 223/1407
# Processed batch 224/1407
# Processed batch 225/1407
# Processed batch 226/1407
# Processed batch 227/1407
# Processed batch 228/1407
# Processed batch 229/1407
# Processed batch 230/1407
# Processed batch 231/1407
# Processed batch 232/1407
# Processed batch 233/1407
# Processed batch 234/1407
# Processed batch 235/1407
# Processed batch 236/1407
# Processed batch 237/1407
# Processed batch 238/1407
# Processed batch 239/1407
# Processed batch 240/1407
# Processed batch 241/1407
# Processed batch 242/1407
# Processed batch 243/1407
# Processed batch 244/1407
# Processed batch 245/1407
# Processed batch 246/1407
# Processed batch 247/1407
# Processed batch 248/1407
# Processed batch 249/1407
# Processed batch 250/1407
# Processed batch 251/1407
# Processed batch 252/1407
# Processed batch 253/1407
# Processed batch 254/1407
# Processed batch 255/1407
# Processed batch 256/1407
# Processed batch 257/1407
# Processed batch 258/1407
# Processed batch 259/1407
# Processed batch 260/1407
# Processed batch 261/1407
# Processed batch 262/1407
# Processed batch 263/1407
# Processed batch 264/1407
# Processed batch 265/1407
# Processed batch 266/1407
# Processed batch 267/1407
# Processed batch 268/1407
# Processed batch 269/1407
# Processed batch 270/1407
# Processed batch 271/1407
# Processed batch 272/1407
# Processed batch 273/1407
# Processed batch 274/1407
# Processed batch 275/1407
# Processed batch 276/1407
# Processed batch 277/1407
# Processed batch 278/1407
# Processed batch 279/1407
# Processed batch 280/1407
# Processed batch 281/1407
# Processed batch 282/1407
# Processed batch 283/1407
# Processed batch 284/1407
# Processed batch 285/1407
# Processed batch 286/1407
# Processed batch 287/1407
# Processed batch 288/1407
# Processed batch 289/1407
# Processed batch 290/1407
# Processed batch 291/1407
# Processed batch 292/1407
# Processed batch 293/1407
# Processed batch 294/1407
# Processed batch 295/1407
# Processed batch 296/1407
# Processed batch 297/1407
# Processed batch 298/1407
# Processed batch 299/1407
# Processed batch 300/1407
# Processed batch 301/1407
# Processed batch 302/1407
# Processed batch 303/1407
# Processed batch 304/1407
# Processed batch 305/1407
# Processed batch 306/1407
# Processed batch 307/1407
# Processed batch 308/1407
# Processed batch 309/1407
# Processed batch 310/1407
# Processed batch 311/1407
# Processed batch 312/1407
# Processed batch 313/1407
# Processed batch 314/1407
# Processed batch 315/1407
# Processed batch 316/1407
# Processed batch 317/1407
# Processed batch 318/1407
# Processed batch 319/1407
# Processed batch 320/1407
# Processed batch 321/1407
# Processed batch 322/1407
# Processed batch 323/1407
# Processed batch 324/1407
# Processed batch 325/1407
# Processed batch 326/1407
# Processed batch 327/1407
# Processed batch 328/1407
# Processed batch 329/1407
# Processed batch 330/1407
# Processed batch 331/1407
# Processed batch 332/1407
# Processed batch 333/1407
# Processed batch 334/1407
# Processed batch 335/1407
# Processed batch 336/1407
# Processed batch 337/1407
# Processed batch 338/1407
# Processed batch 339/1407
# Processed batch 340/1407
# Processed batch 341/1407
# Processed batch 342/1407
# Processed batch 343/1407
# Processed batch 344/1407
# Processed batch 345/1407
# Processed batch 346/1407
# Processed batch 347/1407
# Processed batch 348/1407
# Processed batch 349/1407
# Processed batch 350/1407
# Processed batch 351/1407
# Processed batch 352/1407
# Processed batch 353/1407
# Processed batch 354/1407
# Processed batch 355/1407
# Processed batch 356/1407
# Processed batch 357/1407
# Processed batch 358/1407
# Processed batch 359/1407
# Processed batch 360/1407
# Processed batch 361/1407
# Processed batch 362/1407
# Processed batch 363/1407
# Processed batch 364/1407
# Processed batch 365/1407
# Processed batch 366/1407
# Processed batch 367/1407
# Processed batch 368/1407
# Processed batch 369/1407
# Processed batch 370/1407
# Processed batch 371/1407
# Processed batch 372/1407
# Processed batch 373/1407
# Processed batch 374/1407
# Processed batch 375/1407
# Processed batch 376/1407
# Processed batch 377/1407
# Processed batch 378/1407
# Processed batch 379/1407
# Processed batch 380/1407
# Processed batch 381/1407
# Processed batch 382/1407
# Processed batch 383/1407
# Processed batch 384/1407
# Processed batch 385/1407
# Processed batch 386/1407
# Processed batch 387/1407
# Processed batch 388/1407
# Processed batch 389/1407
# Processed batch 390/1407
# Processed batch 391/1407
# Processed batch 392/1407
# Processed batch 393/1407
# Processed batch 394/1407
# Processed batch 395/1407
# Processed batch 396/1407
# Processed batch 397/1407
# Processed batch 398/1407
# Processed batch 399/1407
# Processed batch 400/1407
# Processed batch 401/1407
# Processed batch 402/1407
# Processed batch 403/1407
# Processed batch 404/1407
# Processed batch 405/1407
# Processed batch 406/1407
# Processed batch 407/1407
# Processed batch 408/1407
# Processed batch 409/1407
# Processed batch 410/1407
# Processed batch 411/1407
# Processed batch 412/1407
# Processed batch 413/1407
# Processed batch 414/1407
# Processed batch 415/1407
# Processed batch 416/1407
# Processed batch 417/1407
# Processed batch 418/1407
# Processed batch 419/1407
# Processed batch 420/1407
# Processed batch 421/1407
# Processed batch 422/1407
# Processed batch 423/1407
# Processed batch 424/1407
# Processed batch 425/1407
# Processed batch 426/1407
# Processed batch 427/1407
# Processed batch 428/1407
# Processed batch 429/1407
# Processed batch 430/1407
# Processed batch 431/1407
# Processed batch 432/1407
# Processed batch 433/1407
# Processed batch 434/1407
# Processed batch 435/1407
# Processed batch 436/1407
# Processed batch 437/1407
# Processed batch 438/1407
# Processed batch 439/1407
# Processed batch 440/1407
# Processed batch 441/1407
# Processed batch 442/1407
# Processed batch 443/1407
# Processed batch 444/1407
# Processed batch 445/1407
# Processed batch 446/1407
# Processed batch 447/1407
# Processed batch 448/1407
# Processed batch 449/1407
# Processed batch 450/1407
# Processed batch 451/1407
# Processed batch 452/1407
# Processed batch 453/1407
# Processed batch 454/1407
# Processed batch 455/1407
# Processed batch 456/1407
# Processed batch 457/1407
# Processed batch 458/1407
# Processed batch 459/1407
# Processed batch 460/1407
# Processed batch 461/1407
# Processed batch 462/1407
# Processed batch 463/1407
# Processed batch 464/1407
# Processed batch 465/1407
# Processed batch 466/1407
# Processed batch 467/1407
# Processed batch 468/1407
# Processed batch 469/1407
# Processed batch 470/1407
# Processed batch 471/1407
# Processed batch 472/1407
# Processed batch 473/1407
# Processed batch 474/1407
# Processed batch 475/1407
# Processed batch 476/1407
# Processed batch 477/1407
# Processed batch 478/1407
# Processed batch 479/1407
# Processed batch 480/1407
# Processed batch 481/1407
# Processed batch 482/1407
# Processed batch 483/1407
# Processed batch 484/1407
# Processed batch 485/1407
# Processed batch 486/1407
# Processed batch 487/1407
# Processed batch 488/1407
# Processed batch 489/1407
# Processed batch 490/1407
# Processed batch 491/1407
# Processed batch 492/1407
# Processed batch 493/1407
# Processed batch 494/1407
# Processed batch 495/1407
# Processed batch 496/1407
# Processed batch 497/1407
# Processed batch 498/1407
# Processed batch 499/1407
# Processed batch 500/1407
# Processed batch 501/1407
# Processed batch 502/1407
# Processed batch 503/1407
# Processed batch 504/1407
# Processed batch 505/1407
# Processed batch 506/1407
# Processed batch 507/1407
# Processed batch 508/1407
# Processed batch 509/1407
# Processed batch 510/1407
# Processed batch 511/1407
# Processed batch 512/1407
# Processed batch 513/1407
# Processed batch 514/1407
# Processed batch 515/1407
# Processed batch 516/1407
# Processed batch 517/1407
# Processed batch 518/1407
# Processed batch 519/1407
# Processed batch 520/1407
# Processed batch 521/1407
# Processed batch 522/1407
# Processed batch 523/1407
# Processed batch 524/1407
# Processed batch 525/1407
# Processed batch 526/1407
# Processed batch 527/1407
# Processed batch 528/1407
# Processed batch 529/1407
# Processed batch 530/1407
# Processed batch 531/1407
# Processed batch 532/1407
# Processed batch 533/1407
# Processed batch 534/1407
# Processed batch 535/1407
# Processed batch 536/1407
# Processed batch 537/1407
# Processed batch 538/1407
# Processed batch 539/1407
# Processed batch 540/1407
# Processed batch 541/1407
# Processed batch 542/1407
# Processed batch 543/1407
# Processed batch 544/1407
# Processed batch 545/1407
# Processed batch 546/1407
# Processed batch 547/1407
# Processed batch 548/1407
# Processed batch 549/1407
# Processed batch 550/1407
# Processed batch 551/1407
# Processed batch 552/1407
# Processed batch 553/1407
# Processed batch 554/1407
# Processed batch 555/1407
# Processed batch 556/1407
# Processed batch 557/1407
# Processed batch 558/1407
# Processed batch 559/1407
# Processed batch 560/1407
# Processed batch 561/1407
# Processed batch 562/1407
# Processed batch 563/1407
# Processed batch 564/1407
# Processed batch 565/1407
# Processed batch 566/1407
# Processed batch 567/1407
# Processed batch 568/1407
# Processed batch 569/1407
# Processed batch 570/1407
# Processed batch 571/1407
# Processed batch 572/1407
# Processed batch 573/1407
# Processed batch 574/1407
# Processed batch 575/1407
# Processed batch 576/1407
# Processed batch 577/1407
# Processed batch 578/1407
# Processed batch 579/1407
# Processed batch 580/1407
# Processed batch 581/1407
# Processed batch 582/1407
# Processed batch 583/1407
# Processed batch 584/1407
# Processed batch 585/1407
# Processed batch 586/1407
# Processed batch 587/1407
# Processed batch 588/1407
# Processed batch 589/1407
# Processed batch 590/1407
# Processed batch 591/1407
# Processed batch 592/1407
# Processed batch 593/1407
# Processed batch 594/1407
# Processed batch 595/1407
# Processed batch 596/1407
# Processed batch 597/1407
# Processed batch 598/1407
# Processed batch 599/1407
# Processed batch 600/1407
# Processed batch 601/1407
# Processed batch 602/1407
# Processed batch 603/1407
# Processed batch 604/1407
# Processed batch 605/1407
# Processed batch 606/1407
# Processed batch 607/1407
# Processed batch 608/1407
# Processed batch 609/1407
# Processed batch 610/1407
# Processed batch 611/1407
# Processed batch 612/1407
# Processed batch 613/1407
# Processed batch 614/1407
# Processed batch 615/1407
# Processed batch 616/1407
# Processed batch 617/1407
# Processed batch 618/1407
# Processed batch 619/1407
# Processed batch 620/1407
# Processed batch 621/1407
# Processed batch 622/1407
# Processed batch 623/1407
# Processed batch 624/1407
# Processed batch 625/1407
# Processed batch 626/1407
# Processed batch 627/1407
# Processed batch 628/1407
# Processed batch 629/1407
# Processed batch 630/1407
# Processed batch 631/1407
# Processed batch 632/1407
# Processed batch 633/1407
# Processed batch 634/1407
# Processed batch 635/1407
# Processed batch 636/1407
# Processed batch 637/1407
# Processed batch 638/1407
# Processed batch 639/1407
# Processed batch 640/1407
# Processed batch 641/1407
# Processed batch 642/1407
# Processed batch 643/1407
# Processed batch 644/1407
# Processed batch 645/1407
# Processed batch 646/1407
# Processed batch 647/1407
# Processed batch 648/1407
# Processed batch 649/1407
# Processed batch 650/1407
# Processed batch 651/1407
# Processed batch 652/1407
# Processed batch 653/1407
# Processed batch 654/1407
# Processed batch 655/1407
# Processed batch 656/1407
# Processed batch 657/1407
# Processed batch 658/1407
# Processed batch 659/1407
# Processed batch 660/1407
# Processed batch 661/1407
# Processed batch 662/1407
# Processed batch 663/1407
# Processed batch 664/1407
# Processed batch 665/1407
# Processed batch 666/1407
# Processed batch 667/1407
# Processed batch 668/1407
# Processed batch 669/1407
# Processed batch 670/1407
# Processed batch 671/1407
# Processed batch 672/1407
# Processed batch 673/1407
# Processed batch 674/1407
# Processed batch 675/1407
# Processed batch 676/1407
# Processed batch 677/1407
# Processed batch 678/1407
# Processed batch 679/1407
# Processed batch 680/1407
# Processed batch 681/1407
# Processed batch 682/1407
# Processed batch 683/1407
# Processed batch 684/1407
# Processed batch 685/1407
# Processed batch 686/1407
# Processed batch 687/1407
# Processed batch 688/1407
# Processed batch 689/1407
# Processed batch 690/1407
# Processed batch 691/1407
# Processed batch 692/1407
# Processed batch 693/1407
# Processed batch 694/1407
# Processed batch 695/1407
# Processed batch 696/1407
# Processed batch 697/1407
# Processed batch 698/1407
# Processed batch 699/1407
# Processed batch 700/1407
# Processed batch 701/1407
# Processed batch 702/1407
# Processed batch 703/1407
# Processed batch 704/1407
# Processed batch 705/1407
# Processed batch 706/1407
# Processed batch 707/1407
# Processed batch 708/1407
# Processed batch 709/1407
# Processed batch 710/1407
# Processed batch 711/1407
# Processed batch 712/1407
# Processed batch 713/1407
# Processed batch 714/1407
# Processed batch 715/1407
# Processed batch 716/1407
# Processed batch 717/1407
# Processed batch 718/1407
# Processed batch 719/1407
# Processed batch 720/1407
# Processed batch 721/1407
# Processed batch 722/1407
# Processed batch 723/1407
# Processed batch 724/1407
# Processed batch 725/1407
# Processed batch 726/1407
# Processed batch 727/1407
# Processed batch 728/1407
# Processed batch 729/1407
# Processed batch 730/1407
# Processed batch 731/1407
# Processed batch 732/1407
# Processed batch 733/1407
# Processed batch 734/1407
# Processed batch 735/1407
# Processed batch 736/1407
# Processed batch 737/1407
# Processed batch 738/1407
# Processed batch 739/1407
# Processed batch 740/1407
# Processed batch 741/1407
# Processed batch 742/1407
# Processed batch 743/1407
# Processed batch 744/1407
# Processed batch 745/1407
# Processed batch 746/1407
# Processed batch 747/1407
# Processed batch 748/1407
# Processed batch 749/1407
# Processed batch 750/1407
# Processed batch 751/1407
# Processed batch 752/1407
# Processed batch 753/1407
# Processed batch 754/1407
# Processed batch 755/1407
# Processed batch 756/1407
# Processed batch 757/1407
# Processed batch 758/1407
# Processed batch 759/1407
# Processed batch 760/1407
# Processed batch 761/1407
# Processed batch 762/1407
# Processed batch 763/1407
# Processed batch 764/1407
# Processed batch 765/1407
# Processed batch 766/1407
# Processed batch 767/1407
# Processed batch 768/1407
# Processed batch 769/1407
# Processed batch 770/1407
# Processed batch 771/1407
# Processed batch 772/1407
# Processed batch 773/1407
# Processed batch 774/1407
# Processed batch 775/1407
# Processed batch 776/1407
# Processed batch 777/1407
# Processed batch 778/1407
# Processed batch 779/1407
# Processed batch 780/1407
# Processed batch 781/1407
# Processed batch 782/1407
# Processed batch 783/1407
# Processed batch 784/1407
# Processed batch 785/1407
# Processed batch 786/1407
# Processed batch 787/1407
# Processed batch 788/1407
# Processed batch 789/1407
# Processed batch 790/1407
# Processed batch 791/1407
# Processed batch 792/1407
# Processed batch 793/1407
# Processed batch 794/1407
# Processed batch 795/1407
# Processed batch 796/1407
# Processed batch 797/1407
# Processed batch 798/1407
# Processed batch 799/1407
# Processed batch 800/1407
# Processed batch 801/1407
# Processed batch 802/1407
# Processed batch 803/1407
# Processed batch 804/1407
# Processed batch 805/1407
# Processed batch 806/1407
# Processed batch 807/1407
# Processed batch 808/1407
# Processed batch 809/1407
# Processed batch 810/1407
# Processed batch 811/1407
# Processed batch 812/1407
# Processed batch 813/1407
# Processed batch 814/1407
# Processed batch 815/1407
# Processed batch 816/1407
# Processed batch 817/1407
# Processed batch 818/1407
# Processed batch 819/1407
# Processed batch 820/1407
# Processed batch 821/1407
# Processed batch 822/1407
# Processed batch 823/1407
# Processed batch 824/1407
# Processed batch 825/1407
# Processed batch 826/1407
# Processed batch 827/1407
# Processed batch 828/1407
# Processed batch 829/1407
# Processed batch 830/1407
# Processed batch 831/1407
# Processed batch 832/1407
# Processed batch 833/1407
# Processed batch 834/1407
# Processed batch 835/1407
# Processed batch 836/1407
# Processed batch 837/1407
# Processed batch 838/1407
# Processed batch 839/1407
# Processed batch 840/1407
# Processed batch 841/1407
# Processed batch 842/1407
# Processed batch 843/1407
# Processed batch 844/1407
# Processed batch 845/1407
# Processed batch 846/1407
# Processed batch 847/1407
# Processed batch 848/1407
# Processed batch 849/1407
# Processed batch 850/1407
# Processed batch 851/1407
# Processed batch 852/1407
# Processed batch 853/1407
# Processed batch 854/1407
# Processed batch 855/1407
# Processed batch 856/1407
# Processed batch 857/1407
# Processed batch 858/1407
# Processed batch 859/1407
# Processed batch 860/1407
# Processed batch 861/1407
# Processed batch 862/1407
# Processed batch 863/1407
# Processed batch 864/1407
# Processed batch 865/1407
# Processed batch 866/1407
# Processed batch 867/1407
# Processed batch 868/1407
# Processed batch 869/1407
# Processed batch 870/1407
# Processed batch 871/1407
# Processed batch 872/1407
# Processed batch 873/1407
# Processed batch 874/1407
# Processed batch 875/1407
# Processed batch 876/1407
# Processed batch 877/1407
# Processed batch 878/1407
# Processed batch 879/1407
# Processed batch 880/1407
# Processed batch 881/1407
# Processed batch 882/1407
# Processed batch 883/1407
# Processed batch 884/1407
# Processed batch 885/1407
# Processed batch 886/1407
# Processed batch 887/1407
# Processed batch 888/1407
# Processed batch 889/1407
# Processed batch 890/1407
# Processed batch 891/1407
# Processed batch 892/1407
# Processed batch 893/1407
# Processed batch 894/1407
# Processed batch 895/1407
# Processed batch 896/1407
# Processed batch 897/1407
# Processed batch 898/1407
# Processed batch 899/1407
# Processed batch 900/1407
# Processed batch 901/1407
# Processed batch 902/1407
# Processed batch 903/1407
# Processed batch 904/1407
# Processed batch 905/1407
# Processed batch 906/1407
# Processed batch 907/1407
# Processed batch 908/1407
# Processed batch 909/1407
# Processed batch 910/1407
# Processed batch 911/1407
# Processed batch 912/1407
# Processed batch 913/1407
# Processed batch 914/1407
# Processed batch 915/1407
# Processed batch 916/1407
# Processed batch 917/1407
# Processed batch 918/1407
# Processed batch 919/1407
# Processed batch 920/1407
# Processed batch 921/1407
# Processed batch 922/1407
# Processed batch 923/1407
# Processed batch 924/1407
# Processed batch 925/1407
# Processed batch 926/1407
# Processed batch 927/1407
# Processed batch 928/1407
# Processed batch 929/1407
# Processed batch 930/1407
# Processed batch 931/1407
# Processed batch 932/1407
# Processed batch 933/1407
# Processed batch 934/1407
# Processed batch 935/1407
# Processed batch 936/1407
# Processed batch 937/1407
# Processed batch 938/1407
# Processed batch 939/1407
# Processed batch 940/1407
# Processed batch 941/1407
# Processed batch 942/1407
# Processed batch 943/1407
# Processed batch 944/1407
# Processed batch 945/1407
# Processed batch 946/1407
# Processed batch 947/1407
# Processed batch 948/1407
# Processed batch 949/1407
# Processed batch 950/1407
# Processed batch 951/1407
# Processed batch 952/1407
# Processed batch 953/1407
# Processed batch 954/1407
# Processed batch 955/1407
# Processed batch 956/1407
# Processed batch 957/1407
# Processed batch 958/1407
# Processed batch 959/1407
# Processed batch 960/1407
# Processed batch 961/1407
# Processed batch 962/1407
# Processed batch 963/1407
# Processed batch 964/1407
# Processed batch 965/1407
# Processed batch 966/1407
# Processed batch 967/1407
# Processed batch 968/1407
# Processed batch 969/1407
# Processed batch 970/1407
# Processed batch 971/1407
# Processed batch 972/1407
# Processed batch 973/1407
# Processed batch 974/1407
# Processed batch 975/1407
# Processed batch 976/1407
# Processed batch 977/1407
# Processed batch 978/1407
# Processed batch 979/1407
# Processed batch 980/1407
# Processed batch 981/1407
# Processed batch 982/1407
# Processed batch 983/1407
# Processed batch 984/1407
# Processed batch 985/1407
# Processed batch 986/1407
# Processed batch 987/1407
# Processed batch 988/1407
# Processed batch 989/1407
# Processed batch 990/1407
# Processed batch 991/1407
# Processed batch 992/1407
# Processed batch 993/1407
# Processed batch 994/1407
# Processed batch 995/1407
# Processed batch 996/1407
# Processed batch 997/1407
# Processed batch 998/1407
# Processed batch 999/1407
# Processed batch 1000/1407
# Processed batch 1001/1407
# Processed batch 1002/1407
# Processed batch 1003/1407
# Processed batch 1004/1407
# Processed batch 1005/1407
# Processed batch 1006/1407
# Processed batch 1007/1407
# Processed batch 1008/1407
# Processed batch 1009/1407
# Processed batch 1010/1407
# Processed batch 1011/1407
# Processed batch 1012/1407
# Processed batch 1013/1407
# Processed batch 1014/1407
# Processed batch 1015/1407
# Processed batch 1016/1407
# Processed batch 1017/1407
# Processed batch 1018/1407
# Processed batch 1019/1407
# Processed batch 1020/1407
# Processed batch 1021/1407
# Processed batch 1022/1407
# Processed batch 1023/1407
# Processed batch 1024/1407
# Processed batch 1025/1407
# Processed batch 1026/1407
# Processed batch 1027/1407
# Processed batch 1028/1407
# Processed batch 1029/1407
# Processed batch 1030/1407
# Processed batch 1031/1407
# Processed batch 1032/1407
# Processed batch 1033/1407
# Processed batch 1034/1407
# Processed batch 1035/1407
# Processed batch 1036/1407
# Processed batch 1037/1407
# Processed batch 1038/1407
# Processed batch 1039/1407
# Processed batch 1040/1407
# Processed batch 1041/1407
# Processed batch 1042/1407
# Processed batch 1043/1407
# Processed batch 1044/1407
# Processed batch 1045/1407
# Processed batch 1046/1407
# Processed batch 1047/1407
# Processed batch 1048/1407
# Processed batch 1049/1407
# Processed batch 1050/1407
# Processed batch 1051/1407
# Processed batch 1052/1407
# Processed batch 1053/1407
# Processed batch 1054/1407
# Processed batch 1055/1407
# Processed batch 1056/1407
# Processed batch 1057/1407
# Processed batch 1058/1407
# Processed batch 1059/1407
# Processed batch 1060/1407
# Processed batch 1061/1407
# Processed batch 1062/1407
# Processed batch 1063/1407
# Processed batch 1064/1407
# Processed batch 1065/1407
# Processed batch 1066/1407
# Processed batch 1067/1407
# Processed batch 1068/1407
# Processed batch 1069/1407
# Processed batch 1070/1407
# Processed batch 1071/1407
# Processed batch 1072/1407
# Processed batch 1073/1407
# Processed batch 1074/1407
# Processed batch 1075/1407
# Processed batch 1076/1407
# Processed batch 1077/1407
# Processed batch 1078/1407
# Processed batch 1079/1407
# Processed batch 1080/1407
# Processed batch 1081/1407
# Processed batch 1082/1407
# Processed batch 1083/1407
# Processed batch 1084/1407
# Processed batch 1085/1407
# Processed batch 1086/1407
# Processed batch 1087/1407
# Processed batch 1088/1407
# Processed batch 1089/1407
# Processed batch 1090/1407
# Processed batch 1091/1407
# Processed batch 1092/1407
# Processed batch 1093/1407
# Processed batch 1094/1407
# Processed batch 1095/1407
# Processed batch 1096/1407
# Processed batch 1097/1407
# Processed batch 1098/1407
# Processed batch 1099/1407
# Processed batch 1100/1407
# Processed batch 1101/1407
# Processed batch 1102/1407
# Processed batch 1103/1407
# Processed batch 1104/1407
# Processed batch 1105/1407
# Processed batch 1106/1407
# Processed batch 1107/1407
# Processed batch 1108/1407
# Processed batch 1109/1407
# Processed batch 1110/1407
# Processed batch 1111/1407
# Processed batch 1112/1407
# Processed batch 1113/1407
# Processed batch 1114/1407
# Processed batch 1115/1407
# Processed batch 1116/1407
# Processed batch 1117/1407
# Processed batch 1118/1407
# Processed batch 1119/1407
# Processed batch 1120/1407
# Processed batch 1121/1407
# Processed batch 1122/1407
# Processed batch 1123/1407
# Processed batch 1124/1407
# Processed batch 1125/1407
# Processed batch 1126/1407
# Processed batch 1127/1407
# Processed batch 1128/1407
# Processed batch 1129/1407
# Processed batch 1130/1407
# Processed batch 1131/1407
# Processed batch 1132/1407
# Processed batch 1133/1407
# Processed batch 1134/1407
# Processed batch 1135/1407
# Processed batch 1136/1407
# Processed batch 1137/1407
# Processed batch 1138/1407
# Processed batch 1139/1407
# Processed batch 1140/1407
# Processed batch 1141/1407
# Processed batch 1142/1407
# Processed batch 1143/1407
# Processed batch 1144/1407
# Processed batch 1145/1407
# Processed batch 1146/1407
# Processed batch 1147/1407
# Processed batch 1148/1407
# Processed batch 1149/1407
# Processed batch 1150/1407
# Processed batch 1151/1407
# Processed batch 1152/1407
# Processed batch 1153/1407
# Processed batch 1154/1407
# Processed batch 1155/1407
# Processed batch 1156/1407
# Processed batch 1157/1407
# Processed batch 1158/1407
# Processed batch 1159/1407
# Processed batch 1160/1407
# Processed batch 1161/1407
# Processed batch 1162/1407
# Processed batch 1163/1407
# Processed batch 1164/1407
# Processed batch 1165/1407
# Processed batch 1166/1407
# Processed batch 1167/1407
# Processed batch 1168/1407
# Processed batch 1169/1407
# Processed batch 1170/1407
# Processed batch 1171/1407
# Processed batch 1172/1407
# Processed batch 1173/1407
# Processed batch 1174/1407
# Processed batch 1175/1407
# Processed batch 1176/1407
# Processed batch 1177/1407
# Processed batch 1178/1407
# Processed batch 1179/1407
# Processed batch 1180/1407
# Processed batch 1181/1407
# Processed batch 1182/1407
# Processed batch 1183/1407
# Processed batch 1184/1407
# Processed batch 1185/1407
# Processed batch 1186/1407
# Processed batch 1187/1407
# Processed batch 1188/1407
# Processed batch 1189/1407
# Processed batch 1190/1407
# Processed batch 1191/1407
# Processed batch 1192/1407
# Processed batch 1193/1407
# Processed batch 1194/1407
# Processed batch 1195/1407
# Processed batch 1196/1407
# Processed batch 1197/1407
# Processed batch 1198/1407
# Processed batch 1199/1407
# Processed batch 1200/1407
# Processed batch 1201/1407
# Processed batch 1202/1407
# Processed batch 1203/1407
# Processed batch 1204/1407
# Processed batch 1205/1407
# Processed batch 1206/1407
# Processed batch 1207/1407
# Processed batch 1208/1407
# Processed batch 1209/1407
# Processed batch 1210/1407
# Processed batch 1211/1407
# Processed batch 1212/1407
# Processed batch 1213/1407
# Processed batch 1214/1407
# Processed batch 1215/1407
# Processed batch 1216/1407
# Processed batch 1217/1407
# Processed batch 1218/1407
# Processed batch 1219/1407
# Processed batch 1220/1407
# Processed batch 1221/1407
# Processed batch 1222/1407
# Processed batch 1223/1407
# Processed batch 1224/1407
# Processed batch 1225/1407
# Processed batch 1226/1407
# Processed batch 1227/1407
# Processed batch 1228/1407
# Processed batch 1229/1407
# Processed batch 1230/1407
# Processed batch 1231/1407
# Processed batch 1232/1407
# Processed batch 1233/1407
# Processed batch 1234/1407
# Processed batch 1235/1407
# Processed batch 1236/1407
# Processed batch 1237/1407
# Processed batch 1238/1407
# Processed batch 1239/1407
# Processed batch 1240/1407
# Processed batch 1241/1407
# Processed batch 1242/1407
# Processed batch 1243/1407
# Processed batch 1244/1407
# Processed batch 1245/1407
# Processed batch 1246/1407
# Processed batch 1247/1407
# Processed batch 1248/1407
# Processed batch 1249/1407
# Processed batch 1250/1407
# Processed batch 1251/1407
# Processed batch 1252/1407
# Processed batch 1253/1407
# Processed batch 1254/1407
# Processed batch 1255/1407
# Processed batch 1256/1407
# Processed batch 1257/1407
# Processed batch 1258/1407
# Processed batch 1259/1407
# Processed batch 1260/1407
# Processed batch 1261/1407
# Processed batch 1262/1407
# Processed batch 1263/1407
# Processed batch 1264/1407
# Processed batch 1265/1407
# Processed batch 1266/1407
# Processed batch 1267/1407
# Processed batch 1268/1407
# Processed batch 1269/1407
# Processed batch 1270/1407
# Processed batch 1271/1407
# Processed batch 1272/1407
# Processed batch 1273/1407
# Processed batch 1274/1407
# Processed batch 1275/1407
# Processed batch 1276/1407
# Processed batch 1277/1407
# Processed batch 1278/1407
# Processed batch 1279/1407
# Processed batch 1280/1407
# Processed batch 1281/1407
# Processed batch 1282/1407
# Processed batch 1283/1407
# Processed batch 1284/1407
# Processed batch 1285/1407
# Processed batch 1286/1407
# Processed batch 1287/1407
# Processed batch 1288/1407
# Processed batch 1289/1407
# Processed batch 1290/1407
# Processed batch 1291/1407
# Processed batch 1292/1407
# Processed batch 1293/1407
# Processed batch 1294/1407
# Processed batch 1295/1407
# Processed batch 1296/1407
# Processed batch 1297/1407
# Processed batch 1298/1407
# Processed batch 1299/1407
# Processed batch 1300/1407
# Processed batch 1301/1407
# Processed batch 1302/1407
# Processed batch 1303/1407
# Processed batch 1304/1407
# Processed batch 1305/1407
# Processed batch 1306/1407
# Processed batch 1307/1407
# Processed batch 1308/1407
# Processed batch 1309/1407
# Processed batch 1310/1407
# Processed batch 1311/1407
# Processed batch 1312/1407
# Processed batch 1313/1407
# Processed batch 1314/1407
# Processed batch 1315/1407
# Processed batch 1316/1407
# Processed batch 1317/1407
# Processed batch 1318/1407
# Processed batch 1319/1407
# Processed batch 1320/1407
# Processed batch 1321/1407
# Processed batch 1322/1407
# Processed batch 1323/1407
# Processed batch 1324/1407
# Processed batch 1325/1407
# Processed batch 1326/1407
# Processed batch 1327/1407
# Processed batch 1328/1407
# Processed batch 1329/1407
# Processed batch 1330/1407
# Processed batch 1331/1407
# Processed batch 1332/1407
# Processed batch 1333/1407
# Processed batch 1334/1407
# Processed batch 1335/1407
# Processed batch 1336/1407
# Processed batch 1337/1407
# Processed batch 1338/1407
# Processed batch 1339/1407
# Processed batch 1340/1407
# Processed batch 1341/1407
# Processed batch 1342/1407
# Processed batch 1343/1407
# Processed batch 1344/1407
# Processed batch 1345/1407
# Processed batch 1346/1407
# Processed batch 1347/1407
# Processed batch 1348/1407
# Processed batch 1349/1407
# Processed batch 1350/1407
# Processed batch 1351/1407
# Processed batch 1352/1407
# Processed batch 1353/1407
# Processed batch 1354/1407
# Processed batch 1355/1407
# Processed batch 1356/1407
# Processed batch 1357/1407
# Processed batch 1358/1407
# Processed batch 1359/1407
# Processed batch 1360/1407
# Processed batch 1361/1407
# Processed batch 1362/1407
# Processed batch 1363/1407
# Processed batch 1364/1407
# Processed batch 1365/1407
# Processed batch 1366/1407
# Processed batch 1367/1407
# Processed batch 1368/1407
# Processed batch 1369/1407
# Processed batch 1370/1407
# Processed batch 1371/1407
# Processed batch 1372/1407
# Processed batch 1373/1407
# Processed batch 1374/1407
# Processed batch 1375/1407
# Processed batch 1376/1407
# Processed batch 1377/1407
# Processed batch 1378/1407
# Processed batch 1379/1407
# Processed batch 1380/1407
# Processed batch 1381/1407
# Processed batch 1382/1407
# Processed batch 1383/1407
# Processed batch 1384/1407
# Processed batch 1385/1407
# Processed batch 1386/1407
# Processed batch 1387/1407
# Processed batch 1388/1407
# Processed batch 1389/1407
# Processed batch 1390/1407
# Processed batch 1391/1407
# Processed batch 1392/1407
# Processed batch 1393/1407
# Processed batch 1394/1407
# Processed batch 1395/1407
# Processed batch 1396/1407
# Processed batch 1397/1407
# Processed batch 1398/1407
# Processed batch 1399/1407
# Processed batch 1400/1407
# Processed batch 1401/1407
# Processed batch 1402/1407
# Processed batch 1403/1407
# Processed batch 1404/1407
# Processed batch 1405/1407
# Processed batch 1406/1407
# Processed batch 1407/1407

# %%
def aggregate_rgb_frequencies(pixel_freq):
    """
    Aggregate RGB frequencies from pixel frequency data and convert RGB to grayscale.

    Args:
        pixel_freq (dict): Dictionary of pixel frequencies with coordinates as keys
                           and RGB frequency counts as values.

    Returns:
        pd.DataFrame: DataFrame containing aggregated frequencies for each pixel and
                      grayscale mapping.
    """
    data = []

    # Convert pixel frequency data into a flat list for DataFrame
    for (i, j), rgb_counts in pixel_freq.items():
        for rgb, count in rgb_counts.items():
            data.append((i, j, rgb[0], rgb[1], rgb[2], len(count)))

    # Create a DataFrame
    df = pd.DataFrame(data, columns=['x', 'y', 'R', 'G', 'B', 'frequency'])

    # Convert RGB to grayscale
    def rgb_to_grayscale(r, g, b):
        return 0.299 * r + 0.587 * g + 0.114 * b

    df['gray_value'] = df.apply(lambda row: rgb_to_grayscale(row['R'], row['G'], row['B']), axis=1)

    # Group by pixel coordinates (x, y)
    grouped = df.groupby(['x', 'y'])

    # Aggregate grayscale and frequency information
    result = grouped.apply(
        lambda group: group.groupby('gray_value')
        .agg({'frequency': 'sum', 'R': 'first', 'G': 'first', 'B': 'first'})
        .reset_index()
        .assign(x=group['x'].iloc[0], y=group['y'].iloc[0])
    ).reset_index(drop=True)

    return result

# %%
# Assuming `pixel_freq` is the output from `calculate_pixel_frequencies_from_loader`
result_df = aggregate_rgb_frequencies(pixel_freq)

# Display the result
print(result_df)
# Out:
#         gray_value  frequency         R         G         B    x    y
# 0         0.000000          9  0.000000  0.000000  0.000000   60  111
# 1         0.000447          1  0.000000  0.000000  0.003922   60  111
# 2         0.001341          1  0.000000  0.000000  0.011765   60  111
# 3         0.002302          1  0.000000  0.003922  0.000000   60  111
# 4         0.002749          2  0.000000  0.003922  0.003922   60  111
# ...            ...        ...       ...       ...       ...  ...  ...
# 928381    0.997933          1  0.996078  1.000000  0.992157  147   87
# 928382    0.998659          3  1.000000  1.000000  0.988235  147   87
# 928383    0.998827          2  0.996078  1.000000  1.000000  147   87
# 928384    0.999553          4  1.000000  1.000000  0.996078  147   87
# 928385    1.000000         21  1.000000  1.000000  1.000000  147   87
#
# [928386 rows x 7 columns]
# /tmp/ipykernel_697652/1455862275.py:33: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = grouped.apply(

# %%
def analyze_max_x_for_epsilon(df, t, epsilon):
    """
    Analyze and compute the maximum x for epsilon for each pixel in the DataFrame.

    Args:
        df (pd.DataFrame): DataFrame containing pixel data with columns 'x', 'y', 'gray_value', 'frequency'.
        t (int): Threshold value for frequency adjustment.
        epsilon (float): Epsilon value to determine maximum x.

    Returns:
        pd.DataFrame: DataFrame containing 'x', 'y', 'gray_value', and 'max_x'.
    """
    def max_x_for_epsilon(freq, t, epsilon):
        # Remaining count after subtracting the threshold t
        remaining_count = int(freq - t)
        if remaining_count <= 0:
            return 0

        max_x = 0
        for x in range(1, remaining_count + 1):
            # Compute the probability using scipy's comb
            probability = comb(freq, x) / comb(remaining_count, x)
            if probability <= epsilon:
                max_x = x
            else:
                break
        return max_x

    # Process each row in the DataFrame and calculate max_x
    results = []
    for _, row in df.iterrows():
        max_x = max_x_for_epsilon(row['frequency'], t, epsilon)
        results.append((row['x'], row['y'], row['gray_value'], max_x))

    # Create a new DataFrame with the results
    return pd.DataFrame(results, columns=['x', 'y', 'gray_value', 'max_x'])

# %%
results_df = analyze_max_x_for_epsilon(result_df, t=2, epsilon=2)
maxValues = results_df.max()
print(maxValues)
# Out:
# x             147.0
# y             143.0
# gray_value      1.0
# max_x          25.0
# dtype: float64

# %%
'''import random
import pickle

def sample_rgb_values(pixel_freq, pixel_coords, results_df, original_df, save_path=None):
    """
    Sample RGB values based on max_x for each pixel coordinate and optionally save them.

    Args:
        pixel_freq (dict): Dictionary of pixel frequencies with coordinates as keys
                           and RGB frequency counts as values.
        pixel_coords (list of tuples): List of pixel coordinates to evaluate.
        results_df (pd.DataFrame): DataFrame containing 'x', 'y', 'gray_value', and 'max_x'.
        original_df (pd.DataFrame): Original DataFrame containing pixel RGB and frequency data.
        save_path (str, optional): Path to save the sampled RGB values. If provided, saves the result.

    Returns:
        dict: Dictionary of sampled RGB values for each coordinate and grayscale level.
    """
    # Initialize a dictionary to store sampled RGB values
    sampled_rgb_values = {coord: {} for coord in pixel_coords}

    # Iterate through the pixel coordinates
    for (i, j) in pixel_coords:
        # Filter the results DataFrame for the current coordinate
        coord_df = results_df[(results_df['x'] == i) & (results_df['y'] == j)]

        # Iterate through the rows for this coordinate
        for _, row in coord_df.iterrows():
            gray_value, max_x = row['gray_value'], row['max_x']

            # Filter the original DataFrame for matching grayscale and pixel coordinates
            original_coord_df = original_df[
                (original_df['x'] == i) & 
                (original_df['y'] == j) & 
                (original_df['gray_value'].round().astype(int) == int(round(gray_value)))
            ]

            # Extract RGB values from pixel_freq for the matching grayscale and coordinate
            rgb_values = []
            for _, orig_row in original_coord_df.iterrows():
                rgb_key = (orig_row['R'], orig_row['G'], orig_row['B'])
                if rgb_key in pixel_freq[(i, j)]:
                    rgb_values.extend([entry[0] for entry in pixel_freq[(i, j)][rgb_key]])

            # Sample up to max_x RGB values, or return an empty list if insufficient values
            sampled_rgb_values[(i, j)][gray_value] = random.sample(rgb_values, int(max_x)) if len(rgb_values) >= max_x else []

    # Save the sampled RGB values if a save path is provided
    if save_path:
        with open(save_path, 'wb') as f:
            pickle.dump(sampled_rgb_values, f)
        print(f"Sampled RGB values saved to {save_path}")

    return sampled_rgb_values'''
# Out:
# 'import random\nimport pickle\n\ndef sample_rgb_values(pixel_freq, pixel_coords, results_df, original_df, save_path=None):\n    """\n    Sample RGB values based on max_x for each pixel coordinate and optionally save them.\n\n    Args:\n        pixel_freq (dict): Dictionary of pixel frequencies with coordinates as keys\n                           and RGB frequency counts as values.\n        pixel_coords (list of tuples): List of pixel coordinates to evaluate.\n        results_df (pd.DataFrame): DataFrame containing \'x\', \'y\', \'gray_value\', and \'max_x\'.\n        original_df (pd.DataFrame): Original DataFrame containing pixel RGB and frequency data.\n        save_path (str, optional): Path to save the sampled RGB values. If provided, saves the result.\n\n    Returns:\n        dict: Dictionary of sampled RGB values for each coordinate and grayscale level.\n    """\n    # Initialize a dictionary to store sampled RGB values\n    sampled_rgb_values = {coord: {} for coord in pixel_coords}\n\n    # Iterate through the pixel coordinates\n    for (i, j) in pixel_coords:\n        # Filter the results DataFrame for the current coordinate\n        coord_df = results_df[(results_df[\'x\'] == i) & (results_df[\'y\'] == j)]\n\n        # Iterate through the rows for this coordinate\n        for _, row in coord_df.iterrows():\n            gray_value, max_x = row[\'gray_value\'], row[\'max_x\']\n\n            # Filter the original DataFrame for matching grayscale and pixel coordinates\n            original_coord_df = original_df[\n                (original_df[\'x\'] == i) & \n                (original_df[\'y\'] == j) & \n                (original_df[\'gray_value\'].round().astype(int) == int(round(gray_value)))\n            ]\n\n            # Extract RGB values from pixel_freq for the matching grayscale and coordinate\n            rgb_values = []\n            for _, orig_row in original_coord_df.iterrows():\n                rgb_key = (orig_row[\'R\'], orig_row[\'G\'], orig_row[\'B\'])\n                if rgb_key in pixel_freq[(i, j)]:\n                    rgb_values.extend([entry[0] for entry in pixel_freq[(i, j)][rgb_key]])\n\n            # Sample up to max_x RGB values, or return an empty list if insufficient values\n            sampled_rgb_values[(i, j)][gray_value] = random.sample(rgb_values, int(max_x)) if len(rgb_values) >= max_x else []\n\n    # Save the sampled RGB values if a save path is provided\n    if save_path:\n        with open(save_path, \'wb\') as f:\n            pickle.dump(sampled_rgb_values, f)\n        print(f"Sampled RGB values saved to {save_path}")\n\n    return sampled_rgb_values'

# %%
import random
import pickle
import pandas as pd

def sample_rgb_values(pixel_freq, pixel_coords, results_df, original_df, save_path=None):
    """
    Optimized function to sample RGB values based on max_x for each pixel coordinate.

    Args:
        pixel_freq (dict): Dictionary of pixel frequencies with coordinates as keys
                           and RGB frequency counts as values.
        pixel_coords (list of tuples): List of pixel coordinates to evaluate.
        results_df (pd.DataFrame): DataFrame containing 'x', 'y', 'gray_value', and 'max_x'.
        original_df (pd.DataFrame): Original DataFrame containing pixel RGB and frequency data.
        save_path (str, optional): Path to save the sampled RGB values. If provided, saves periodically.
        save_interval (int, optional): Number of coordinates to process before saving intermediate results.

    Returns:
        dict: Dictionary of sampled RGB values for each coordinate and grayscale level.
    """
    sampled_rgb_values = {}  # Initialize result dictionary

    # Convert pixel_freq to a flattened DataFrame for faster lookups
    flat_pixel_freq = []
    for (x, y), rgb_dict in pixel_freq.items():
        for rgb, entries in rgb_dict.items():
            flat_pixel_freq.append((x, y, *rgb, len(entries)))
    freq_df = pd.DataFrame(flat_pixel_freq, columns=['x', 'y', 'R', 'G', 'B', 'frequency'])

    # Iterate through the pixel coordinates
    for idx, (i, j) in enumerate(pixel_coords):
        sampled_rgb_values[(i, j)] = {}
        # Filter for the current coordinate
        coord_results = results_df[(results_df['x'] == i) & (results_df['y'] == j)]

        # Process each grayscale value and max_x for the coordinate
        for _, row in coord_results.iterrows():
            gray_value, max_x = row['gray_value'], row['max_x']

            # Filter original DataFrame for grayscale match
            original_coord_df = original_df[
                (original_df['x'] == i) & 
                (original_df['y'] == j) & 
                (original_df['gray_value'].round().astype(int) == int(round(gray_value)))
            ]

            # Extract RGB values
            if not original_coord_df.empty:
                rgb_values = original_coord_df[['R', 'G', 'B']].values.tolist()
                # Sample up to max_x values or return an empty list if insufficient
                sampled_rgb_values[(i, j)][gray_value] = random.sample(rgb_values, int(max_x)) if len(rgb_values) >= max_x else []

        # Save intermediate results periodically
        if save_path and idx % save_interval == 0:
            with open(save_path, 'wb') as f:
                pickle.dump(sampled_rgb_values, f)
            print(f"Saved intermediate results after processing {idx + 1} coordinates.")

    # Final save
    if save_path:
        with open(save_path, 'wb') as f:
            pickle.dump(sampled_rgb_values, f)
        print(f"Final sampled RGB values saved to {save_path}")

    return sampled_rgb_values

# %%
'''import time

start_time = time.time()

sampled_values = sample_rgb_values(pixel_freq, top_22_coords, results_df, result_df, save_path="/home/j597s263/scratch/j597s263/Datasets/Defense/Resnet/SampledValues/t2e2_cif.pkl")

end_time = time.time()

print(f"Execution time: {end_time - start_time:.2f} seconds")'''
# Out:
# 'import time\n\nstart_time = time.time()\n\nsampled_values = sample_rgb_values(pixel_freq, top_22_coords, results_df, result_df, save_path="/home/j597s263/scratch/j597s263/Datasets/Defense/Resnet/SampledValues/t2e2_cif.pkl")\n\nend_time = time.time()\n\nprint(f"Execution time: {end_time - start_time:.2f} seconds")'

# %%
import pickle

# Load the sampled RGB values in one line
sampled_values = pickle.load(open("/home/j597s263/scratch/j597s263/Datasets/Defense/Resnet/SampledValues/Opt/t2e3_cif.pkl", "rb"))
print("Sampled RGB values loaded successfully!")
# Out:
# Sampled RGB values loaded successfully!

# %%
import os
import torch

def apply_samples_to_dataset(data_loader, sampled_rgb_values, pixel_coords, output_path):
    """
    Apply sampled RGB values to images and save the dataset with labels to a file.

    Args:
        data_loader (DataLoader): DataLoader containing the images to modify.
        sampled_rgb_values (dict): Dictionary of sampled RGB values for each pixel.
        pixel_coords (list of tuples): List of pixel coordinates to evaluate.
        output_path (str): Path to the file where the dataset will be saved.
    """
    modified_images = []
    labels = []

    # Process each image in the data loader
    for batch_idx, (images, batch_labels) in enumerate(data_loader):
        images = images.clone()  # Clone to avoid modifying the original data
        batch_size = images.size(0)

        for img_idx in range(batch_size):
            image_tensor = images[img_idx]
            img_array = image_tensor.permute(1, 2, 0).cpu().numpy()  # Convert to (H, W, C)

            height, width, _ = img_array.shape
            for coord in pixel_coords:
                x, y = coord
                if x < height and y < width:
                    if (x, y) in sampled_rgb_values:
                        gray_levels = sampled_rgb_values[(x, y)]
                        found = False
                        for gray_level in gray_levels:
                            if img_idx in gray_levels[gray_level]:
                                found = True
                                break
                        if not found:
                            img_array[x, y] = [0, 0, 0]  # Set to black if no match
                    else:
                        img_array[x, y] = [0, 0, 0]  # Set to black for unmatched coordinates

            # Convert modified array back to tensor
            modified_tensor = torch.from_numpy(img_array).permute(2, 0, 1)

            # Add modified tensor and corresponding label to the dataset
            modified_images.append(modified_tensor)
            labels.append(batch_labels[img_idx].item())

        print(f"Processed batch {batch_idx + 1}/{len(data_loader)}")

    # Save the modified dataset
    dataset = {
        "images": torch.stack(modified_images),
        "labels": torch.tensor(labels)
    }
    torch.save(dataset, output_path)
    print(f"Modified dataset saved to {output_path}")

# %%
output_dir = "/home/j597s263/scratch/j597s263/Datasets/Defense/Resnet/ResCifShap.pt"
apply_samples_to_dataset(train_loader, sampled_values, top_22_coords, output_dir)
# Out:
# Processed batch 1/1407
# Processed batch 2/1407
# Processed batch 3/1407
# Processed batch 4/1407
# Processed batch 5/1407
# Processed batch 6/1407
# Processed batch 7/1407
# Processed batch 8/1407
# Processed batch 9/1407
# Processed batch 10/1407
# Processed batch 11/1407
# Processed batch 12/1407
# Processed batch 13/1407
# Processed batch 14/1407
# Processed batch 15/1407
# Processed batch 16/1407
# Processed batch 17/1407
# Processed batch 18/1407
# Processed batch 19/1407
# Processed batch 20/1407
# Processed batch 21/1407
# Processed batch 22/1407
# Processed batch 23/1407
# Processed batch 24/1407
# Processed batch 25/1407
# Processed batch 26/1407
# Processed batch 27/1407
# Processed batch 28/1407
# Processed batch 29/1407
# Processed batch 30/1407
# Processed batch 31/1407
# Processed batch 32/1407
# Processed batch 33/1407
# Processed batch 34/1407
# Processed batch 35/1407
# Processed batch 36/1407
# Processed batch 37/1407
# Processed batch 38/1407
# Processed batch 39/1407
# Processed batch 40/1407
# Processed batch 41/1407
# Processed batch 42/1407
# Processed batch 43/1407
# Processed batch 44/1407
# Processed batch 45/1407
# Processed batch 46/1407
# Processed batch 47/1407
# Processed batch 48/1407
# Processed batch 49/1407
# Processed batch 50/1407
# Processed batch 51/1407
# Processed batch 52/1407
# Processed batch 53/1407
# Processed batch 54/1407
# Processed batch 55/1407
# Processed batch 56/1407
# Processed batch 57/1407
# Processed batch 58/1407
# Processed batch 59/1407
# Processed batch 60/1407
# Processed batch 61/1407
# Processed batch 62/1407
# Processed batch 63/1407
# Processed batch 64/1407
# Processed batch 65/1407
# Processed batch 66/1407
# Processed batch 67/1407
# Processed batch 68/1407
# Processed batch 69/1407
# Processed batch 70/1407
# Processed batch 71/1407
# Processed batch 72/1407
# Processed batch 73/1407
# Processed batch 74/1407
# Processed batch 75/1407
# Processed batch 76/1407
# Processed batch 77/1407
# Processed batch 78/1407
# Processed batch 79/1407
# Processed batch 80/1407
# Processed batch 81/1407
# Processed batch 82/1407
# Processed batch 83/1407
# Processed batch 84/1407
# Processed batch 85/1407
# Processed batch 86/1407
# Processed batch 87/1407
# Processed batch 88/1407
# Processed batch 89/1407
# Processed batch 90/1407
# Processed batch 91/1407
# Processed batch 92/1407
# Processed batch 93/1407
# Processed batch 94/1407
# Processed batch 95/1407
# Processed batch 96/1407
# Processed batch 97/1407
# Processed batch 98/1407
# Processed batch 99/1407
# Processed batch 100/1407
# Processed batch 101/1407
# Processed batch 102/1407
# Processed batch 103/1407
# Processed batch 104/1407
# Processed batch 105/1407
# Processed batch 106/1407
# Processed batch 107/1407
# Processed batch 108/1407
# Processed batch 109/1407
# Processed batch 110/1407
# Processed batch 111/1407
# Processed batch 112/1407
# Processed batch 113/1407
# Processed batch 114/1407
# Processed batch 115/1407
# Processed batch 116/1407
# Processed batch 117/1407
# Processed batch 118/1407
# Processed batch 119/1407
# Processed batch 120/1407
# Processed batch 121/1407
# Processed batch 122/1407
# Processed batch 123/1407
# Processed batch 124/1407
# Processed batch 125/1407
# Processed batch 126/1407
# Processed batch 127/1407
# Processed batch 128/1407
# Processed batch 129/1407
# Processed batch 130/1407
# Processed batch 131/1407
# Processed batch 132/1407
# Processed batch 133/1407
# Processed batch 134/1407
# Processed batch 135/1407
# Processed batch 136/1407
# Processed batch 137/1407
# Processed batch 138/1407
# Processed batch 139/1407
# Processed batch 140/1407
# Processed batch 141/1407
# Processed batch 142/1407
# Processed batch 143/1407
# Processed batch 144/1407
# Processed batch 145/1407
# Processed batch 146/1407
# Processed batch 147/1407
# Processed batch 148/1407
# Processed batch 149/1407
# Processed batch 150/1407
# Processed batch 151/1407
# Processed batch 152/1407
# Processed batch 153/1407
# Processed batch 154/1407
# Processed batch 155/1407
# Processed batch 156/1407
# Processed batch 157/1407
# Processed batch 158/1407
# Processed batch 159/1407
# Processed batch 160/1407
# Processed batch 161/1407
# Processed batch 162/1407
# Processed batch 163/1407
# Processed batch 164/1407
# Processed batch 165/1407
# Processed batch 166/1407
# Processed batch 167/1407
# Processed batch 168/1407
# Processed batch 169/1407
# Processed batch 170/1407
# Processed batch 171/1407
# Processed batch 172/1407
# Processed batch 173/1407
# Processed batch 174/1407
# Processed batch 175/1407
# Processed batch 176/1407
# Processed batch 177/1407
# Processed batch 178/1407
# Processed batch 179/1407
# Processed batch 180/1407
# Processed batch 181/1407
# Processed batch 182/1407
# Processed batch 183/1407
# Processed batch 184/1407
# Processed batch 185/1407
# Processed batch 186/1407
# Processed batch 187/1407
# Processed batch 188/1407
# Processed batch 189/1407
# Processed batch 190/1407
# Processed batch 191/1407
# Processed batch 192/1407
# Processed batch 193/1407
# Processed batch 194/1407
# Processed batch 195/1407
# Processed batch 196/1407
# Processed batch 197/1407
# Processed batch 198/1407
# Processed batch 199/1407
# Processed batch 200/1407
# Processed batch 201/1407
# Processed batch 202/1407
# Processed batch 203/1407
# Processed batch 204/1407
# Processed batch 205/1407
# Processed batch 206/1407
# Processed batch 207/1407
# Processed batch 208/1407
# Processed batch 209/1407
# Processed batch 210/1407
# Processed batch 211/1407
# Processed batch 212/1407
# Processed batch 213/1407
# Processed batch 214/1407
# Processed batch 215/1407
# Processed batch 216/1407
# Processed batch 217/1407
# Processed batch 218/1407
# Processed batch 219/1407
# Processed batch 220/1407
# Processed batch 221/1407
# Processed batch 222/1407
# Processed batch 223/1407
# Processed batch 224/1407
# Processed batch 225/1407
# Processed batch 226/1407
# Processed batch 227/1407
# Processed batch 228/1407
# Processed batch 229/1407
# Processed batch 230/1407
# Processed batch 231/1407
# Processed batch 232/1407
# Processed batch 233/1407
# Processed batch 234/1407
# Processed batch 235/1407
# Processed batch 236/1407
# Processed batch 237/1407
# Processed batch 238/1407
# Processed batch 239/1407
# Processed batch 240/1407
# Processed batch 241/1407
# Processed batch 242/1407
# Processed batch 243/1407
# Processed batch 244/1407
# Processed batch 245/1407
# Processed batch 246/1407
# Processed batch 247/1407
# Processed batch 248/1407
# Processed batch 249/1407
# Processed batch 250/1407
# Processed batch 251/1407
# Processed batch 252/1407
# Processed batch 253/1407
# Processed batch 254/1407
# Processed batch 255/1407
# Processed batch 256/1407
# Processed batch 257/1407
# Processed batch 258/1407
# Processed batch 259/1407
# Processed batch 260/1407
# Processed batch 261/1407
# Processed batch 262/1407
# Processed batch 263/1407
# Processed batch 264/1407
# Processed batch 265/1407
# Processed batch 266/1407
# Processed batch 267/1407
# Processed batch 268/1407
# Processed batch 269/1407
# Processed batch 270/1407
# Processed batch 271/1407
# Processed batch 272/1407
# Processed batch 273/1407
# Processed batch 274/1407
# Processed batch 275/1407
# Processed batch 276/1407
# Processed batch 277/1407
# Processed batch 278/1407
# Processed batch 279/1407
# Processed batch 280/1407
# Processed batch 281/1407
# Processed batch 282/1407
# Processed batch 283/1407
# Processed batch 284/1407
# Processed batch 285/1407
# Processed batch 286/1407
# Processed batch 287/1407
# Processed batch 288/1407
# Processed batch 289/1407
# Processed batch 290/1407
# Processed batch 291/1407
# Processed batch 292/1407
# Processed batch 293/1407
# Processed batch 294/1407
# Processed batch 295/1407
# Processed batch 296/1407
# Processed batch 297/1407
# Processed batch 298/1407
# Processed batch 299/1407
# Processed batch 300/1407
# Processed batch 301/1407
# Processed batch 302/1407
# Processed batch 303/1407
# Processed batch 304/1407
# Processed batch 305/1407
# Processed batch 306/1407
# Processed batch 307/1407
# Processed batch 308/1407
# Processed batch 309/1407
# Processed batch 310/1407
# Processed batch 311/1407
# Processed batch 312/1407
# Processed batch 313/1407
# Processed batch 314/1407
# Processed batch 315/1407
# Processed batch 316/1407
# Processed batch 317/1407
# Processed batch 318/1407
# Processed batch 319/1407
# Processed batch 320/1407
# Processed batch 321/1407
# Processed batch 322/1407
# Processed batch 323/1407
# Processed batch 324/1407
# Processed batch 325/1407
# Processed batch 326/1407
# Processed batch 327/1407
# Processed batch 328/1407
# Processed batch 329/1407
# Processed batch 330/1407
# Processed batch 331/1407
# Processed batch 332/1407
# Processed batch 333/1407
# Processed batch 334/1407
# Processed batch 335/1407
# Processed batch 336/1407
# Processed batch 337/1407
# Processed batch 338/1407
# Processed batch 339/1407
# Processed batch 340/1407
# Processed batch 341/1407
# Processed batch 342/1407
# Processed batch 343/1407
# Processed batch 344/1407
# Processed batch 345/1407
# Processed batch 346/1407
# Processed batch 347/1407
# Processed batch 348/1407
# Processed batch 349/1407
# Processed batch 350/1407
# Processed batch 351/1407
# Processed batch 352/1407
# Processed batch 353/1407
# Processed batch 354/1407
# Processed batch 355/1407
# Processed batch 356/1407
# Processed batch 357/1407
# Processed batch 358/1407
# Processed batch 359/1407
# Processed batch 360/1407
# Processed batch 361/1407
# Processed batch 362/1407
# Processed batch 363/1407
# Processed batch 364/1407
# Processed batch 365/1407
# Processed batch 366/1407
# Processed batch 367/1407
# Processed batch 368/1407
# Processed batch 369/1407
# Processed batch 370/1407
# Processed batch 371/1407
# Processed batch 372/1407
# Processed batch 373/1407
# Processed batch 374/1407
# Processed batch 375/1407
# Processed batch 376/1407
# Processed batch 377/1407
# Processed batch 378/1407
# Processed batch 379/1407
# Processed batch 380/1407
# Processed batch 381/1407
# Processed batch 382/1407
# Processed batch 383/1407
# Processed batch 384/1407
# Processed batch 385/1407
# Processed batch 386/1407
# Processed batch 387/1407
# Processed batch 388/1407
# Processed batch 389/1407
# Processed batch 390/1407
# Processed batch 391/1407
# Processed batch 392/1407
# Processed batch 393/1407
# Processed batch 394/1407
# Processed batch 395/1407
# Processed batch 396/1407
# Processed batch 397/1407
# Processed batch 398/1407
# Processed batch 399/1407
# Processed batch 400/1407
# Processed batch 401/1407
# Processed batch 402/1407
# Processed batch 403/1407
# Processed batch 404/1407
# Processed batch 405/1407
# Processed batch 406/1407
# Processed batch 407/1407
# Processed batch 408/1407
# Processed batch 409/1407
# Processed batch 410/1407
# Processed batch 411/1407
# Processed batch 412/1407
# Processed batch 413/1407
# Processed batch 414/1407
# Processed batch 415/1407
# Processed batch 416/1407
# Processed batch 417/1407
# Processed batch 418/1407
# Processed batch 419/1407
# Processed batch 420/1407
# Processed batch 421/1407
# Processed batch 422/1407
# Processed batch 423/1407
# Processed batch 424/1407
# Processed batch 425/1407
# Processed batch 426/1407
# Processed batch 427/1407
# Processed batch 428/1407
# Processed batch 429/1407
# Processed batch 430/1407
# Processed batch 431/1407
# Processed batch 432/1407
# Processed batch 433/1407
# Processed batch 434/1407
# Processed batch 435/1407
# Processed batch 436/1407
# Processed batch 437/1407
# Processed batch 438/1407
# Processed batch 439/1407
# Processed batch 440/1407
# Processed batch 441/1407
# Processed batch 442/1407
# Processed batch 443/1407
# Processed batch 444/1407
# Processed batch 445/1407
# Processed batch 446/1407
# Processed batch 447/1407
# Processed batch 448/1407
# Processed batch 449/1407
# Processed batch 450/1407
# Processed batch 451/1407
# Processed batch 452/1407
# Processed batch 453/1407
# Processed batch 454/1407
# Processed batch 455/1407
# Processed batch 456/1407
# Processed batch 457/1407
# Processed batch 458/1407
# Processed batch 459/1407
# Processed batch 460/1407
# Processed batch 461/1407
# Processed batch 462/1407
# Processed batch 463/1407
# Processed batch 464/1407
# Processed batch 465/1407
# Processed batch 466/1407
# Processed batch 467/1407
# Processed batch 468/1407
# Processed batch 469/1407
# Processed batch 470/1407
# Processed batch 471/1407
# Processed batch 472/1407
# Processed batch 473/1407
# Processed batch 474/1407
# Processed batch 475/1407
# Processed batch 476/1407
# Processed batch 477/1407
# Processed batch 478/1407
# Processed batch 479/1407
# Processed batch 480/1407
# Processed batch 481/1407
# Processed batch 482/1407
# Processed batch 483/1407
# Processed batch 484/1407
# Processed batch 485/1407
# Processed batch 486/1407
# Processed batch 487/1407
# Processed batch 488/1407
# Processed batch 489/1407
# Processed batch 490/1407
# Processed batch 491/1407
# Processed batch 492/1407
# Processed batch 493/1407
# Processed batch 494/1407
# Processed batch 495/1407
# Processed batch 496/1407
# Processed batch 497/1407
# Processed batch 498/1407
# Processed batch 499/1407
# Processed batch 500/1407
# Processed batch 501/1407
# Processed batch 502/1407
# Processed batch 503/1407
# Processed batch 504/1407
# Processed batch 505/1407
# Processed batch 506/1407
# Processed batch 507/1407
# Processed batch 508/1407
# Processed batch 509/1407
# Processed batch 510/1407
# Processed batch 511/1407
# Processed batch 512/1407
# Processed batch 513/1407
# Processed batch 514/1407
# Processed batch 515/1407
# Processed batch 516/1407
# Processed batch 517/1407
# Processed batch 518/1407
# Processed batch 519/1407
# Processed batch 520/1407
# Processed batch 521/1407
# Processed batch 522/1407
# Processed batch 523/1407
# Processed batch 524/1407
# Processed batch 525/1407
# Processed batch 526/1407
# Processed batch 527/1407
# Processed batch 528/1407
# Processed batch 529/1407
# Processed batch 530/1407
# Processed batch 531/1407
# Processed batch 532/1407
# Processed batch 533/1407
# Processed batch 534/1407
# Processed batch 535/1407
# Processed batch 536/1407
# Processed batch 537/1407
# Processed batch 538/1407
# Processed batch 539/1407
# Processed batch 540/1407
# Processed batch 541/1407
# Processed batch 542/1407
# Processed batch 543/1407
# Processed batch 544/1407
# Processed batch 545/1407
# Processed batch 546/1407
# Processed batch 547/1407
# Processed batch 548/1407
# Processed batch 549/1407
# Processed batch 550/1407
# Processed batch 551/1407
# Processed batch 552/1407
# Processed batch 553/1407
# Processed batch 554/1407
# Processed batch 555/1407
# Processed batch 556/1407
# Processed batch 557/1407
# Processed batch 558/1407
# Processed batch 559/1407
# Processed batch 560/1407
# Processed batch 561/1407
# Processed batch 562/1407
# Processed batch 563/1407
# Processed batch 564/1407
# Processed batch 565/1407
# Processed batch 566/1407
# Processed batch 567/1407
# Processed batch 568/1407
# Processed batch 569/1407
# Processed batch 570/1407
# Processed batch 571/1407
# Processed batch 572/1407
# Processed batch 573/1407
# Processed batch 574/1407
# Processed batch 575/1407
# Processed batch 576/1407
# Processed batch 577/1407
# Processed batch 578/1407
# Processed batch 579/1407
# Processed batch 580/1407
# Processed batch 581/1407
# Processed batch 582/1407
# Processed batch 583/1407
# Processed batch 584/1407
# Processed batch 585/1407
# Processed batch 586/1407
# Processed batch 587/1407
# Processed batch 588/1407
# Processed batch 589/1407
# Processed batch 590/1407
# Processed batch 591/1407
# Processed batch 592/1407
# Processed batch 593/1407
# Processed batch 594/1407
# Processed batch 595/1407
# Processed batch 596/1407
# Processed batch 597/1407
# Processed batch 598/1407
# Processed batch 599/1407
# Processed batch 600/1407
# Processed batch 601/1407
# Processed batch 602/1407
# Processed batch 603/1407
# Processed batch 604/1407
# Processed batch 605/1407
# Processed batch 606/1407
# Processed batch 607/1407
# Processed batch 608/1407
# Processed batch 609/1407
# Processed batch 610/1407
# Processed batch 611/1407
# Processed batch 612/1407
# Processed batch 613/1407
# Processed batch 614/1407
# Processed batch 615/1407
# Processed batch 616/1407
# Processed batch 617/1407
# Processed batch 618/1407
# Processed batch 619/1407
# Processed batch 620/1407
# Processed batch 621/1407
# Processed batch 622/1407
# Processed batch 623/1407
# Processed batch 624/1407
# Processed batch 625/1407
# Processed batch 626/1407
# Processed batch 627/1407
# Processed batch 628/1407
# Processed batch 629/1407
# Processed batch 630/1407
# Processed batch 631/1407
# Processed batch 632/1407
# Processed batch 633/1407
# Processed batch 634/1407
# Processed batch 635/1407
# Processed batch 636/1407
# Processed batch 637/1407
# Processed batch 638/1407
# Processed batch 639/1407
# Processed batch 640/1407
# Processed batch 641/1407
# Processed batch 642/1407
# Processed batch 643/1407
# Processed batch 644/1407
# Processed batch 645/1407
# Processed batch 646/1407
# Processed batch 647/1407
# Processed batch 648/1407
# Processed batch 649/1407
# Processed batch 650/1407
# Processed batch 651/1407
# Processed batch 652/1407
# Processed batch 653/1407
# Processed batch 654/1407
# Processed batch 655/1407
# Processed batch 656/1407
# Processed batch 657/1407
# Processed batch 658/1407
# Processed batch 659/1407
# Processed batch 660/1407
# Processed batch 661/1407
# Processed batch 662/1407
# Processed batch 663/1407
# Processed batch 664/1407
# Processed batch 665/1407
# Processed batch 666/1407
# Processed batch 667/1407
# Processed batch 668/1407
# Processed batch 669/1407
# Processed batch 670/1407
# Processed batch 671/1407
# Processed batch 672/1407
# Processed batch 673/1407
# Processed batch 674/1407
# Processed batch 675/1407
# Processed batch 676/1407
# Processed batch 677/1407
# Processed batch 678/1407
# Processed batch 679/1407
# Processed batch 680/1407
# Processed batch 681/1407
# Processed batch 682/1407
# Processed batch 683/1407
# Processed batch 684/1407
# Processed batch 685/1407
# Processed batch 686/1407
# Processed batch 687/1407
# Processed batch 688/1407
# Processed batch 689/1407
# Processed batch 690/1407
# Processed batch 691/1407
# Processed batch 692/1407
# Processed batch 693/1407
# Processed batch 694/1407
# Processed batch 695/1407
# Processed batch 696/1407
# Processed batch 697/1407
# Processed batch 698/1407
# Processed batch 699/1407
# Processed batch 700/1407
# Processed batch 701/1407
# Processed batch 702/1407
# Processed batch 703/1407
# Processed batch 704/1407
# Processed batch 705/1407
# Processed batch 706/1407
# Processed batch 707/1407
# Processed batch 708/1407
# Processed batch 709/1407
# Processed batch 710/1407
# Processed batch 711/1407
# Processed batch 712/1407
# Processed batch 713/1407
# Processed batch 714/1407
# Processed batch 715/1407
# Processed batch 716/1407
# Processed batch 717/1407
# Processed batch 718/1407
# Processed batch 719/1407
# Processed batch 720/1407
# Processed batch 721/1407
# Processed batch 722/1407
# Processed batch 723/1407
# Processed batch 724/1407
# Processed batch 725/1407
# Processed batch 726/1407
# Processed batch 727/1407
# Processed batch 728/1407
# Processed batch 729/1407
# Processed batch 730/1407
# Processed batch 731/1407
# Processed batch 732/1407
# Processed batch 733/1407
# Processed batch 734/1407
# Processed batch 735/1407
# Processed batch 736/1407
# Processed batch 737/1407
# Processed batch 738/1407
# Processed batch 739/1407
# Processed batch 740/1407
# Processed batch 741/1407
# Processed batch 742/1407
# Processed batch 743/1407
# Processed batch 744/1407
# Processed batch 745/1407
# Processed batch 746/1407
# Processed batch 747/1407
# Processed batch 748/1407
# Processed batch 749/1407
# Processed batch 750/1407
# Processed batch 751/1407
# Processed batch 752/1407
# Processed batch 753/1407
# Processed batch 754/1407
# Processed batch 755/1407
# Processed batch 756/1407
# Processed batch 757/1407
# Processed batch 758/1407
# Processed batch 759/1407
# Processed batch 760/1407
# Processed batch 761/1407
# Processed batch 762/1407
# Processed batch 763/1407
# Processed batch 764/1407
# Processed batch 765/1407
# Processed batch 766/1407
# Processed batch 767/1407
# Processed batch 768/1407
# Processed batch 769/1407
# Processed batch 770/1407
# Processed batch 771/1407
# Processed batch 772/1407
# Processed batch 773/1407
# Processed batch 774/1407
# Processed batch 775/1407
# Processed batch 776/1407
# Processed batch 777/1407
# Processed batch 778/1407
# Processed batch 779/1407
# Processed batch 780/1407
# Processed batch 781/1407
# Processed batch 782/1407
# Processed batch 783/1407
# Processed batch 784/1407
# Processed batch 785/1407
# Processed batch 786/1407
# Processed batch 787/1407
# Processed batch 788/1407
# Processed batch 789/1407
# Processed batch 790/1407
# Processed batch 791/1407
# Processed batch 792/1407
# Processed batch 793/1407
# Processed batch 794/1407
# Processed batch 795/1407
# Processed batch 796/1407
# Processed batch 797/1407
# Processed batch 798/1407
# Processed batch 799/1407
# Processed batch 800/1407
# Processed batch 801/1407
# Processed batch 802/1407
# Processed batch 803/1407
# Processed batch 804/1407
# Processed batch 805/1407
# Processed batch 806/1407
# Processed batch 807/1407
# Processed batch 808/1407
# Processed batch 809/1407
# Processed batch 810/1407
# Processed batch 811/1407
# Processed batch 812/1407
# Processed batch 813/1407
# Processed batch 814/1407
# Processed batch 815/1407
# Processed batch 816/1407
# Processed batch 817/1407
# Processed batch 818/1407
# Processed batch 819/1407
# Processed batch 820/1407
# Processed batch 821/1407
# Processed batch 822/1407
# Processed batch 823/1407
# Processed batch 824/1407
# Processed batch 825/1407
# Processed batch 826/1407
# Processed batch 827/1407
# Processed batch 828/1407
# Processed batch 829/1407
# Processed batch 830/1407
# Processed batch 831/1407
# Processed batch 832/1407
# Processed batch 833/1407
# Processed batch 834/1407
# Processed batch 835/1407
# Processed batch 836/1407
# Processed batch 837/1407
# Processed batch 838/1407
# Processed batch 839/1407
# Processed batch 840/1407
# Processed batch 841/1407
# Processed batch 842/1407
# Processed batch 843/1407
# Processed batch 844/1407
# Processed batch 845/1407
# Processed batch 846/1407
# Processed batch 847/1407
# Processed batch 848/1407
# Processed batch 849/1407
# Processed batch 850/1407
# Processed batch 851/1407
# Processed batch 852/1407
# Processed batch 853/1407
# Processed batch 854/1407
# Processed batch 855/1407
# Processed batch 856/1407
# Processed batch 857/1407
# Processed batch 858/1407
# Processed batch 859/1407
# Processed batch 860/1407
# Processed batch 861/1407
# Processed batch 862/1407
# Processed batch 863/1407
# Processed batch 864/1407
# Processed batch 865/1407
# Processed batch 866/1407
# Processed batch 867/1407
# Processed batch 868/1407
# Processed batch 869/1407
# Processed batch 870/1407
# Processed batch 871/1407
# Processed batch 872/1407
# Processed batch 873/1407
# Processed batch 874/1407
# Processed batch 875/1407
# Processed batch 876/1407
# Processed batch 877/1407
# Processed batch 878/1407
# Processed batch 879/1407
# Processed batch 880/1407
# Processed batch 881/1407
# Processed batch 882/1407
# Processed batch 883/1407
# Processed batch 884/1407
# Processed batch 885/1407
# Processed batch 886/1407
# Processed batch 887/1407
# Processed batch 888/1407
# Processed batch 889/1407
# Processed batch 890/1407
# Processed batch 891/1407
# Processed batch 892/1407
# Processed batch 893/1407
# Processed batch 894/1407
# Processed batch 895/1407
# Processed batch 896/1407
# Processed batch 897/1407
# Processed batch 898/1407
# Processed batch 899/1407
# Processed batch 900/1407
# Processed batch 901/1407
# Processed batch 902/1407
# Processed batch 903/1407
# Processed batch 904/1407
# Processed batch 905/1407
# Processed batch 906/1407
# Processed batch 907/1407
# Processed batch 908/1407
# Processed batch 909/1407
# Processed batch 910/1407
# Processed batch 911/1407
# Processed batch 912/1407
# Processed batch 913/1407
# Processed batch 914/1407
# Processed batch 915/1407
# Processed batch 916/1407
# Processed batch 917/1407
# Processed batch 918/1407
# Processed batch 919/1407
# Processed batch 920/1407
# Processed batch 921/1407
# Processed batch 922/1407
# Processed batch 923/1407
# Processed batch 924/1407
# Processed batch 925/1407
# Processed batch 926/1407
# Processed batch 927/1407
# Processed batch 928/1407
# Processed batch 929/1407
# Processed batch 930/1407
# Processed batch 931/1407
# Processed batch 932/1407
# Processed batch 933/1407
# Processed batch 934/1407
# Processed batch 935/1407
# Processed batch 936/1407
# Processed batch 937/1407
# Processed batch 938/1407
# Processed batch 939/1407
# Processed batch 940/1407
# Processed batch 941/1407
# Processed batch 942/1407
# Processed batch 943/1407
# Processed batch 944/1407
# Processed batch 945/1407
# Processed batch 946/1407
# Processed batch 947/1407
# Processed batch 948/1407
# Processed batch 949/1407
# Processed batch 950/1407
# Processed batch 951/1407
# Processed batch 952/1407
# Processed batch 953/1407
# Processed batch 954/1407
# Processed batch 955/1407
# Processed batch 956/1407
# Processed batch 957/1407
# Processed batch 958/1407
# Processed batch 959/1407
# Processed batch 960/1407
# Processed batch 961/1407
# Processed batch 962/1407
# Processed batch 963/1407
# Processed batch 964/1407
# Processed batch 965/1407
# Processed batch 966/1407
# Processed batch 967/1407
# Processed batch 968/1407
# Processed batch 969/1407
# Processed batch 970/1407
# Processed batch 971/1407
# Processed batch 972/1407
# Processed batch 973/1407
# Processed batch 974/1407
# Processed batch 975/1407
# Processed batch 976/1407
# Processed batch 977/1407
# Processed batch 978/1407
# Processed batch 979/1407
# Processed batch 980/1407
# Processed batch 981/1407
# Processed batch 982/1407
# Processed batch 983/1407
# Processed batch 984/1407
# Processed batch 985/1407
# Processed batch 986/1407
# Processed batch 987/1407
# Processed batch 988/1407
# Processed batch 989/1407
# Processed batch 990/1407
# Processed batch 991/1407
# Processed batch 992/1407
# Processed batch 993/1407
# Processed batch 994/1407
# Processed batch 995/1407
# Processed batch 996/1407
# Processed batch 997/1407
# Processed batch 998/1407
# Processed batch 999/1407
# Processed batch 1000/1407
# Processed batch 1001/1407
# Processed batch 1002/1407
# Processed batch 1003/1407
# Processed batch 1004/1407
# Processed batch 1005/1407
# Processed batch 1006/1407
# Processed batch 1007/1407
# Processed batch 1008/1407
# Processed batch 1009/1407
# Processed batch 1010/1407
# Processed batch 1011/1407
# Processed batch 1012/1407
# Processed batch 1013/1407
# Processed batch 1014/1407
# Processed batch 1015/1407
# Processed batch 1016/1407
# Processed batch 1017/1407
# Processed batch 1018/1407
# Processed batch 1019/1407
# Processed batch 1020/1407
# Processed batch 1021/1407
# Processed batch 1022/1407
# Processed batch 1023/1407
# Processed batch 1024/1407
# Processed batch 1025/1407
# Processed batch 1026/1407
# Processed batch 1027/1407
# Processed batch 1028/1407
# Processed batch 1029/1407
# Processed batch 1030/1407
# Processed batch 1031/1407
# Processed batch 1032/1407
# Processed batch 1033/1407
# Processed batch 1034/1407
# Processed batch 1035/1407
# Processed batch 1036/1407
# Processed batch 1037/1407
# Processed batch 1038/1407
# Processed batch 1039/1407
# Processed batch 1040/1407
# Processed batch 1041/1407
# Processed batch 1042/1407
# Processed batch 1043/1407
# Processed batch 1044/1407
# Processed batch 1045/1407
# Processed batch 1046/1407
# Processed batch 1047/1407
# Processed batch 1048/1407
# Processed batch 1049/1407
# Processed batch 1050/1407
# Processed batch 1051/1407
# Processed batch 1052/1407
# Processed batch 1053/1407
# Processed batch 1054/1407
# Processed batch 1055/1407
# Processed batch 1056/1407
# Processed batch 1057/1407
# Processed batch 1058/1407
# Processed batch 1059/1407
# Processed batch 1060/1407
# Processed batch 1061/1407
# Processed batch 1062/1407
# Processed batch 1063/1407
# Processed batch 1064/1407
# Processed batch 1065/1407
# Processed batch 1066/1407
# Processed batch 1067/1407
# Processed batch 1068/1407
# Processed batch 1069/1407
# Processed batch 1070/1407
# Processed batch 1071/1407
# Processed batch 1072/1407
# Processed batch 1073/1407
# Processed batch 1074/1407
# Processed batch 1075/1407
# Processed batch 1076/1407
# Processed batch 1077/1407
# Processed batch 1078/1407
# Processed batch 1079/1407
# Processed batch 1080/1407
# Processed batch 1081/1407
# Processed batch 1082/1407
# Processed batch 1083/1407
# Processed batch 1084/1407
# Processed batch 1085/1407
# Processed batch 1086/1407
# Processed batch 1087/1407
# Processed batch 1088/1407
# Processed batch 1089/1407
# Processed batch 1090/1407
# Processed batch 1091/1407
# Processed batch 1092/1407
# Processed batch 1093/1407
# Processed batch 1094/1407
# Processed batch 1095/1407
# Processed batch 1096/1407
# Processed batch 1097/1407
# Processed batch 1098/1407
# Processed batch 1099/1407
# Processed batch 1100/1407
# Processed batch 1101/1407
# Processed batch 1102/1407
# Processed batch 1103/1407
# Processed batch 1104/1407
# Processed batch 1105/1407
# Processed batch 1106/1407
# Processed batch 1107/1407
# Processed batch 1108/1407
# Processed batch 1109/1407
# Processed batch 1110/1407
# Processed batch 1111/1407
# Processed batch 1112/1407
# Processed batch 1113/1407
# Processed batch 1114/1407
# Processed batch 1115/1407
# Processed batch 1116/1407
# Processed batch 1117/1407
# Processed batch 1118/1407
# Processed batch 1119/1407
# Processed batch 1120/1407
# Processed batch 1121/1407
# Processed batch 1122/1407
# Processed batch 1123/1407
# Processed batch 1124/1407
# Processed batch 1125/1407
# Processed batch 1126/1407
# Processed batch 1127/1407
# Processed batch 1128/1407
# Processed batch 1129/1407
# Processed batch 1130/1407
# Processed batch 1131/1407
# Processed batch 1132/1407
# Processed batch 1133/1407
# Processed batch 1134/1407
# Processed batch 1135/1407
# Processed batch 1136/1407
# Processed batch 1137/1407
# Processed batch 1138/1407
# Processed batch 1139/1407
# Processed batch 1140/1407
# Processed batch 1141/1407
# Processed batch 1142/1407
# Processed batch 1143/1407
# Processed batch 1144/1407
# Processed batch 1145/1407
# Processed batch 1146/1407
# Processed batch 1147/1407
# Processed batch 1148/1407
# Processed batch 1149/1407
# Processed batch 1150/1407
# Processed batch 1151/1407
# Processed batch 1152/1407
# Processed batch 1153/1407
# Processed batch 1154/1407
# Processed batch 1155/1407
# Processed batch 1156/1407
# Processed batch 1157/1407
# Processed batch 1158/1407
# Processed batch 1159/1407
# Processed batch 1160/1407
# Processed batch 1161/1407
# Processed batch 1162/1407
# Processed batch 1163/1407
# Processed batch 1164/1407
# Processed batch 1165/1407
# Processed batch 1166/1407
# Processed batch 1167/1407
# Processed batch 1168/1407
# Processed batch 1169/1407
# Processed batch 1170/1407
# Processed batch 1171/1407
# Processed batch 1172/1407
# Processed batch 1173/1407
# Processed batch 1174/1407
# Processed batch 1175/1407
# Processed batch 1176/1407
# Processed batch 1177/1407
# Processed batch 1178/1407
# Processed batch 1179/1407
# Processed batch 1180/1407
# Processed batch 1181/1407
# Processed batch 1182/1407
# Processed batch 1183/1407
# Processed batch 1184/1407
# Processed batch 1185/1407
# Processed batch 1186/1407
# Processed batch 1187/1407
# Processed batch 1188/1407
# Processed batch 1189/1407
# Processed batch 1190/1407
# Processed batch 1191/1407
# Processed batch 1192/1407
# Processed batch 1193/1407
# Processed batch 1194/1407
# Processed batch 1195/1407
# Processed batch 1196/1407
# Processed batch 1197/1407
# Processed batch 1198/1407
# Processed batch 1199/1407
# Processed batch 1200/1407
# Processed batch 1201/1407
# Processed batch 1202/1407
# Processed batch 1203/1407
# Processed batch 1204/1407
# Processed batch 1205/1407
# Processed batch 1206/1407
# Processed batch 1207/1407
# Processed batch 1208/1407
# Processed batch 1209/1407
# Processed batch 1210/1407
# Processed batch 1211/1407
# Processed batch 1212/1407
# Processed batch 1213/1407
# Processed batch 1214/1407
# Processed batch 1215/1407
# Processed batch 1216/1407
# Processed batch 1217/1407
# Processed batch 1218/1407
# Processed batch 1219/1407
# Processed batch 1220/1407
# Processed batch 1221/1407
# Processed batch 1222/1407
# Processed batch 1223/1407
# Processed batch 1224/1407
# Processed batch 1225/1407
# Processed batch 1226/1407
# Processed batch 1227/1407
# Processed batch 1228/1407
# Processed batch 1229/1407
# Processed batch 1230/1407
# Processed batch 1231/1407
# Processed batch 1232/1407
# Processed batch 1233/1407
# Processed batch 1234/1407
# Processed batch 1235/1407
# Processed batch 1236/1407
# Processed batch 1237/1407
# Processed batch 1238/1407
# Processed batch 1239/1407
# Processed batch 1240/1407
# Processed batch 1241/1407
# Processed batch 1242/1407
# Processed batch 1243/1407
# Processed batch 1244/1407
# Processed batch 1245/1407
# Processed batch 1246/1407
# Processed batch 1247/1407
# Processed batch 1248/1407
# Processed batch 1249/1407
# Processed batch 1250/1407
# Processed batch 1251/1407
# Processed batch 1252/1407
# Processed batch 1253/1407
# Processed batch 1254/1407
# Processed batch 1255/1407
# Processed batch 1256/1407
# Processed batch 1257/1407
# Processed batch 1258/1407
# Processed batch 1259/1407
# Processed batch 1260/1407
# Processed batch 1261/1407
# Processed batch 1262/1407
# Processed batch 1263/1407
# Processed batch 1264/1407
# Processed batch 1265/1407
# Processed batch 1266/1407
# Processed batch 1267/1407
# Processed batch 1268/1407
# Processed batch 1269/1407
# Processed batch 1270/1407
# Processed batch 1271/1407
# Processed batch 1272/1407
# Processed batch 1273/1407
# Processed batch 1274/1407
# Processed batch 1275/1407
# Processed batch 1276/1407
# Processed batch 1277/1407
# Processed batch 1278/1407
# Processed batch 1279/1407
# Processed batch 1281/1407
# Processed batch 1282/1407
# Processed batch 1283/1407
# Processed batch 1284/1407
# Processed batch 1285/1407
# Processed batch 1286/1407
# Processed batch 1287/1407
# Processed batch 1288/1407
# Processed batch 1289/1407
# Processed batch 1290/1407
# Processed batch 1291/1407
# Processed batch 1292/1407
# Processed batch 1293/1407
# Processed batch 1294/1407
# Processed batch 1295/1407
# Processed batch 1296/1407
# Processed batch 1297/1407
