# %%
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader, Subset
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.amp import GradScaler, autocast
import os
import random
import pandas as pd
from scipy.special import comb
from scipy.stats import binom

# %%
import torch
import numpy as np
from torch.utils.data import DataLoader, Subset
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import random

# Define dataset root directory
mnist_root = '/home/j597s263/scratch/j597s263/Datasets/MNIST'

random.seed(42)
torch.manual_seed(42)
np.random.seed(42)

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor()
])

train_dataset = datasets.MNIST(root=mnist_root, transform=transform, train=True, download=True)
test_dataset = datasets.MNIST(root=mnist_root, transform=transform, train=False, download=True)

train_indices = list(range(len(train_dataset)))
random.shuffle(train_indices)  

split_idx = int(0.9 * len(train_indices))  
train_indices, attack_indices = train_indices[:split_idx], train_indices[split_idx:]

train_data = Subset(train_dataset, train_indices)
attack_data = Subset(train_dataset, attack_indices)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)  # Shuffle within batches
attack_loader = DataLoader(attack_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

print(f"Total training samples: {len(train_dataset)}")
print(f"Training samples after split: {len(train_data)}")
print(f"Attack samples: {len(attack_data)}")
print(f"Testing samples: {len(test_dataset)}")
# Out:
# Total training samples: 60000
# Training samples after split: 54000
# Attack samples: 6000
# Testing samples: 10000

# %%
def get_pixel_coords(flat_indices, width):
    return [divmod(idx, width) for idx in flat_indices]

# %%
def calculate_pixel_frequencies_from_loader(data_loader, pixel_coords):
    """
    Calculate the frequency of grayscale pixel values at specific coordinates from an MNIST DataLoader.

    Args:
        data_loader (DataLoader): A DataLoader containing the MNIST dataset.
        pixel_coords (list of tuples): A list of (x, y) pixel coordinates to evaluate.

    Returns:
        dict: A dictionary where keys are pixel coordinates, and values are dictionaries of grayscale frequencies.
    """
    pixel_freq = {coord: {} for coord in pixel_coords}

    for batch_idx, (images, _) in enumerate(data_loader):
        # Move batch to CPU and convert to NumPy for efficient processing
        images = images.cpu().numpy()  # Shape: (batch_size, 1, height, width)

        # Iterate through the batch of images
        for img_idx, img_array in enumerate(images):
            img_array = img_array.squeeze(0)  # Convert from (1, H, W) to (H, W)

            # Check and count each specified pixel coordinate
            for (i, j) in pixel_coords:
                if 0 <= i < img_array.shape[0] and 0 <= j < img_array.shape[1]:
                    pixel_value = int(img_array[i, j] * 255)  # Convert to grayscale intensity (0-255)
                    
                    if pixel_value not in pixel_freq[(i, j)]:
                        pixel_freq[(i, j)][pixel_value] = 0
                    pixel_freq[(i, j)][pixel_value] += 1  # Increment count

        print(f"Processed batch {batch_idx + 1}/{len(data_loader)}")

    return pixel_freq

# %%
top_22_coords = [
    (151, 83), (155, 83), (147, 79), (87, 79), (151, 79),
    (151, 87), (155, 87), (139, 71), (139, 75), (91, 79),
    (147, 83), (143, 75), (89, 75), (83, 79), (147, 75),
    (108, 146), (115, 156), (167, 158), (85, 75), (155, 79),
    (171, 158), (125, 77)
]

pixel_freq = calculate_pixel_frequencies_from_loader(train_loader, top_22_coords)

print(pixel_freq[(151, 83)])
# Out:
# Processed batch 1/844
# Processed batch 2/844
# Processed batch 3/844
# Processed batch 4/844
# Processed batch 5/844
# Processed batch 6/844
# Processed batch 7/844
# Processed batch 8/844
# Processed batch 9/844
# Processed batch 10/844
# Processed batch 11/844
# Processed batch 12/844
# Processed batch 13/844
# Processed batch 14/844
# Processed batch 15/844
# Processed batch 16/844
# Processed batch 17/844
# Processed batch 18/844
# Processed batch 19/844
# Processed batch 20/844
# Processed batch 21/844
# Processed batch 22/844
# Processed batch 23/844
# Processed batch 24/844
# Processed batch 25/844
# Processed batch 26/844
# Processed batch 27/844
# Processed batch 28/844
# Processed batch 29/844
# Processed batch 30/844
# Processed batch 31/844
# Processed batch 32/844
# Processed batch 33/844
# Processed batch 34/844
# Processed batch 35/844
# Processed batch 36/844
# Processed batch 37/844
# Processed batch 38/844
# Processed batch 39/844
# Processed batch 40/844
# Processed batch 41/844
# Processed batch 42/844
# Processed batch 43/844
# Processed batch 44/844
# Processed batch 45/844
# Processed batch 46/844
# Processed batch 47/844
# Processed batch 48/844
# Processed batch 49/844
# Processed batch 50/844
# Processed batch 51/844
# Processed batch 52/844
# Processed batch 53/844
# Processed batch 54/844
# Processed batch 55/844
# Processed batch 56/844
# Processed batch 57/844
# Processed batch 58/844
# Processed batch 59/844
# Processed batch 60/844
# Processed batch 61/844
# Processed batch 62/844
# Processed batch 63/844
# Processed batch 64/844
# Processed batch 65/844
# Processed batch 66/844
# Processed batch 67/844
# Processed batch 68/844
# Processed batch 69/844
# Processed batch 70/844
# Processed batch 71/844
# Processed batch 72/844
# Processed batch 73/844
# Processed batch 74/844
# Processed batch 75/844
# Processed batch 76/844
# Processed batch 77/844
# Processed batch 78/844
# Processed batch 79/844
# Processed batch 80/844
# Processed batch 81/844
# Processed batch 82/844
# Processed batch 83/844
# Processed batch 84/844
# Processed batch 85/844
# Processed batch 86/844
# Processed batch 87/844
# Processed batch 88/844
# Processed batch 89/844
# Processed batch 90/844
# Processed batch 91/844
# Processed batch 92/844
# Processed batch 93/844
# Processed batch 94/844
# Processed batch 95/844
# Processed batch 96/844
# Processed batch 97/844
# Processed batch 98/844
# Processed batch 99/844
# Processed batch 100/844
# Processed batch 101/844
# Processed batch 102/844
# Processed batch 103/844
# Processed batch 104/844
# Processed batch 105/844
# Processed batch 106/844
# Processed batch 107/844
# Processed batch 108/844
# Processed batch 109/844
# Processed batch 110/844
# Processed batch 111/844
# Processed batch 112/844
# Processed batch 113/844
# Processed batch 114/844
# Processed batch 115/844
# Processed batch 116/844
# Processed batch 117/844
# Processed batch 118/844
# Processed batch 119/844
# Processed batch 120/844
# Processed batch 121/844
# Processed batch 122/844
# Processed batch 123/844
# Processed batch 124/844
# Processed batch 125/844
# Processed batch 126/844
# Processed batch 127/844
# Processed batch 128/844
# Processed batch 129/844
# Processed batch 130/844
# Processed batch 131/844
# Processed batch 132/844
# Processed batch 133/844
# Processed batch 134/844
# Processed batch 135/844
# Processed batch 136/844
# Processed batch 137/844
# Processed batch 138/844
# Processed batch 139/844
# Processed batch 140/844
# Processed batch 141/844
# Processed batch 142/844
# Processed batch 143/844
# Processed batch 144/844
# Processed batch 145/844
# Processed batch 146/844
# Processed batch 147/844
# Processed batch 148/844
# Processed batch 149/844
# Processed batch 150/844
# Processed batch 151/844
# Processed batch 152/844
# Processed batch 153/844
# Processed batch 154/844
# Processed batch 155/844
# Processed batch 156/844
# Processed batch 157/844
# Processed batch 158/844
# Processed batch 159/844
# Processed batch 160/844
# Processed batch 161/844
# Processed batch 162/844
# Processed batch 163/844
# Processed batch 164/844
# Processed batch 165/844
# Processed batch 166/844
# Processed batch 167/844
# Processed batch 168/844
# Processed batch 169/844
# Processed batch 170/844
# Processed batch 171/844
# Processed batch 172/844
# Processed batch 173/844
# Processed batch 174/844
# Processed batch 175/844
# Processed batch 176/844
# Processed batch 177/844
# Processed batch 178/844
# Processed batch 179/844
# Processed batch 180/844
# Processed batch 181/844
# Processed batch 182/844
# Processed batch 183/844
# Processed batch 184/844
# Processed batch 185/844
# Processed batch 186/844
# Processed batch 187/844
# Processed batch 188/844
# Processed batch 189/844
# Processed batch 190/844
# Processed batch 191/844
# Processed batch 192/844
# Processed batch 193/844
# Processed batch 194/844
# Processed batch 195/844
# Processed batch 196/844
# Processed batch 197/844
# Processed batch 198/844
# Processed batch 199/844
# Processed batch 200/844
# Processed batch 201/844
# Processed batch 202/844
# Processed batch 203/844
# Processed batch 204/844
# Processed batch 205/844
# Processed batch 206/844
# Processed batch 207/844
# Processed batch 208/844
# Processed batch 209/844
# Processed batch 210/844
# Processed batch 211/844
# Processed batch 212/844
# Processed batch 213/844
# Processed batch 214/844
# Processed batch 215/844
# Processed batch 216/844
# Processed batch 217/844
# Processed batch 218/844
# Processed batch 219/844
# Processed batch 220/844
# Processed batch 221/844
# Processed batch 222/844
# Processed batch 223/844
# Processed batch 224/844
# Processed batch 225/844
# Processed batch 226/844
# Processed batch 227/844
# Processed batch 228/844
# Processed batch 229/844
# Processed batch 230/844
# Processed batch 231/844
# Processed batch 232/844
# Processed batch 233/844
# Processed batch 234/844
# Processed batch 235/844
# Processed batch 236/844
# Processed batch 237/844
# Processed batch 238/844
# Processed batch 239/844
# Processed batch 240/844
# Processed batch 241/844
# Processed batch 242/844
# Processed batch 243/844
# Processed batch 244/844
# Processed batch 245/844
# Processed batch 246/844
# Processed batch 247/844
# Processed batch 248/844
# Processed batch 249/844
# Processed batch 250/844
# Processed batch 251/844
# Processed batch 252/844
# Processed batch 253/844
# Processed batch 254/844
# Processed batch 255/844
# Processed batch 256/844
# Processed batch 257/844
# Processed batch 258/844
# Processed batch 259/844
# Processed batch 260/844
# Processed batch 261/844
# Processed batch 262/844
# Processed batch 263/844
# Processed batch 264/844
# Processed batch 265/844
# Processed batch 266/844
# Processed batch 267/844
# Processed batch 268/844
# Processed batch 269/844
# Processed batch 270/844
# Processed batch 271/844
# Processed batch 272/844
# Processed batch 273/844
# Processed batch 274/844
# Processed batch 275/844
# Processed batch 276/844
# Processed batch 277/844
# Processed batch 278/844
# Processed batch 279/844
# Processed batch 280/844
# Processed batch 281/844
# Processed batch 282/844
# Processed batch 283/844
# Processed batch 284/844
# Processed batch 285/844
# Processed batch 286/844
# Processed batch 287/844
# Processed batch 288/844
# Processed batch 289/844
# Processed batch 290/844
# Processed batch 291/844
# Processed batch 292/844
# Processed batch 293/844
# Processed batch 294/844
# Processed batch 295/844
# Processed batch 296/844
# Processed batch 297/844
# Processed batch 298/844
# Processed batch 299/844
# Processed batch 300/844
# Processed batch 301/844
# Processed batch 302/844
# Processed batch 303/844
# Processed batch 304/844
# Processed batch 305/844
# Processed batch 306/844
# Processed batch 307/844
# Processed batch 308/844
# Processed batch 309/844
# Processed batch 310/844
# Processed batch 311/844
# Processed batch 312/844
# Processed batch 313/844
# Processed batch 314/844
# Processed batch 315/844
# Processed batch 316/844
# Processed batch 317/844
# Processed batch 318/844
# Processed batch 319/844
# Processed batch 320/844
# Processed batch 321/844
# Processed batch 322/844
# Processed batch 323/844
# Processed batch 324/844
# Processed batch 325/844
# Processed batch 326/844
# Processed batch 327/844
# Processed batch 328/844
# Processed batch 329/844
# Processed batch 330/844
# Processed batch 331/844
# Processed batch 332/844
# Processed batch 333/844
# Processed batch 334/844
# Processed batch 335/844
# Processed batch 336/844
# Processed batch 337/844
# Processed batch 338/844
# Processed batch 339/844
# Processed batch 340/844
# Processed batch 341/844
# Processed batch 342/844
# Processed batch 343/844
# Processed batch 344/844
# Processed batch 345/844
# Processed batch 346/844
# Processed batch 347/844
# Processed batch 348/844
# Processed batch 349/844
# Processed batch 350/844
# Processed batch 351/844
# Processed batch 352/844
# Processed batch 353/844
# Processed batch 354/844
# Processed batch 355/844
# Processed batch 356/844
# Processed batch 357/844
# Processed batch 358/844
# Processed batch 359/844
# Processed batch 360/844
# Processed batch 361/844
# Processed batch 362/844
# Processed batch 363/844
# Processed batch 364/844
# Processed batch 365/844
# Processed batch 366/844
# Processed batch 367/844
# Processed batch 368/844
# Processed batch 369/844
# Processed batch 370/844
# Processed batch 371/844
# Processed batch 372/844
# Processed batch 373/844
# Processed batch 374/844
# Processed batch 375/844
# Processed batch 376/844
# Processed batch 377/844
# Processed batch 378/844
# Processed batch 379/844
# Processed batch 380/844
# Processed batch 381/844
# Processed batch 382/844
# Processed batch 383/844
# Processed batch 384/844
# Processed batch 385/844
# Processed batch 386/844
# Processed batch 387/844
# Processed batch 388/844
# Processed batch 389/844
# Processed batch 390/844
# Processed batch 391/844
# Processed batch 392/844
# Processed batch 393/844
# Processed batch 394/844
# Processed batch 395/844
# Processed batch 396/844
# Processed batch 397/844
# Processed batch 398/844
# Processed batch 399/844
# Processed batch 400/844
# Processed batch 401/844
# Processed batch 402/844
# Processed batch 403/844
# Processed batch 404/844
# Processed batch 405/844
# Processed batch 406/844
# Processed batch 407/844
# Processed batch 408/844
# Processed batch 409/844
# Processed batch 410/844
# Processed batch 411/844
# Processed batch 412/844
# Processed batch 413/844
# Processed batch 414/844
# Processed batch 415/844
# Processed batch 416/844
# Processed batch 417/844
# Processed batch 418/844
# Processed batch 419/844
# Processed batch 420/844
# Processed batch 421/844
# Processed batch 422/844
# Processed batch 423/844
# Processed batch 424/844
# Processed batch 425/844
# Processed batch 426/844
# Processed batch 427/844
# Processed batch 428/844
# Processed batch 429/844
# Processed batch 430/844
# Processed batch 431/844
# Processed batch 432/844
# Processed batch 433/844
# Processed batch 434/844
# Processed batch 435/844
# Processed batch 436/844
# Processed batch 437/844
# Processed batch 438/844
# Processed batch 439/844
# Processed batch 440/844
# Processed batch 441/844
# Processed batch 442/844
# Processed batch 443/844
# Processed batch 444/844
# Processed batch 445/844
# Processed batch 446/844
# Processed batch 447/844
# Processed batch 448/844
# Processed batch 449/844
# Processed batch 450/844
# Processed batch 451/844
# Processed batch 452/844
# Processed batch 453/844
# Processed batch 454/844
# Processed batch 455/844
# Processed batch 456/844
# Processed batch 457/844
# Processed batch 458/844
# Processed batch 459/844
# Processed batch 460/844
# Processed batch 461/844
# Processed batch 462/844
# Processed batch 463/844
# Processed batch 464/844
# Processed batch 465/844
# Processed batch 466/844
# Processed batch 467/844
# Processed batch 468/844
# Processed batch 469/844
# Processed batch 470/844
# Processed batch 471/844
# Processed batch 472/844
# Processed batch 473/844
# Processed batch 474/844
# Processed batch 475/844
# Processed batch 476/844
# Processed batch 477/844
# Processed batch 478/844
# Processed batch 479/844
# Processed batch 480/844
# Processed batch 481/844
# Processed batch 482/844
# Processed batch 483/844
# Processed batch 484/844
# Processed batch 485/844
# Processed batch 486/844
# Processed batch 487/844
# Processed batch 488/844
# Processed batch 489/844
# Processed batch 490/844
# Processed batch 491/844
# Processed batch 492/844
# Processed batch 493/844
# Processed batch 494/844
# Processed batch 495/844
# Processed batch 496/844
# Processed batch 497/844
# Processed batch 498/844
# Processed batch 499/844
# Processed batch 500/844
# Processed batch 501/844
# Processed batch 502/844
# Processed batch 503/844
# Processed batch 504/844
# Processed batch 505/844
# Processed batch 506/844
# Processed batch 507/844
# Processed batch 508/844
# Processed batch 509/844
# Processed batch 510/844
# Processed batch 511/844
# Processed batch 512/844
# Processed batch 513/844
# Processed batch 514/844
# Processed batch 515/844
# Processed batch 516/844
# Processed batch 517/844
# Processed batch 518/844
# Processed batch 519/844
# Processed batch 520/844
# Processed batch 521/844
# Processed batch 522/844
# Processed batch 523/844
# Processed batch 524/844
# Processed batch 525/844
# Processed batch 526/844
# Processed batch 527/844
# Processed batch 528/844
# Processed batch 529/844
# Processed batch 530/844
# Processed batch 531/844
# Processed batch 532/844
# Processed batch 533/844
# Processed batch 534/844
# Processed batch 535/844
# Processed batch 536/844
# Processed batch 537/844
# Processed batch 538/844
# Processed batch 539/844
# Processed batch 540/844
# Processed batch 541/844
# Processed batch 542/844
# Processed batch 543/844
# Processed batch 544/844
# Processed batch 545/844
# Processed batch 546/844
# Processed batch 547/844
# Processed batch 548/844
# Processed batch 549/844
# Processed batch 550/844
# Processed batch 551/844
# Processed batch 552/844
# Processed batch 553/844
# Processed batch 554/844
# Processed batch 555/844
# Processed batch 556/844
# Processed batch 557/844
# Processed batch 558/844
# Processed batch 559/844
# Processed batch 560/844
# Processed batch 561/844
# Processed batch 562/844
# Processed batch 563/844
# Processed batch 564/844
# Processed batch 565/844
# Processed batch 566/844
# Processed batch 567/844
# Processed batch 568/844
# Processed batch 569/844
# Processed batch 570/844
# Processed batch 571/844
# Processed batch 572/844
# Processed batch 573/844
# Processed batch 574/844
# Processed batch 575/844
# Processed batch 576/844
# Processed batch 577/844
# Processed batch 578/844
# Processed batch 579/844
# Processed batch 580/844
# Processed batch 581/844
# Processed batch 582/844
# Processed batch 583/844
# Processed batch 584/844
# Processed batch 585/844
# Processed batch 586/844
# Processed batch 587/844
# Processed batch 588/844
# Processed batch 589/844
# Processed batch 590/844
# Processed batch 591/844
# Processed batch 592/844
# Processed batch 593/844
# Processed batch 594/844
# Processed batch 595/844
# Processed batch 596/844
# Processed batch 597/844
# Processed batch 598/844
# Processed batch 599/844
# Processed batch 600/844
# Processed batch 601/844
# Processed batch 602/844
# Processed batch 603/844
# Processed batch 604/844
# Processed batch 605/844
# Processed batch 606/844
# Processed batch 607/844
# Processed batch 608/844
# Processed batch 609/844
# Processed batch 610/844
# Processed batch 611/844
# Processed batch 612/844
# Processed batch 613/844
# Processed batch 614/844
# Processed batch 615/844
# Processed batch 616/844
# Processed batch 617/844
# Processed batch 618/844
# Processed batch 619/844
# Processed batch 620/844
# Processed batch 621/844
# Processed batch 622/844
# Processed batch 623/844
# Processed batch 624/844
# Processed batch 625/844
# Processed batch 626/844
# Processed batch 627/844
# Processed batch 628/844
# Processed batch 629/844
# Processed batch 630/844
# Processed batch 631/844
# Processed batch 632/844
# Processed batch 633/844
# Processed batch 634/844
# Processed batch 635/844
# Processed batch 636/844
# Processed batch 637/844
# Processed batch 638/844
# Processed batch 639/844
# Processed batch 640/844
# Processed batch 641/844
# Processed batch 642/844
# Processed batch 643/844
# Processed batch 644/844
# Processed batch 645/844
# Processed batch 646/844
# Processed batch 647/844
# Processed batch 648/844
# Processed batch 649/844
# Processed batch 650/844
# Processed batch 651/844
# Processed batch 652/844
# Processed batch 653/844
# Processed batch 654/844
# Processed batch 655/844
# Processed batch 656/844
# Processed batch 657/844
# Processed batch 658/844
# Processed batch 659/844
# Processed batch 660/844
# Processed batch 661/844
# Processed batch 662/844
# Processed batch 663/844
# Processed batch 664/844
# Processed batch 665/844
# Processed batch 666/844
# Processed batch 667/844
# Processed batch 668/844
# Processed batch 669/844
# Processed batch 670/844
# Processed batch 671/844
# Processed batch 672/844
# Processed batch 673/844
# Processed batch 674/844
# Processed batch 675/844
# Processed batch 676/844
# Processed batch 677/844
# Processed batch 678/844
# Processed batch 679/844
# Processed batch 680/844
# Processed batch 681/844
# Processed batch 682/844
# Processed batch 683/844
# Processed batch 684/844
# Processed batch 685/844
# Processed batch 686/844
# Processed batch 687/844
# Processed batch 688/844
# Processed batch 689/844
# Processed batch 690/844
# Processed batch 691/844
# Processed batch 692/844
# Processed batch 693/844
# Processed batch 694/844
# Processed batch 695/844
# Processed batch 696/844
# Processed batch 697/844
# Processed batch 698/844
# Processed batch 699/844
# Processed batch 700/844
# Processed batch 701/844
# Processed batch 702/844
# Processed batch 703/844
# Processed batch 704/844
# Processed batch 705/844
# Processed batch 706/844
# Processed batch 707/844
# Processed batch 708/844
# Processed batch 709/844
# Processed batch 710/844
# Processed batch 711/844
# Processed batch 712/844
# Processed batch 713/844
# Processed batch 714/844
# Processed batch 715/844
# Processed batch 716/844
# Processed batch 717/844
# Processed batch 718/844
# Processed batch 719/844
# Processed batch 720/844
# Processed batch 721/844
# Processed batch 722/844
# Processed batch 723/844
# Processed batch 724/844
# Processed batch 725/844
# Processed batch 726/844
# Processed batch 727/844
# Processed batch 728/844
# Processed batch 729/844
# Processed batch 730/844
# Processed batch 731/844
# Processed batch 732/844
# Processed batch 733/844
# Processed batch 734/844
# Processed batch 735/844
# Processed batch 736/844
# Processed batch 737/844
# Processed batch 738/844
# Processed batch 739/844
# Processed batch 740/844
# Processed batch 741/844
# Processed batch 742/844
# Processed batch 743/844
# Processed batch 744/844
# Processed batch 745/844
# Processed batch 746/844
# Processed batch 747/844
# Processed batch 748/844
# Processed batch 749/844
# Processed batch 750/844
# Processed batch 751/844
# Processed batch 752/844
# Processed batch 753/844
# Processed batch 754/844
# Processed batch 755/844
# Processed batch 756/844
# Processed batch 757/844
# Processed batch 758/844
# Processed batch 759/844
# Processed batch 760/844
# Processed batch 761/844
# Processed batch 762/844
# Processed batch 763/844
# Processed batch 764/844
# Processed batch 765/844
# Processed batch 766/844
# Processed batch 767/844
# Processed batch 768/844
# Processed batch 769/844
# Processed batch 770/844
# Processed batch 771/844
# Processed batch 772/844
# Processed batch 773/844
# Processed batch 774/844
# Processed batch 775/844
# Processed batch 776/844
# Processed batch 777/844
# Processed batch 778/844
# Processed batch 779/844
# Processed batch 780/844
# Processed batch 781/844
# Processed batch 782/844
# Processed batch 783/844
# Processed batch 784/844
# Processed batch 785/844
# Processed batch 786/844
# Processed batch 787/844
# Processed batch 788/844
# Processed batch 789/844
# Processed batch 790/844
# Processed batch 791/844
# Processed batch 792/844
# Processed batch 793/844
# Processed batch 794/844
# Processed batch 795/844
# Processed batch 796/844
# Processed batch 797/844
# Processed batch 798/844
# Processed batch 799/844
# Processed batch 800/844
# Processed batch 801/844
# Processed batch 802/844
# Processed batch 803/844
# Processed batch 804/844
# Processed batch 805/844
# Processed batch 806/844
# Processed batch 807/844
# Processed batch 808/844
# Processed batch 809/844
# Processed batch 810/844
# Processed batch 811/844
# Processed batch 812/844
# Processed batch 813/844
# Processed batch 814/844
# Processed batch 815/844
# Processed batch 816/844
# Processed batch 817/844
# Processed batch 818/844
# Processed batch 819/844
# Processed batch 820/844
# Processed batch 821/844
# Processed batch 822/844
# Processed batch 823/844
# Processed batch 824/844
# Processed batch 825/844
# Processed batch 826/844
# Processed batch 827/844
# Processed batch 828/844
# Processed batch 829/844
# Processed batch 830/844
# Processed batch 831/844
# Processed batch 832/844
# Processed batch 833/844
# Processed batch 834/844
# Processed batch 835/844
# Processed batch 836/844
# Processed batch 837/844
# Processed batch 838/844
# Processed batch 839/844
# Processed batch 840/844
# Processed batch 841/844
# Processed batch 842/844
# Processed batch 843/844
# Processed batch 844/844
# {76: 69, 0: 25327, 2: 510, 1: 565, 251: 555, 96: 76, 253: 1636, 71: 53, 124: 63, 179: 69, 129: 42, 243: 223, 247: 279, 11: 213, 249: 321, 109: 61, 255: 258, 225: 89, 67: 67, 220: 98, 216: 85, 7: 262, 133: 64, 206: 90, 18: 115, 92: 68, 170: 57, 74: 82, 182: 65, 227: 99, 41: 81, 139: 62, 37: 121, 252: 1108, 242: 195, 150: 66, 132: 50, 95: 86, 93: 72, 21: 138, 107: 64, 173: 69, 248: 291, 234: 95, 166: 74, 119: 53, 160: 63, 39: 99, 245: 244, 121: 53, 117: 47, 5: 285, 6: 247, 241: 171, 72: 86, 193: 79, 229: 111, 228: 91, 203: 91, 164: 60, 178: 66, 205: 84, 53: 113, 230: 95, 80: 71, 61: 60, 189: 64, 174: 65, 90: 63, 159: 70, 250: 421, 168: 61, 246: 251, 32: 95, 51: 65, 45: 74, 141: 61, 8: 192, 196: 71, 239: 140, 254: 710, 54: 72, 14: 178, 68: 106, 28: 114, 123: 53, 16: 166, 147: 76, 181: 50, 222: 87, 217: 105, 13: 156, 236: 148, 25: 124, 148: 55, 84: 68, 156: 57, 198: 74, 52: 84, 82: 88, 43: 83, 127: 62, 89: 69, 231: 123, 97: 60, 12: 184, 46: 99, 19: 125, 218: 106, 223: 104, 3: 359, 81: 85, 184: 76, 212: 74, 190: 73, 36: 87, 42: 87, 4: 365, 202: 81, 200: 72, 197: 67, 98: 69, 101: 69, 116: 68, 59: 71, 17: 116, 221: 93, 237: 116, 112: 67, 23: 105, 165: 65, 161: 75, 238: 134, 10: 183, 118: 65, 69: 98, 149: 62, 155: 61, 213: 100, 235: 95, 63: 75, 35: 120, 158: 73, 232: 103, 57: 74, 143: 81, 15: 135, 140: 63, 244: 203, 66: 83, 58: 76, 30: 109, 22: 120, 91: 75, 152: 72, 136: 67, 20: 110, 26: 158, 126: 68, 163: 58, 33: 93, 192: 63, 219: 108, 56: 80, 145: 69, 138: 71, 48: 71, 233: 123, 209: 88, 162: 64, 142: 78, 105: 75, 103: 72, 9: 184, 144: 53, 226: 87, 180: 64, 111: 71, 38: 101, 50: 100, 77: 89, 167: 62, 31: 88, 47: 108, 125: 58, 185: 57, 176: 60, 85: 62, 114: 70, 49: 87, 40: 83, 65: 58, 208: 85, 201: 66, 175: 72, 224: 106, 79: 51, 73: 75, 29: 96, 100: 65, 88: 72, 135: 63, 187: 63, 183: 64, 70: 73, 151: 60, 204: 90, 211: 95, 240: 143, 194: 78, 55: 63, 207: 71, 24: 102, 134: 65, 169: 70, 210: 82, 157: 60, 62: 60, 87: 55, 64: 66, 195: 74, 214: 68, 34: 100, 94: 45, 122: 54, 137: 64, 102: 72, 146: 81, 99: 70, 110: 72, 153: 69, 191: 65, 154: 71, 104: 60, 120: 57, 128: 53, 188: 72, 78: 87, 215: 93, 172: 73, 44: 86, 86: 90, 177: 70, 83: 80, 75: 74, 113: 62, 106: 61, 115: 59, 186: 56, 199: 69, 130: 66, 131: 69, 108: 53, 60: 95, 27: 77, 171: 83}

# %%
import pandas as pd

def aggregate_grayscale_frequencies(pixel_freq):
    """
    Aggregate grayscale frequencies from pixel frequency data.

    Args:
        pixel_freq (dict): Dictionary of pixel frequencies with coordinates as keys
                           and grayscale intensity counts as values.

    Returns:
        pd.DataFrame: DataFrame containing aggregated frequencies for each pixel.
    """
    data = []

    # Convert pixel frequency data into a flat list for DataFrame
    for (i, j), gray_counts in pixel_freq.items():
        for gray_value, count in gray_counts.items():
            data.append((i, j, gray_value, count))

    # Create a DataFrame
    df = pd.DataFrame(data, columns=['x', 'y', 'gray_value', 'frequency'])

    # Group by pixel coordinates (x, y) and aggregate frequencies
    result = df.groupby(['x', 'y', 'gray_value'])['frequency'].sum().reset_index()

    return result

# %%
# Assuming `pixel_freq` is the output from `calculate_pixel_frequencies_from_loader`
result_df = aggregate_grayscale_frequencies(pixel_freq)

# Display the result
print(result_df)
# Out:
#         x    y  gray_value  frequency
# 0      83   79           0      19183
# 1      83   79           1        705
# 2      83   79           2        558
# 3      83   79           3        417
# 4      83   79           4        418
# ...   ...  ...         ...        ...
# 5627  171  158         251        209
# 5628  171  158         252        462
# 5629  171  158         253        557
# 5630  171  158         254        201
# 5631  171  158         255        105
#
# [5632 rows x 4 columns]

# %%
def analyze_max_x_for_epsilon(df, t, epsilon):
    """
    Analyze and compute the maximum x for epsilon for each pixel in the DataFrame.

    Args:
        df (pd.DataFrame): DataFrame containing pixel data with columns 'x', 'y', 'gray_value', 'frequency'.
        t (int): Threshold value for frequency adjustment.
        epsilon (float): Epsilon value to determine maximum x.

    Returns:
        pd.DataFrame: DataFrame containing 'x', 'y', 'gray_value', and 'max_x'.
    """
    def max_x_for_epsilon(freq, t, epsilon):
        """
        Compute max_x based on binomial probability constraint.
        """
        remaining_count = int(freq - t)
        if remaining_count <= 0:
            return 0
        
        for x in range(remaining_count + 1):
            # Compute probability using Binomial CDF
            probability = binom.cdf(x, freq, 0.5)  # Assuming uniform probability of success (p=0.5)
            if probability >= epsilon:
                return x
        return remaining_count  # If no value satisfies the condition, return max possible x

    # Apply function to the DataFrame
    df['max_x'] = df.apply(lambda row: max_x_for_epsilon(row['frequency'], t, epsilon), axis=1)

    return df[['x', 'y', 'gray_value', 'max_x']]

# %%
results_df = analyze_max_x_for_epsilon(result_df, t=2, epsilon=2)
maxValues = results_df.max()
print(maxValues)
# Out:
# x               171
# y               158
# gray_value      255
# max_x         34081
# dtype: int64

# %%
import random
import pickle
import pandas as pd

def sample_grayscale_values(pixel_freq, pixel_coords, results_df, original_df, save_path=None):
    """
    Sample grayscale values based on max_x for each pixel coordinate and optionally save them.

    Args:
        pixel_freq (dict): Dictionary of pixel frequencies with coordinates as keys
                           and grayscale frequency counts as values.
        pixel_coords (list of tuples): List of pixel coordinates to evaluate.
        results_df (pd.DataFrame): DataFrame containing 'x', 'y', 'gray_value', and 'max_x'.
        original_df (pd.DataFrame): Original DataFrame containing pixel grayscale and frequency data.
        save_path (str, optional): Path to save the sampled grayscale values. If provided, saves the result.

    Returns:
        dict: Dictionary of sampled grayscale values for each coordinate.
    """
    # Initialize dictionary to store sampled grayscale values
    sampled_grayscale_values = {coord: {} for coord in pixel_coords}

    # Iterate through the pixel coordinates
    for (i, j) in pixel_coords:
        # Filter the results DataFrame for the current coordinate
        coord_df = results_df[(results_df['x'] == i) & (results_df['y'] == j)]

        # Iterate through the rows for this coordinate
        for _, row in coord_df.iterrows():
            gray_value, max_x = int(round(row['gray_value'])), int(row['max_x'])

            # Filter the original DataFrame for matching grayscale and pixel coordinates
            original_coord_df = original_df[
                (original_df['x'] == i) & 
                (original_df['y'] == j) & 
                (original_df['gray_value'].round().astype(int) == gray_value)
            ]

            # Extract grayscale values from pixel_freq for the matching coordinate
            grayscale_values = []
            for _, orig_row in original_coord_df.iterrows():
                intensity = int(round(orig_row['gray_value']))
                if intensity in pixel_freq[(i, j)]:
                    grayscale_values.extend([intensity] * pixel_freq[(i, j)][intensity])  # Replicate values by frequency

            # Sample up to max_x grayscale values, ensuring no error if fewer values exist
            sampled_grayscale_values[(i, j)][gray_value] = random.sample(grayscale_values, min(len(grayscale_values), max_x)) if grayscale_values else []

    # Save the sampled grayscale values if a save path is provided
    if save_path:
        with open(save_path, 'wb') as f:
            pickle.dump(sampled_grayscale_values, f)
        print(f"Sampled grayscale values saved to {save_path}")

    return sampled_grayscale_values

# %%
'''import time

start_time = time.time()

sampled_values = sample_grayscale_values(pixel_freq, top_22_coords, results_df, result_df, save_path="/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/Sampled_Values/Mni/t2e2_mni.pkl")

end_time = time.time()

print(f"Execution time: {end_time - start_time:.2f} seconds")'''
# Out:
# 'import time\n\nstart_time = time.time()\n\nsampled_values = sample_grayscale_values(pixel_freq, top_22_coords, results_df, result_df, save_path="/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/Sampled_Values/Mni/t2e2_mni.pkl")\n\nend_time = time.time()\n\nprint(f"Execution time: {end_time - start_time:.2f} seconds")'

# %%
import pickle

# Load the sampled RGB values in one line
sampled_values = pickle.load(open("/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/Sampled_Values/Mni/t2e4_mni.pkl", "rb"))
print("Sampled RGB values loaded successfully!")
# Out:
# Sampled RGB values loaded successfully!

# %%
import os
import torch

def apply_samples_to_dataset(data_loader, sampled_gray_values, pixel_coords, output_path):
    """
    Apply sampled grayscale values to MNIST images and save the dataset with labels.

    Args:
        data_loader (DataLoader): DataLoader containing the MNIST images to modify.
        sampled_gray_values (dict): Dictionary of sampled grayscale values for each pixel.
        pixel_coords (list of tuples): List of pixel coordinates to modify.
        output_path (str): Path to the file where the modified dataset will be saved.
    """
    modified_images = []
    labels = []

    # Process each image in the data loader
    for batch_idx, (images, batch_labels) in enumerate(data_loader):
        images = images.clone()  # Clone to avoid modifying the original data
        batch_size = images.size(0)

        for img_idx in range(batch_size):
            image_tensor = images[img_idx]  # Shape: (1, H, W)
            img_array = image_tensor.squeeze(0).cpu().numpy()  # Convert to (H, W) for easy manipulation

            height, width = img_array.shape
            for (x, y) in pixel_coords:
                if 0 <= x < height and 0 <= y < width:
                    if (x, y) in sampled_gray_values:
                        gray_levels = sampled_gray_values[(x, y)]
                        found = False
                        for gray_value in gray_levels:
                            if img_idx in gray_levels[gray_value]:  # Check if this image index has a sample
                                img_array[x, y] = gray_value / 255.0  # Normalize grayscale
                                found = True
                                break
                        if not found:
                            img_array[x, y] = 0.0  # Set to black if no matching sample
                    else:
                        img_array[x, y] = 0.0  # Set to black for unmatched coordinates

            # Convert modified array back to tensor
            modified_tensor = torch.tensor(img_array, dtype=torch.float32).unsqueeze(0)  # Shape: (1, H, W)

            # Add modified tensor and corresponding label to the dataset
            modified_images.append(modified_tensor)
            labels.append(batch_labels[img_idx].item())

        print(f"Processed batch {batch_idx + 1}/{len(data_loader)}")

    # Save the modified dataset
    dataset = {
        "images": torch.stack(modified_images),
        "labels": torch.tensor(labels)
    }
    torch.save(dataset, output_path)
    print(f"Modified MNIST dataset saved to {output_path}")

# %%
output_dir = "/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE4.pt"
apply_samples_to_dataset(train_loader, sampled_values, top_22_coords, output_dir)
# Out:
# Processed batch 1/844
# Processed batch 2/844
# Processed batch 3/844
# Processed batch 4/844
# Processed batch 5/844
# Processed batch 6/844
# Processed batch 7/844
# Processed batch 8/844
# Processed batch 9/844
# Processed batch 10/844
# Processed batch 11/844
# Processed batch 12/844
# Processed batch 13/844
# Processed batch 14/844
# Processed batch 15/844
# Processed batch 16/844
# Processed batch 17/844
# Processed batch 18/844
# Processed batch 19/844
# Processed batch 20/844
# Processed batch 21/844
# Processed batch 22/844
# Processed batch 23/844
# Processed batch 24/844
# Processed batch 25/844
# Processed batch 26/844
# Processed batch 27/844
# Processed batch 28/844
# Processed batch 29/844
# Processed batch 30/844
# Processed batch 31/844
# Processed batch 32/844
# Processed batch 33/844
# Processed batch 34/844
# Processed batch 35/844
# Processed batch 36/844
# Processed batch 37/844
# Processed batch 38/844
# Processed batch 39/844
# Processed batch 40/844
# Processed batch 41/844
# Processed batch 42/844
# Processed batch 43/844
# Processed batch 44/844
# Processed batch 45/844
# Processed batch 46/844
# Processed batch 47/844
# Processed batch 48/844
# Processed batch 49/844
# Processed batch 50/844
# Processed batch 51/844
# Processed batch 52/844
# Processed batch 53/844
# Processed batch 54/844
# Processed batch 55/844
# Processed batch 56/844
# Processed batch 57/844
# Processed batch 58/844
# Processed batch 59/844
# Processed batch 60/844
# Processed batch 61/844
# Processed batch 62/844
# Processed batch 63/844
# Processed batch 64/844
# Processed batch 65/844
# Processed batch 66/844
# Processed batch 67/844
# Processed batch 68/844
# Processed batch 69/844
# Processed batch 70/844
# Processed batch 71/844
# Processed batch 72/844
# Processed batch 73/844
# Processed batch 74/844
# Processed batch 75/844
# Processed batch 76/844
# Processed batch 77/844
# Processed batch 78/844
# Processed batch 79/844
# Processed batch 80/844
# Processed batch 81/844
# Processed batch 82/844
# Processed batch 83/844
# Processed batch 84/844
# Processed batch 85/844
# Processed batch 86/844
# Processed batch 87/844
# Processed batch 88/844
# Processed batch 89/844
# Processed batch 90/844
# Processed batch 91/844
# Processed batch 92/844
# Processed batch 93/844
# Processed batch 94/844
# Processed batch 95/844
# Processed batch 96/844
# Processed batch 97/844
# Processed batch 98/844
# Processed batch 99/844
# Processed batch 100/844
# Processed batch 101/844
# Processed batch 102/844
# Processed batch 103/844
# Processed batch 104/844
# Processed batch 105/844
# Processed batch 106/844
# Processed batch 107/844
# Processed batch 108/844
# Processed batch 109/844
# Processed batch 110/844
# Processed batch 111/844
# Processed batch 112/844
# Processed batch 113/844
# Processed batch 114/844
# Processed batch 115/844
# Processed batch 116/844
# Processed batch 117/844
# Processed batch 118/844
# Processed batch 119/844
# Processed batch 120/844
# Processed batch 121/844
# Processed batch 122/844
# Processed batch 123/844
# Processed batch 124/844
# Processed batch 125/844
# Processed batch 126/844
# Processed batch 127/844
# Processed batch 128/844
# Processed batch 129/844
# Processed batch 130/844
# Processed batch 131/844
# Processed batch 132/844
# Processed batch 133/844
# Processed batch 134/844
# Processed batch 135/844
# Processed batch 136/844
# Processed batch 137/844
# Processed batch 138/844
# Processed batch 139/844
# Processed batch 140/844
# Processed batch 141/844
# Processed batch 142/844
# Processed batch 143/844
# Processed batch 144/844
# Processed batch 145/844
# Processed batch 146/844
# Processed batch 147/844
# Processed batch 148/844
# Processed batch 149/844
# Processed batch 150/844
# Processed batch 151/844
# Processed batch 152/844
# Processed batch 153/844
# Processed batch 154/844
# Processed batch 155/844
# Processed batch 156/844
# Processed batch 157/844
# Processed batch 158/844
# Processed batch 159/844
# Processed batch 160/844
# Processed batch 161/844
# Processed batch 162/844
# Processed batch 163/844
# Processed batch 164/844
# Processed batch 165/844
# Processed batch 166/844
# Processed batch 167/844
# Processed batch 168/844
# Processed batch 169/844
# Processed batch 170/844
# Processed batch 171/844
# Processed batch 172/844
# Processed batch 173/844
# Processed batch 174/844
# Processed batch 175/844
# Processed batch 176/844
# Processed batch 177/844
# Processed batch 178/844
# Processed batch 179/844
# Processed batch 180/844
# Processed batch 181/844
# Processed batch 182/844
# Processed batch 183/844
# Processed batch 184/844
# Processed batch 185/844
# Processed batch 186/844
# Processed batch 187/844
# Processed batch 188/844
# Processed batch 189/844
# Processed batch 190/844
# Processed batch 191/844
# Processed batch 192/844
# Processed batch 193/844
# Processed batch 194/844
# Processed batch 195/844
# Processed batch 196/844
# Processed batch 197/844
# Processed batch 198/844
# Processed batch 199/844
# Processed batch 200/844
# Processed batch 201/844
# Processed batch 202/844
# Processed batch 203/844
# Processed batch 204/844
# Processed batch 205/844
# Processed batch 206/844
# Processed batch 207/844
# Processed batch 208/844
# Processed batch 209/844
# Processed batch 210/844
# Processed batch 211/844
# Processed batch 212/844
# Processed batch 213/844
# Processed batch 214/844
# Processed batch 215/844
# Processed batch 216/844
# Processed batch 217/844
# Processed batch 218/844
# Processed batch 219/844
# Processed batch 220/844
# Processed batch 221/844
# Processed batch 222/844
# Processed batch 223/844
# Processed batch 224/844
# Processed batch 225/844
# Processed batch 226/844
# Processed batch 227/844
# Processed batch 228/844
# Processed batch 229/844
# Processed batch 230/844
# Processed batch 231/844
# Processed batch 232/844
# Processed batch 233/844
# Processed batch 234/844
# Processed batch 235/844
# Processed batch 236/844
# Processed batch 237/844
# Processed batch 238/844
# Processed batch 239/844
# Processed batch 240/844
# Processed batch 241/844
# Processed batch 242/844
# Processed batch 243/844
# Processed batch 244/844
# Processed batch 245/844
# Processed batch 246/844
# Processed batch 247/844
# Processed batch 248/844
# Processed batch 249/844
# Processed batch 250/844
# Processed batch 251/844
# Processed batch 252/844
# Processed batch 253/844
# Processed batch 254/844
# Processed batch 255/844
# Processed batch 256/844
# Processed batch 257/844
# Processed batch 258/844
# Processed batch 259/844
# Processed batch 260/844
# Processed batch 261/844
# Processed batch 262/844
# Processed batch 263/844
# Processed batch 264/844
# Processed batch 265/844
# Processed batch 266/844
# Processed batch 267/844
# Processed batch 268/844
# Processed batch 269/844
# Processed batch 270/844
# Processed batch 271/844
# Processed batch 272/844
# Processed batch 273/844
# Processed batch 274/844
# Processed batch 275/844
# Processed batch 276/844
# Processed batch 277/844
# Processed batch 278/844
# Processed batch 279/844
# Processed batch 280/844
# Processed batch 281/844
# Processed batch 282/844
# Processed batch 283/844
# Processed batch 284/844
# Processed batch 285/844
# Processed batch 286/844
# Processed batch 287/844
# Processed batch 288/844
# Processed batch 289/844
# Processed batch 290/844
# Processed batch 291/844
# Processed batch 292/844
# Processed batch 293/844
# Processed batch 294/844
# Processed batch 295/844
# Processed batch 296/844
# Processed batch 297/844
# Processed batch 298/844
# Processed batch 299/844
# Processed batch 300/844
# Processed batch 301/844
# Processed batch 302/844
# Processed batch 303/844
# Processed batch 304/844
# Processed batch 305/844
# Processed batch 306/844
# Processed batch 307/844
# Processed batch 308/844
# Processed batch 309/844
# Processed batch 310/844
# Processed batch 311/844
# Processed batch 312/844
# Processed batch 313/844
# Processed batch 314/844
# Processed batch 315/844
# Processed batch 316/844
# Processed batch 317/844
# Processed batch 318/844
# Processed batch 319/844
# Processed batch 320/844
# Processed batch 321/844
# Processed batch 322/844
# Processed batch 323/844
# Processed batch 324/844
# Processed batch 325/844
# Processed batch 326/844
# Processed batch 327/844
# Processed batch 328/844
# Processed batch 329/844
# Processed batch 330/844
# Processed batch 331/844
# Processed batch 332/844
# Processed batch 333/844
# Processed batch 334/844
# Processed batch 335/844
# Processed batch 336/844
# Processed batch 337/844
# Processed batch 338/844
# Processed batch 339/844
# Processed batch 340/844
# Processed batch 341/844
# Processed batch 342/844
# Processed batch 343/844
# Processed batch 344/844
# Processed batch 345/844
# Processed batch 346/844
# Processed batch 347/844
# Processed batch 348/844
# Processed batch 349/844
# Processed batch 350/844
# Processed batch 351/844
# Processed batch 352/844
# Processed batch 353/844
# Processed batch 354/844
# Processed batch 355/844
# Processed batch 356/844
# Processed batch 357/844
# Processed batch 358/844
# Processed batch 359/844
# Processed batch 360/844
# Processed batch 361/844
# Processed batch 362/844
# Processed batch 363/844
# Processed batch 364/844
# Processed batch 365/844
# Processed batch 366/844
# Processed batch 367/844
# Processed batch 368/844
# Processed batch 369/844
# Processed batch 370/844
# Processed batch 371/844
# Processed batch 372/844
# Processed batch 373/844
# Processed batch 374/844
# Processed batch 375/844
# Processed batch 376/844
# Processed batch 377/844
# Processed batch 378/844
# Processed batch 379/844
# Processed batch 380/844
# Processed batch 381/844
# Processed batch 382/844
# Processed batch 383/844
# Processed batch 384/844
# Processed batch 385/844
# Processed batch 386/844
# Processed batch 387/844
# Processed batch 388/844
# Processed batch 389/844
# Processed batch 390/844
# Processed batch 391/844
# Processed batch 392/844
# Processed batch 393/844
# Processed batch 394/844
# Processed batch 395/844
# Processed batch 396/844
# Processed batch 397/844
# Processed batch 398/844
# Processed batch 399/844
# Processed batch 400/844
# Processed batch 401/844
# Processed batch 402/844
# Processed batch 403/844
# Processed batch 404/844
# Processed batch 405/844
# Processed batch 406/844
# Processed batch 407/844
# Processed batch 408/844
# Processed batch 409/844
# Processed batch 410/844
# Processed batch 411/844
# Processed batch 412/844
# Processed batch 413/844
# Processed batch 414/844
# Processed batch 415/844
# Processed batch 416/844
# Processed batch 417/844
# Processed batch 418/844
# Processed batch 419/844
# Processed batch 420/844
# Processed batch 421/844
# Processed batch 422/844
# Processed batch 423/844
# Processed batch 424/844
# Processed batch 425/844
# Processed batch 426/844
# Processed batch 427/844
# Processed batch 428/844
# Processed batch 429/844
# Processed batch 430/844
# Processed batch 431/844
# Processed batch 432/844
# Processed batch 433/844
# Processed batch 434/844
# Processed batch 435/844
# Processed batch 436/844
# Processed batch 437/844
# Processed batch 438/844
# Processed batch 439/844
# Processed batch 440/844
# Processed batch 441/844
# Processed batch 442/844
# Processed batch 443/844
# Processed batch 444/844
# Processed batch 445/844
# Processed batch 446/844
# Processed batch 447/844
# Processed batch 448/844
# Processed batch 449/844
# Processed batch 450/844
# Processed batch 451/844
# Processed batch 452/844
# Processed batch 453/844
# Processed batch 454/844
# Processed batch 455/844
# Processed batch 456/844
# Processed batch 457/844
# Processed batch 458/844
# Processed batch 459/844
# Processed batch 460/844
# Processed batch 461/844
# Processed batch 462/844
# Processed batch 463/844
# Processed batch 464/844
# Processed batch 465/844
# Processed batch 466/844
# Processed batch 467/844
# Processed batch 468/844
# Processed batch 469/844
# Processed batch 470/844
# Processed batch 471/844
# Processed batch 472/844
# Processed batch 473/844
# Processed batch 474/844
# Processed batch 475/844
# Processed batch 476/844
# Processed batch 477/844
# Processed batch 478/844
# Processed batch 479/844
# Processed batch 480/844
# Processed batch 481/844
# Processed batch 482/844
# Processed batch 483/844
# Processed batch 484/844
# Processed batch 485/844
# Processed batch 486/844
# Processed batch 487/844
# Processed batch 488/844
# Processed batch 489/844
# Processed batch 490/844
# Processed batch 491/844
# Processed batch 492/844
# Processed batch 493/844
# Processed batch 494/844
# Processed batch 495/844
# Processed batch 496/844
# Processed batch 497/844
# Processed batch 498/844
# Processed batch 499/844
# Processed batch 500/844
# Processed batch 501/844
# Processed batch 502/844
# Processed batch 503/844
# Processed batch 504/844
# Processed batch 505/844
# Processed batch 506/844
# Processed batch 507/844
# Processed batch 508/844
# Processed batch 509/844
# Processed batch 510/844
# Processed batch 511/844
# Processed batch 512/844
# Processed batch 513/844
# Processed batch 514/844
# Processed batch 515/844
# Processed batch 516/844
# Processed batch 517/844
# Processed batch 518/844
# Processed batch 519/844
# Processed batch 520/844
# Processed batch 521/844
# Processed batch 522/844
# Processed batch 523/844
# Processed batch 524/844
# Processed batch 525/844
# Processed batch 526/844
# Processed batch 527/844
# Processed batch 528/844
# Processed batch 529/844
# Processed batch 530/844
# Processed batch 531/844
# Processed batch 532/844
# Processed batch 533/844
# Processed batch 534/844
# Processed batch 535/844
# Processed batch 536/844
# Processed batch 537/844
# Processed batch 538/844
# Processed batch 539/844
# Processed batch 540/844
# Processed batch 541/844
# Processed batch 542/844
# Processed batch 543/844
# Processed batch 544/844
# Processed batch 545/844
# Processed batch 546/844
# Processed batch 547/844
# Processed batch 548/844
# Processed batch 549/844
# Processed batch 550/844
# Processed batch 551/844
# Processed batch 552/844
# Processed batch 553/844
# Processed batch 554/844
# Processed batch 555/844
# Processed batch 556/844
# Processed batch 557/844
# Processed batch 558/844
# Processed batch 559/844
# Processed batch 560/844
# Processed batch 561/844
# Processed batch 562/844
# Processed batch 563/844
# Processed batch 564/844
# Processed batch 565/844
# Processed batch 566/844
# Processed batch 567/844
# Processed batch 568/844
# Processed batch 569/844
# Processed batch 570/844
# Processed batch 571/844
# Processed batch 572/844
# Processed batch 573/844
# Processed batch 574/844
# Processed batch 575/844
# Processed batch 576/844
# Processed batch 577/844
# Processed batch 578/844
# Processed batch 579/844
# Processed batch 580/844
# Processed batch 581/844
# Processed batch 582/844
# Processed batch 583/844
# Processed batch 584/844
# Processed batch 585/844
# Processed batch 586/844
# Processed batch 587/844
# Processed batch 588/844
# Processed batch 589/844
# Processed batch 590/844
# Processed batch 591/844
# Processed batch 592/844
# Processed batch 593/844
# Processed batch 594/844
# Processed batch 595/844
# Processed batch 596/844
# Processed batch 597/844
# Processed batch 598/844
# Processed batch 599/844
# Processed batch 600/844
# Processed batch 601/844
# Processed batch 602/844
# Processed batch 603/844
# Processed batch 604/844
# Processed batch 605/844
# Processed batch 606/844
# Processed batch 607/844
# Processed batch 608/844
# Processed batch 609/844
# Processed batch 610/844
# Processed batch 611/844
# Processed batch 612/844
# Processed batch 613/844
# Processed batch 614/844
# Processed batch 615/844
# Processed batch 616/844
# Processed batch 617/844
# Processed batch 618/844
# Processed batch 619/844
# Processed batch 620/844
# Processed batch 621/844
# Processed batch 622/844
# Processed batch 623/844
# Processed batch 624/844
# Processed batch 625/844
# Processed batch 626/844
# Processed batch 627/844
# Processed batch 628/844
# Processed batch 629/844
# Processed batch 630/844
# Processed batch 631/844
# Processed batch 632/844
# Processed batch 633/844
# Processed batch 634/844
# Processed batch 635/844
# Processed batch 636/844
# Processed batch 637/844
# Processed batch 638/844
# Processed batch 639/844
# Processed batch 640/844
# Processed batch 641/844
# Processed batch 642/844
# Processed batch 643/844
# Processed batch 644/844
# Processed batch 645/844
# Processed batch 646/844
# Processed batch 647/844
# Processed batch 648/844
# Processed batch 649/844
# Processed batch 650/844
# Processed batch 651/844
# Processed batch 652/844
# Processed batch 653/844
# Processed batch 654/844
# Processed batch 655/844
# Processed batch 656/844
# Processed batch 657/844
# Processed batch 658/844
# Processed batch 659/844
# Processed batch 660/844
# Processed batch 661/844
# Processed batch 662/844
# Processed batch 663/844
# Processed batch 664/844
# Processed batch 665/844
# Processed batch 666/844
# Processed batch 667/844
# Processed batch 668/844
# Processed batch 669/844
# Processed batch 670/844
# Processed batch 671/844
# Processed batch 672/844
# Processed batch 673/844
# Processed batch 674/844
# Processed batch 675/844
# Processed batch 676/844
# Processed batch 677/844
# Processed batch 678/844
# Processed batch 679/844
# Processed batch 680/844
# Processed batch 681/844
# Processed batch 682/844
# Processed batch 683/844
# Processed batch 684/844
# Processed batch 685/844
# Processed batch 686/844
# Processed batch 687/844
# Processed batch 688/844
# Processed batch 689/844
# Processed batch 690/844
# Processed batch 691/844
# Processed batch 692/844
# Processed batch 693/844
# Processed batch 694/844
# Processed batch 695/844
# Processed batch 696/844
# Processed batch 697/844
# Processed batch 698/844
# Processed batch 699/844
# Processed batch 700/844
# Processed batch 701/844
# Processed batch 702/844
# Processed batch 703/844
# Processed batch 704/844
# Processed batch 705/844
# Processed batch 706/844
# Processed batch 707/844
# Processed batch 708/844
# Processed batch 709/844
# Processed batch 710/844
# Processed batch 711/844
# Processed batch 712/844
# Processed batch 713/844
# Processed batch 714/844
# Processed batch 715/844
# Processed batch 716/844
# Processed batch 717/844
# Processed batch 718/844
# Processed batch 719/844
# Processed batch 720/844
# Processed batch 721/844
# Processed batch 722/844
# Processed batch 723/844
# Processed batch 724/844
# Processed batch 725/844
# Processed batch 726/844
# Processed batch 727/844
# Processed batch 728/844
# Processed batch 729/844
# Processed batch 730/844
# Processed batch 731/844
# Processed batch 732/844
# Processed batch 733/844
# Processed batch 734/844
# Processed batch 735/844
# Processed batch 736/844
# Processed batch 737/844
# Processed batch 738/844
# Processed batch 739/844
# Processed batch 740/844
# Processed batch 741/844
# Processed batch 742/844
# Processed batch 743/844
# Processed batch 744/844
# Processed batch 745/844
# Processed batch 746/844
# Processed batch 747/844
# Processed batch 748/844
# Processed batch 749/844
# Processed batch 750/844
# Processed batch 751/844
# Processed batch 752/844
# Processed batch 753/844
# Processed batch 754/844
# Processed batch 755/844
# Processed batch 756/844
# Processed batch 757/844
# Processed batch 758/844
# Processed batch 759/844
# Processed batch 760/844
# Processed batch 761/844
# Processed batch 762/844
# Processed batch 763/844
# Processed batch 764/844
# Processed batch 765/844
# Processed batch 766/844
# Processed batch 767/844
# Processed batch 768/844
# Processed batch 769/844
# Processed batch 770/844
# Processed batch 771/844
# Processed batch 772/844
# Processed batch 773/844
# Processed batch 774/844
# Processed batch 775/844
# Processed batch 776/844
# Processed batch 777/844
# Processed batch 778/844
# Processed batch 779/844
# Processed batch 780/844
# Processed batch 781/844
# Processed batch 782/844
# Processed batch 783/844
# Processed batch 784/844
# Processed batch 785/844
# Processed batch 786/844
# Processed batch 787/844
# Processed batch 788/844
# Processed batch 789/844
# Processed batch 790/844
# Processed batch 791/844
# Processed batch 792/844
# Processed batch 793/844
# Processed batch 794/844
# Processed batch 795/844
# Processed batch 796/844
# Processed batch 797/844
# Processed batch 798/844
# Processed batch 799/844
# Processed batch 800/844
# Processed batch 801/844
# Processed batch 802/844
# Processed batch 803/844
# Processed batch 804/844
# Processed batch 805/844
# Processed batch 806/844
# Processed batch 807/844
# Processed batch 808/844
# Processed batch 809/844
# Processed batch 810/844
# Processed batch 811/844
# Processed batch 812/844
# Processed batch 813/844
# Processed batch 814/844
# Processed batch 815/844
# Processed batch 816/844
# Processed batch 817/844
# Processed batch 818/844
# Processed batch 819/844
# Processed batch 820/844
# Processed batch 821/844
# Processed batch 822/844
# Processed batch 823/844
# Processed batch 824/844
# Processed batch 825/844
# Processed batch 826/844
# Processed batch 827/844
# Processed batch 828/844
# Processed batch 829/844
# Processed batch 830/844
# Processed batch 831/844
# Processed batch 832/844
# Processed batch 833/844
# Processed batch 834/844
# Processed batch 835/844
# Processed batch 836/844
# Processed batch 837/844
# Processed batch 838/844
# Processed batch 839/844
# Processed batch 840/844
# Processed batch 841/844
# Processed batch 842/844
# Processed batch 843/844
# Processed batch 844/844
# Modified MNIST dataset saved to /home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE4.pt

# %%
import pickle

# Load the sampled RGB values in one line
sampled_values = pickle.load(open("/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/Sampled_Values/Mni/t2e5_mni.pkl", "rb"))
print("Sampled RGB values loaded successfully!")

output_dir = "/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE5.pt"
apply_samples_to_dataset(train_loader, sampled_values, top_22_coords, output_dir)
# Out:
# Sampled RGB values loaded successfully!
# Processed batch 1/844
# Processed batch 2/844
# Processed batch 3/844
# Processed batch 4/844
# Processed batch 5/844
# Processed batch 6/844
# Processed batch 7/844
# Processed batch 8/844
# Processed batch 9/844
# Processed batch 10/844
# Processed batch 11/844
# Processed batch 12/844
# Processed batch 13/844
# Processed batch 14/844
# Processed batch 15/844
# Processed batch 16/844
# Processed batch 17/844
# Processed batch 18/844
# Processed batch 19/844
# Processed batch 20/844
# Processed batch 21/844
# Processed batch 22/844
# Processed batch 23/844
# Processed batch 24/844
# Processed batch 25/844
# Processed batch 26/844
# Processed batch 27/844
# Processed batch 28/844
# Processed batch 29/844
# Processed batch 30/844
# Processed batch 31/844
# Processed batch 32/844
# Processed batch 33/844
# Processed batch 34/844
# Processed batch 35/844
# Processed batch 36/844
# Processed batch 37/844
# Processed batch 38/844
# Processed batch 39/844
# Processed batch 40/844
# Processed batch 41/844
# Processed batch 42/844
# Processed batch 43/844
# Processed batch 44/844
# Processed batch 45/844
# Processed batch 46/844
# Processed batch 47/844
# Processed batch 48/844
# Processed batch 49/844
# Processed batch 50/844
# Processed batch 51/844
# Processed batch 52/844
# Processed batch 53/844
# Processed batch 54/844
# Processed batch 55/844
# Processed batch 56/844
# Processed batch 57/844
# Processed batch 58/844
# Processed batch 59/844
# Processed batch 60/844
# Processed batch 61/844
# Processed batch 62/844
# Processed batch 63/844
# Processed batch 64/844
# Processed batch 65/844
# Processed batch 66/844
# Processed batch 67/844
# Processed batch 68/844
# Processed batch 69/844
# Processed batch 70/844
# Processed batch 71/844
# Processed batch 72/844
# Processed batch 73/844
# Processed batch 74/844
# Processed batch 75/844
# Processed batch 76/844
# Processed batch 77/844
# Processed batch 78/844
# Processed batch 79/844
# Processed batch 80/844
# Processed batch 81/844
# Processed batch 82/844
# Processed batch 83/844
# Processed batch 84/844
# Processed batch 85/844
# Processed batch 86/844
# Processed batch 87/844
# Processed batch 88/844
# Processed batch 89/844
# Processed batch 90/844
# Processed batch 91/844
# Processed batch 92/844
# Processed batch 93/844
# Processed batch 94/844
# Processed batch 95/844
# Processed batch 96/844
# Processed batch 97/844
# Processed batch 98/844
# Processed batch 99/844
# Processed batch 100/844
# Processed batch 101/844
# Processed batch 102/844
# Processed batch 103/844
# Processed batch 104/844
# Processed batch 105/844
# Processed batch 106/844
# Processed batch 107/844
# Processed batch 108/844
# Processed batch 109/844
# Processed batch 110/844
# Processed batch 111/844
# Processed batch 112/844
# Processed batch 113/844
# Processed batch 114/844
# Processed batch 115/844
# Processed batch 116/844
# Processed batch 117/844
# Processed batch 118/844
# Processed batch 119/844
# Processed batch 120/844
# Processed batch 121/844
# Processed batch 122/844
# Processed batch 123/844
# Processed batch 124/844
# Processed batch 125/844
# Processed batch 126/844
# Processed batch 127/844
# Processed batch 128/844
# Processed batch 129/844
# Processed batch 130/844
# Processed batch 131/844
# Processed batch 132/844
# Processed batch 133/844
# Processed batch 134/844
# Processed batch 135/844
# Processed batch 136/844
# Processed batch 137/844
# Processed batch 138/844
# Processed batch 139/844
# Processed batch 140/844
# Processed batch 141/844
# Processed batch 142/844
# Processed batch 143/844
# Processed batch 144/844
# Processed batch 145/844
# Processed batch 146/844
# Processed batch 147/844
# Processed batch 148/844
# Processed batch 149/844
# Processed batch 150/844
# Processed batch 151/844
# Processed batch 152/844
# Processed batch 153/844
# Processed batch 154/844
# Processed batch 155/844
# Processed batch 156/844
# Processed batch 157/844
# Processed batch 158/844
# Processed batch 159/844
# Processed batch 160/844
# Processed batch 161/844
# Processed batch 162/844
# Processed batch 163/844
# Processed batch 164/844
# Processed batch 165/844
# Processed batch 166/844
# Processed batch 167/844
# Processed batch 168/844
# Processed batch 169/844
# Processed batch 170/844
# Processed batch 171/844
# Processed batch 172/844
# Processed batch 173/844
# Processed batch 174/844
# Processed batch 175/844
# Processed batch 176/844
# Processed batch 177/844
# Processed batch 178/844
# Processed batch 179/844
# Processed batch 180/844
# Processed batch 181/844
# Processed batch 182/844
# Processed batch 183/844
# Processed batch 184/844
# Processed batch 185/844
# Processed batch 186/844
# Processed batch 187/844
# Processed batch 188/844
# Processed batch 189/844
# Processed batch 190/844
# Processed batch 191/844
# Processed batch 192/844
# Processed batch 193/844
# Processed batch 194/844
# Processed batch 195/844
# Processed batch 196/844
# Processed batch 197/844
# Processed batch 198/844
# Processed batch 199/844
# Processed batch 200/844
# Processed batch 201/844
# Processed batch 202/844
# Processed batch 203/844
# Processed batch 204/844
# Processed batch 205/844
# Processed batch 206/844
# Processed batch 207/844
# Processed batch 208/844
# Processed batch 209/844
# Processed batch 210/844
# Processed batch 211/844
# Processed batch 212/844
# Processed batch 213/844
# Processed batch 214/844
# Processed batch 215/844
# Processed batch 216/844
# Processed batch 217/844
# Processed batch 218/844
# Processed batch 219/844
# Processed batch 220/844
# Processed batch 221/844
# Processed batch 222/844
# Processed batch 223/844
# Processed batch 224/844
# Processed batch 225/844
# Processed batch 226/844
# Processed batch 227/844
# Processed batch 228/844
# Processed batch 229/844
# Processed batch 230/844
# Processed batch 231/844
# Processed batch 232/844
# Processed batch 233/844
# Processed batch 234/844
# Processed batch 235/844
# Processed batch 236/844
# Processed batch 237/844
# Processed batch 238/844
# Processed batch 239/844
# Processed batch 240/844
# Processed batch 241/844
# Processed batch 242/844
# Processed batch 243/844
# Processed batch 244/844
# Processed batch 245/844
# Processed batch 246/844
# Processed batch 247/844
# Processed batch 248/844
# Processed batch 249/844
# Processed batch 250/844
# Processed batch 251/844
# Processed batch 252/844
# Processed batch 253/844
# Processed batch 254/844
# Processed batch 255/844
# Processed batch 256/844
# Processed batch 257/844
# Processed batch 258/844
# Processed batch 259/844
# Processed batch 260/844
# Processed batch 261/844
# Processed batch 262/844
# Processed batch 263/844
# Processed batch 264/844
# Processed batch 265/844
# Processed batch 266/844
# Processed batch 267/844
# Processed batch 268/844
# Processed batch 269/844
# Processed batch 270/844
# Processed batch 271/844
# Processed batch 272/844
# Processed batch 273/844
# Processed batch 274/844
# Processed batch 275/844
# Processed batch 276/844
# Processed batch 277/844
# Processed batch 278/844
# Processed batch 279/844
# Processed batch 280/844
# Processed batch 281/844
# Processed batch 282/844
# Processed batch 283/844
# Processed batch 284/844
# Processed batch 285/844
# Processed batch 286/844
# Processed batch 287/844
# Processed batch 288/844
# Processed batch 289/844
# Processed batch 290/844
# Processed batch 291/844
# Processed batch 292/844
# Processed batch 293/844
# Processed batch 294/844
# Processed batch 295/844
# Processed batch 296/844
# Processed batch 297/844
# Processed batch 298/844
# Processed batch 299/844
# Processed batch 300/844
# Processed batch 301/844
# Processed batch 302/844
# Processed batch 303/844
# Processed batch 304/844
# Processed batch 305/844
# Processed batch 306/844
# Processed batch 307/844
# Processed batch 308/844
# Processed batch 309/844
# Processed batch 310/844
# Processed batch 311/844
# Processed batch 312/844
# Processed batch 313/844
# Processed batch 314/844
# Processed batch 315/844
# Processed batch 316/844
# Processed batch 317/844
# Processed batch 318/844
# Processed batch 319/844
# Processed batch 320/844
# Processed batch 321/844
# Processed batch 322/844
# Processed batch 323/844
# Processed batch 324/844
# Processed batch 325/844
# Processed batch 326/844
# Processed batch 327/844
# Processed batch 328/844
# Processed batch 329/844
# Processed batch 330/844
# Processed batch 331/844
# Processed batch 332/844
# Processed batch 333/844
# Processed batch 334/844
# Processed batch 335/844
# Processed batch 336/844
# Processed batch 337/844
# Processed batch 338/844
# Processed batch 339/844
# Processed batch 340/844
# Processed batch 341/844
# Processed batch 342/844
# Processed batch 343/844
# Processed batch 344/844
# Processed batch 345/844
# Processed batch 346/844
# Processed batch 347/844
# Processed batch 348/844
# Processed batch 349/844
# Processed batch 350/844
# Processed batch 351/844
# Processed batch 352/844
# Processed batch 353/844
# Processed batch 354/844
# Processed batch 355/844
# Processed batch 356/844
# Processed batch 357/844
# Processed batch 358/844
# Processed batch 359/844
# Processed batch 360/844
# Processed batch 361/844
# Processed batch 362/844
# Processed batch 363/844
# Processed batch 364/844
# Processed batch 365/844
# Processed batch 366/844
# Processed batch 367/844
# Processed batch 368/844
# Processed batch 369/844
# Processed batch 370/844
# Processed batch 371/844
# Processed batch 372/844
# Processed batch 373/844
# Processed batch 374/844
# Processed batch 375/844
# Processed batch 376/844
# Processed batch 377/844
# Processed batch 378/844
# Processed batch 379/844
# Processed batch 380/844
# Processed batch 381/844
# Processed batch 382/844
# Processed batch 383/844
# Processed batch 384/844
# Processed batch 385/844
# Processed batch 386/844
# Processed batch 387/844
# Processed batch 388/844
# Processed batch 389/844
# Processed batch 390/844
# Processed batch 391/844
# Processed batch 392/844
# Processed batch 393/844
# Processed batch 394/844
# Processed batch 395/844
# Processed batch 396/844
# Processed batch 397/844
# Processed batch 398/844
# Processed batch 399/844
# Processed batch 400/844
# Processed batch 401/844
# Processed batch 402/844
# Processed batch 403/844
# Processed batch 404/844
# Processed batch 405/844
# Processed batch 406/844
# Processed batch 407/844
# Processed batch 408/844
# Processed batch 409/844
# Processed batch 410/844
# Processed batch 411/844
# Processed batch 412/844
# Processed batch 413/844
# Processed batch 414/844
# Processed batch 415/844
# Processed batch 416/844
# Processed batch 417/844
# Processed batch 418/844
# Processed batch 419/844
# Processed batch 420/844
# Processed batch 421/844
# Processed batch 422/844
# Processed batch 423/844
# Processed batch 424/844
# Processed batch 425/844
# Processed batch 426/844
# Processed batch 427/844
# Processed batch 428/844
# Processed batch 429/844
# Processed batch 430/844
# Processed batch 431/844
# Processed batch 432/844
# Processed batch 433/844
# Processed batch 434/844
# Processed batch 435/844
# Processed batch 436/844
# Processed batch 437/844
# Processed batch 438/844
# Processed batch 439/844
# Processed batch 440/844
# Processed batch 441/844
# Processed batch 442/844
# Processed batch 443/844
# Processed batch 444/844
# Processed batch 445/844
# Processed batch 446/844
# Processed batch 447/844
# Processed batch 448/844
# Processed batch 449/844
# Processed batch 450/844
# Processed batch 451/844
# Processed batch 452/844
# Processed batch 453/844
# Processed batch 454/844
# Processed batch 455/844
# Processed batch 456/844
# Processed batch 457/844
# Processed batch 458/844
# Processed batch 459/844
# Processed batch 460/844
# Processed batch 461/844
# Processed batch 462/844
# Processed batch 463/844
# Processed batch 464/844
# Processed batch 465/844
# Processed batch 466/844
# Processed batch 467/844
# Processed batch 468/844
# Processed batch 469/844
# Processed batch 470/844
# Processed batch 471/844
# Processed batch 472/844
# Processed batch 473/844
# Processed batch 474/844
# Processed batch 475/844
# Processed batch 476/844
# Processed batch 477/844
# Processed batch 478/844
# Processed batch 479/844
# Processed batch 480/844
# Processed batch 481/844
# Processed batch 482/844
# Processed batch 483/844
# Processed batch 484/844
# Processed batch 485/844
# Processed batch 486/844
# Processed batch 487/844
# Processed batch 488/844
# Processed batch 489/844
# Processed batch 490/844
# Processed batch 491/844
# Processed batch 492/844
# Processed batch 493/844
# Processed batch 494/844
# Processed batch 495/844
# Processed batch 496/844
# Processed batch 497/844
# Processed batch 498/844
# Processed batch 499/844
# Processed batch 500/844
# Processed batch 501/844
# Processed batch 502/844
# Processed batch 503/844
# Processed batch 504/844
# Processed batch 505/844
# Processed batch 506/844
# Processed batch 507/844
# Processed batch 508/844
# Processed batch 509/844
# Processed batch 510/844
# Processed batch 511/844
# Processed batch 512/844
# Processed batch 513/844
# Processed batch 514/844
# Processed batch 515/844
# Processed batch 516/844
# Processed batch 517/844
# Processed batch 518/844
# Processed batch 519/844
# Processed batch 520/844
# Processed batch 521/844
# Processed batch 522/844
# Processed batch 523/844
# Processed batch 524/844
# Processed batch 525/844
# Processed batch 526/844
# Processed batch 527/844
# Processed batch 528/844
# Processed batch 529/844
# Processed batch 530/844
# Processed batch 531/844
# Processed batch 532/844
# Processed batch 533/844
# Processed batch 534/844
# Processed batch 535/844
# Processed batch 536/844
# Processed batch 537/844
# Processed batch 538/844
# Processed batch 539/844
# Processed batch 540/844
# Processed batch 541/844
# Processed batch 542/844
# Processed batch 543/844
# Processed batch 544/844
# Processed batch 545/844
# Processed batch 546/844
# Processed batch 547/844
# Processed batch 548/844
# Processed batch 549/844
# Processed batch 550/844
# Processed batch 551/844
# Processed batch 552/844
# Processed batch 553/844
# Processed batch 554/844
# Processed batch 555/844
# Processed batch 556/844
# Processed batch 557/844
# Processed batch 558/844
# Processed batch 559/844
# Processed batch 560/844
# Processed batch 561/844
# Processed batch 562/844
# Processed batch 563/844
# Processed batch 564/844
# Processed batch 565/844
# Processed batch 566/844
# Processed batch 567/844
# Processed batch 568/844
# Processed batch 569/844
# Processed batch 570/844
# Processed batch 571/844
# Processed batch 572/844
# Processed batch 573/844
# Processed batch 574/844
# Processed batch 575/844
# Processed batch 576/844
# Processed batch 577/844
# Processed batch 578/844
# Processed batch 579/844
# Processed batch 580/844
# Processed batch 581/844
# Processed batch 582/844
# Processed batch 583/844
# Processed batch 584/844
# Processed batch 585/844
# Processed batch 586/844
# Processed batch 587/844
# Processed batch 588/844
# Processed batch 589/844
# Processed batch 590/844
# Processed batch 591/844
# Processed batch 592/844
# Processed batch 593/844
# Processed batch 594/844
# Processed batch 595/844
# Processed batch 596/844
# Processed batch 597/844
# Processed batch 598/844
# Processed batch 599/844
# Processed batch 600/844
# Processed batch 601/844
# Processed batch 602/844
# Processed batch 603/844
# Processed batch 604/844
# Processed batch 605/844
# Processed batch 606/844
# Processed batch 607/844
# Processed batch 608/844
# Processed batch 609/844
# Processed batch 610/844
# Processed batch 611/844
# Processed batch 612/844
# Processed batch 613/844
# Processed batch 614/844
# Processed batch 615/844
# Processed batch 616/844
# Processed batch 617/844
# Processed batch 618/844
# Processed batch 619/844
# Processed batch 620/844
# Processed batch 621/844
# Processed batch 622/844
# Processed batch 623/844
# Processed batch 624/844
# Processed batch 625/844
# Processed batch 626/844
# Processed batch 627/844
# Processed batch 628/844
# Processed batch 629/844
# Processed batch 630/844
# Processed batch 631/844
# Processed batch 632/844
# Processed batch 633/844
# Processed batch 634/844
# Processed batch 635/844
# Processed batch 636/844
# Processed batch 637/844
# Processed batch 638/844
# Processed batch 639/844
# Processed batch 640/844
# Processed batch 641/844
# Processed batch 642/844
# Processed batch 643/844
# Processed batch 644/844
# Processed batch 645/844
# Processed batch 646/844
# Processed batch 647/844
# Processed batch 648/844
# Processed batch 649/844
# Processed batch 650/844
# Processed batch 651/844
# Processed batch 652/844
# Processed batch 653/844
# Processed batch 654/844
# Processed batch 655/844
# Processed batch 656/844
# Processed batch 657/844
# Processed batch 658/844
# Processed batch 659/844
# Processed batch 660/844
# Processed batch 661/844
# Processed batch 662/844
# Processed batch 663/844
# Processed batch 664/844
# Processed batch 665/844
# Processed batch 666/844
# Processed batch 667/844
# Processed batch 668/844
# Processed batch 669/844
# Processed batch 670/844
# Processed batch 671/844
# Processed batch 672/844
# Processed batch 673/844
# Processed batch 674/844
# Processed batch 675/844
# Processed batch 676/844
# Processed batch 677/844
# Processed batch 678/844
# Processed batch 679/844
# Processed batch 680/844
# Processed batch 681/844
# Processed batch 682/844
# Processed batch 683/844
# Processed batch 684/844
# Processed batch 685/844
# Processed batch 686/844
# Processed batch 687/844
# Processed batch 688/844
# Processed batch 689/844
# Processed batch 690/844
# Processed batch 691/844
# Processed batch 692/844
# Processed batch 693/844
# Processed batch 694/844
# Processed batch 695/844
# Processed batch 696/844
# Processed batch 697/844
# Processed batch 698/844
# Processed batch 699/844
# Processed batch 700/844
# Processed batch 701/844
# Processed batch 702/844
# Processed batch 703/844
# Processed batch 704/844
# Processed batch 705/844
# Processed batch 706/844
# Processed batch 707/844
# Processed batch 708/844
# Processed batch 709/844
# Processed batch 710/844
# Processed batch 711/844
# Processed batch 712/844
# Processed batch 713/844
# Processed batch 714/844
# Processed batch 715/844
# Processed batch 716/844
# Processed batch 717/844
# Processed batch 718/844
# Processed batch 719/844
# Processed batch 720/844
# Processed batch 721/844
# Processed batch 722/844
# Processed batch 723/844
# Processed batch 724/844
# Processed batch 725/844
# Processed batch 726/844
# Processed batch 727/844
# Processed batch 728/844
# Processed batch 729/844
# Processed batch 730/844
# Processed batch 731/844
# Processed batch 732/844
# Processed batch 733/844
# Processed batch 734/844
# Processed batch 735/844
# Processed batch 736/844
# Processed batch 737/844
# Processed batch 738/844
# Processed batch 739/844
# Processed batch 740/844
# Processed batch 741/844
# Processed batch 742/844
# Processed batch 743/844
# Processed batch 744/844
# Processed batch 745/844
# Processed batch 746/844
# Processed batch 747/844
# Processed batch 748/844
# Processed batch 749/844
# Processed batch 750/844
# Processed batch 751/844
# Processed batch 752/844
# Processed batch 753/844
# Processed batch 754/844
# Processed batch 755/844
# Processed batch 756/844
# Processed batch 757/844
# Processed batch 758/844
# Processed batch 759/844
# Processed batch 760/844
# Processed batch 761/844
# Processed batch 762/844
# Processed batch 763/844
# Processed batch 764/844
# Processed batch 765/844
# Processed batch 766/844
# Processed batch 767/844
# Processed batch 768/844
# Processed batch 769/844
# Processed batch 770/844
# Processed batch 771/844
# Processed batch 772/844
# Processed batch 773/844
# Processed batch 774/844
# Processed batch 775/844
# Processed batch 776/844
# Processed batch 777/844
# Processed batch 778/844
# Processed batch 779/844
# Processed batch 780/844
# Processed batch 781/844
# Processed batch 782/844
# Processed batch 783/844
# Processed batch 784/844
# Processed batch 785/844
# Processed batch 786/844
# Processed batch 787/844
# Processed batch 788/844
# Processed batch 789/844
# Processed batch 790/844
# Processed batch 791/844
# Processed batch 792/844
# Processed batch 793/844
# Processed batch 794/844
# Processed batch 795/844
# Processed batch 796/844
# Processed batch 797/844
# Processed batch 798/844
# Processed batch 799/844
# Processed batch 800/844
# Processed batch 801/844
# Processed batch 802/844
# Processed batch 803/844
# Processed batch 804/844
# Processed batch 805/844
# Processed batch 806/844
# Processed batch 807/844
# Processed batch 808/844
# Processed batch 809/844
# Processed batch 810/844
# Processed batch 811/844
# Processed batch 812/844
# Processed batch 813/844
# Processed batch 814/844
# Processed batch 815/844
# Processed batch 816/844
# Processed batch 817/844
# Processed batch 818/844
# Processed batch 819/844
# Processed batch 820/844
# Processed batch 821/844
# Processed batch 822/844
# Processed batch 823/844
# Processed batch 824/844
# Processed batch 825/844
# Processed batch 826/844
# Processed batch 827/844
# Processed batch 828/844
# Processed batch 829/844
# Processed batch 830/844
# Processed batch 831/844
# Processed batch 832/844
# Processed batch 833/844
# Processed batch 834/844
# Processed batch 835/844
# Processed batch 836/844
# Processed batch 837/844
# Processed batch 838/844
# Processed batch 839/844
# Processed batch 840/844
# Processed batch 841/844
# Processed batch 842/844
# Processed batch 843/844
# Processed batch 844/844
# Modified MNIST dataset saved to /home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE5.pt

# %%
import pickle

# Load the sampled RGB values in one line
sampled_values = pickle.load(open("/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/Sampled_Values/Mni/t2e6_mni.pkl", "rb"))
print("Sampled RGB values loaded successfully!")

output_dir = "/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE6.pt"
apply_samples_to_dataset(train_loader, sampled_values, top_22_coords, output_dir)
# Out:
# Sampled RGB values loaded successfully!
# Processed batch 1/844
# Processed batch 2/844
# Processed batch 3/844
# Processed batch 4/844
# Processed batch 5/844
# Processed batch 6/844
# Processed batch 7/844
# Processed batch 8/844
# Processed batch 9/844
# Processed batch 10/844
# Processed batch 11/844
# Processed batch 12/844
# Processed batch 13/844
# Processed batch 14/844
# Processed batch 15/844
# Processed batch 16/844
# Processed batch 17/844
# Processed batch 18/844
# Processed batch 19/844
# Processed batch 20/844
# Processed batch 21/844
# Processed batch 22/844
# Processed batch 23/844
# Processed batch 24/844
# Processed batch 25/844
# Processed batch 26/844
# Processed batch 27/844
# Processed batch 28/844
# Processed batch 29/844
# Processed batch 30/844
# Processed batch 31/844
# Processed batch 32/844
# Processed batch 33/844
# Processed batch 34/844
# Processed batch 35/844
# Processed batch 36/844
# Processed batch 37/844
# Processed batch 38/844
# Processed batch 39/844
# Processed batch 40/844
# Processed batch 41/844
# Processed batch 42/844
# Processed batch 43/844
# Processed batch 44/844
# Processed batch 45/844
# Processed batch 46/844
# Processed batch 47/844
# Processed batch 48/844
# Processed batch 49/844
# Processed batch 50/844
# Processed batch 51/844
# Processed batch 52/844
# Processed batch 53/844
# Processed batch 54/844
# Processed batch 55/844
# Processed batch 56/844
# Processed batch 57/844
# Processed batch 58/844
# Processed batch 59/844
# Processed batch 60/844
# Processed batch 61/844
# Processed batch 62/844
# Processed batch 63/844
# Processed batch 64/844
# Processed batch 65/844
# Processed batch 66/844
# Processed batch 67/844
# Processed batch 68/844
# Processed batch 69/844
# Processed batch 70/844
# Processed batch 71/844
# Processed batch 72/844
# Processed batch 73/844
# Processed batch 74/844
# Processed batch 75/844
# Processed batch 76/844
# Processed batch 77/844
# Processed batch 78/844
# Processed batch 79/844
# Processed batch 80/844
# Processed batch 81/844
# Processed batch 82/844
# Processed batch 83/844
# Processed batch 84/844
# Processed batch 85/844
# Processed batch 86/844
# Processed batch 87/844
# Processed batch 88/844
# Processed batch 89/844
# Processed batch 90/844
# Processed batch 91/844
# Processed batch 92/844
# Processed batch 93/844
# Processed batch 94/844
# Processed batch 95/844
# Processed batch 96/844
# Processed batch 97/844
# Processed batch 98/844
# Processed batch 99/844
# Processed batch 100/844
# Processed batch 101/844
# Processed batch 102/844
# Processed batch 103/844
# Processed batch 104/844
# Processed batch 105/844
# Processed batch 106/844
# Processed batch 107/844
# Processed batch 108/844
# Processed batch 109/844
# Processed batch 110/844
# Processed batch 111/844
# Processed batch 112/844
# Processed batch 113/844
# Processed batch 114/844
# Processed batch 115/844
# Processed batch 116/844
# Processed batch 117/844
# Processed batch 118/844
# Processed batch 119/844
# Processed batch 120/844
# Processed batch 121/844
# Processed batch 122/844
# Processed batch 123/844
# Processed batch 124/844
# Processed batch 125/844
# Processed batch 126/844
# Processed batch 127/844
# Processed batch 128/844
# Processed batch 129/844
# Processed batch 130/844
# Processed batch 131/844
# Processed batch 132/844
# Processed batch 133/844
# Processed batch 134/844
# Processed batch 135/844
# Processed batch 136/844
# Processed batch 137/844
# Processed batch 138/844
# Processed batch 139/844
# Processed batch 140/844
# Processed batch 141/844
# Processed batch 142/844
# Processed batch 143/844
# Processed batch 144/844
# Processed batch 145/844
# Processed batch 146/844
# Processed batch 147/844
# Processed batch 148/844
# Processed batch 149/844
# Processed batch 150/844
# Processed batch 151/844
# Processed batch 152/844
# Processed batch 153/844
# Processed batch 154/844
# Processed batch 155/844
# Processed batch 156/844
# Processed batch 157/844
# Processed batch 158/844
# Processed batch 159/844
# Processed batch 160/844
# Processed batch 161/844
# Processed batch 162/844
# Processed batch 163/844
# Processed batch 164/844
# Processed batch 165/844
# Processed batch 166/844
# Processed batch 167/844
# Processed batch 168/844
# Processed batch 169/844
# Processed batch 170/844
# Processed batch 171/844
# Processed batch 172/844
# Processed batch 173/844
# Processed batch 174/844
# Processed batch 175/844
# Processed batch 176/844
# Processed batch 177/844
# Processed batch 178/844
# Processed batch 179/844
# Processed batch 180/844
# Processed batch 181/844
# Processed batch 182/844
# Processed batch 183/844
# Processed batch 184/844
# Processed batch 185/844
# Processed batch 186/844
# Processed batch 187/844
# Processed batch 188/844
# Processed batch 189/844
# Processed batch 190/844
# Processed batch 191/844
# Processed batch 192/844
# Processed batch 193/844
# Processed batch 194/844
# Processed batch 195/844
# Processed batch 196/844
# Processed batch 197/844
# Processed batch 198/844
# Processed batch 199/844
# Processed batch 200/844
# Processed batch 201/844
# Processed batch 202/844
# Processed batch 203/844
# Processed batch 204/844
# Processed batch 205/844
# Processed batch 206/844
# Processed batch 207/844
# Processed batch 208/844
# Processed batch 209/844
# Processed batch 210/844
# Processed batch 211/844
# Processed batch 212/844
# Processed batch 213/844
# Processed batch 214/844
# Processed batch 215/844
# Processed batch 216/844
# Processed batch 217/844
# Processed batch 218/844
# Processed batch 219/844
# Processed batch 220/844
# Processed batch 221/844
# Processed batch 222/844
# Processed batch 223/844
# Processed batch 224/844
# Processed batch 225/844
# Processed batch 226/844
# Processed batch 227/844
# Processed batch 228/844
# Processed batch 229/844
# Processed batch 230/844
# Processed batch 231/844
# Processed batch 232/844
# Processed batch 233/844
# Processed batch 234/844
# Processed batch 235/844
# Processed batch 236/844
# Processed batch 237/844
# Processed batch 238/844
# Processed batch 239/844
# Processed batch 240/844
# Processed batch 241/844
# Processed batch 242/844
# Processed batch 243/844
# Processed batch 244/844
# Processed batch 245/844
# Processed batch 246/844
# Processed batch 247/844
# Processed batch 248/844
# Processed batch 249/844
# Processed batch 250/844
# Processed batch 251/844
# Processed batch 252/844
# Processed batch 253/844
# Processed batch 254/844
# Processed batch 255/844
# Processed batch 256/844
# Processed batch 257/844
# Processed batch 258/844
# Processed batch 259/844
# Processed batch 260/844
# Processed batch 261/844
# Processed batch 262/844
# Processed batch 263/844
# Processed batch 264/844
# Processed batch 265/844
# Processed batch 266/844
# Processed batch 267/844
# Processed batch 268/844
# Processed batch 269/844
# Processed batch 270/844
# Processed batch 271/844
# Processed batch 272/844
# Processed batch 273/844
# Processed batch 274/844
# Processed batch 275/844
# Processed batch 276/844
# Processed batch 277/844
# Processed batch 278/844
# Processed batch 279/844
# Processed batch 280/844
# Processed batch 281/844
# Processed batch 282/844
# Processed batch 283/844
# Processed batch 284/844
# Processed batch 285/844
# Processed batch 286/844
# Processed batch 287/844
# Processed batch 288/844
# Processed batch 289/844
# Processed batch 290/844
# Processed batch 291/844
# Processed batch 292/844
# Processed batch 293/844
# Processed batch 294/844
# Processed batch 295/844
# Processed batch 296/844
# Processed batch 297/844
# Processed batch 298/844
# Processed batch 299/844
# Processed batch 300/844
# Processed batch 301/844
# Processed batch 302/844
# Processed batch 303/844
# Processed batch 304/844
# Processed batch 305/844
# Processed batch 306/844
# Processed batch 307/844
# Processed batch 308/844
# Processed batch 309/844
# Processed batch 310/844
# Processed batch 311/844
# Processed batch 312/844
# Processed batch 313/844
# Processed batch 314/844
# Processed batch 315/844
# Processed batch 316/844
# Processed batch 317/844
# Processed batch 318/844
# Processed batch 319/844
# Processed batch 320/844
# Processed batch 321/844
# Processed batch 322/844
# Processed batch 323/844
# Processed batch 324/844
# Processed batch 325/844
# Processed batch 326/844
# Processed batch 327/844
# Processed batch 328/844
# Processed batch 329/844
# Processed batch 330/844
# Processed batch 331/844
# Processed batch 332/844
# Processed batch 333/844
# Processed batch 334/844
# Processed batch 335/844
# Processed batch 336/844
# Processed batch 337/844
# Processed batch 338/844
# Processed batch 339/844
# Processed batch 340/844
# Processed batch 341/844
# Processed batch 342/844
# Processed batch 343/844
# Processed batch 344/844
# Processed batch 345/844
# Processed batch 346/844
# Processed batch 347/844
# Processed batch 348/844
# Processed batch 349/844
# Processed batch 350/844
# Processed batch 351/844
# Processed batch 352/844
# Processed batch 353/844
# Processed batch 354/844
# Processed batch 355/844
# Processed batch 356/844
# Processed batch 357/844
# Processed batch 358/844
# Processed batch 359/844
# Processed batch 360/844
# Processed batch 361/844
# Processed batch 362/844
# Processed batch 363/844
# Processed batch 364/844
# Processed batch 365/844
# Processed batch 366/844
# Processed batch 367/844
# Processed batch 368/844
# Processed batch 369/844
# Processed batch 370/844
# Processed batch 371/844
# Processed batch 372/844
# Processed batch 373/844
# Processed batch 374/844
# Processed batch 375/844
# Processed batch 376/844
# Processed batch 377/844
# Processed batch 378/844
# Processed batch 379/844
# Processed batch 380/844
# Processed batch 381/844
# Processed batch 382/844
# Processed batch 383/844
# Processed batch 384/844
# Processed batch 385/844
# Processed batch 386/844
# Processed batch 387/844
# Processed batch 388/844
# Processed batch 389/844
# Processed batch 390/844
# Processed batch 391/844
# Processed batch 392/844
# Processed batch 393/844
# Processed batch 394/844
# Processed batch 395/844
# Processed batch 396/844
# Processed batch 397/844
# Processed batch 398/844
# Processed batch 399/844
# Processed batch 400/844
# Processed batch 401/844
# Processed batch 402/844
# Processed batch 403/844
# Processed batch 404/844
# Processed batch 405/844
# Processed batch 406/844
# Processed batch 407/844
# Processed batch 408/844
# Processed batch 409/844
# Processed batch 410/844
# Processed batch 411/844
# Processed batch 412/844
# Processed batch 413/844
# Processed batch 414/844
# Processed batch 415/844
# Processed batch 416/844
# Processed batch 417/844
# Processed batch 418/844
# Processed batch 419/844
# Processed batch 420/844
# Processed batch 421/844
# Processed batch 422/844
# Processed batch 423/844
# Processed batch 424/844
# Processed batch 425/844
# Processed batch 426/844
# Processed batch 427/844
# Processed batch 428/844
# Processed batch 429/844
# Processed batch 430/844
# Processed batch 431/844
# Processed batch 432/844
# Processed batch 433/844
# Processed batch 434/844
# Processed batch 435/844
# Processed batch 436/844
# Processed batch 437/844
# Processed batch 438/844
# Processed batch 439/844
# Processed batch 440/844
# Processed batch 441/844
# Processed batch 442/844
# Processed batch 443/844
# Processed batch 444/844
# Processed batch 445/844
# Processed batch 446/844
# Processed batch 447/844
# Processed batch 448/844
# Processed batch 449/844
# Processed batch 450/844
# Processed batch 451/844
# Processed batch 452/844
# Processed batch 453/844
# Processed batch 454/844
# Processed batch 455/844
# Processed batch 456/844
# Processed batch 457/844
# Processed batch 458/844
# Processed batch 459/844
# Processed batch 460/844
# Processed batch 461/844
# Processed batch 462/844
# Processed batch 463/844
# Processed batch 464/844
# Processed batch 465/844
# Processed batch 466/844
# Processed batch 467/844
# Processed batch 468/844
# Processed batch 469/844
# Processed batch 470/844
# Processed batch 471/844
# Processed batch 472/844
# Processed batch 473/844
# Processed batch 474/844
# Processed batch 475/844
# Processed batch 476/844
# Processed batch 477/844
# Processed batch 478/844
# Processed batch 479/844
# Processed batch 480/844
# Processed batch 481/844
# Processed batch 482/844
# Processed batch 483/844
# Processed batch 484/844
# Processed batch 485/844
# Processed batch 486/844
# Processed batch 487/844
# Processed batch 488/844
# Processed batch 489/844
# Processed batch 490/844
# Processed batch 491/844
# Processed batch 492/844
# Processed batch 493/844
# Processed batch 494/844
# Processed batch 495/844
# Processed batch 496/844
# Processed batch 497/844
# Processed batch 498/844
# Processed batch 499/844
# Processed batch 500/844
# Processed batch 501/844
# Processed batch 502/844
# Processed batch 503/844
# Processed batch 504/844
# Processed batch 505/844
# Processed batch 506/844
# Processed batch 507/844
# Processed batch 508/844
# Processed batch 509/844
# Processed batch 510/844
# Processed batch 511/844
# Processed batch 512/844
# Processed batch 513/844
# Processed batch 514/844
# Processed batch 515/844
# Processed batch 516/844
# Processed batch 517/844
# Processed batch 518/844
# Processed batch 519/844
# Processed batch 520/844
# Processed batch 521/844
# Processed batch 522/844
# Processed batch 523/844
# Processed batch 524/844
# Processed batch 525/844
# Processed batch 526/844
# Processed batch 527/844
# Processed batch 528/844
# Processed batch 529/844
# Processed batch 530/844
# Processed batch 531/844
# Processed batch 532/844
# Processed batch 533/844
# Processed batch 534/844
# Processed batch 535/844
# Processed batch 536/844
# Processed batch 537/844
# Processed batch 538/844
# Processed batch 539/844
# Processed batch 540/844
# Processed batch 541/844
# Processed batch 542/844
# Processed batch 543/844
# Processed batch 544/844
# Processed batch 545/844
# Processed batch 546/844
# Processed batch 547/844
# Processed batch 548/844
# Processed batch 549/844
# Processed batch 550/844
# Processed batch 551/844
# Processed batch 552/844
# Processed batch 553/844
# Processed batch 554/844
# Processed batch 555/844
# Processed batch 556/844
# Processed batch 557/844
# Processed batch 558/844
# Processed batch 559/844
# Processed batch 560/844
# Processed batch 561/844
# Processed batch 562/844
# Processed batch 563/844
# Processed batch 564/844
# Processed batch 565/844
# Processed batch 566/844
# Processed batch 567/844
# Processed batch 568/844
# Processed batch 569/844
# Processed batch 570/844
# Processed batch 571/844
# Processed batch 572/844
# Processed batch 573/844
# Processed batch 574/844
# Processed batch 575/844
# Processed batch 576/844
# Processed batch 577/844
# Processed batch 578/844
# Processed batch 579/844
# Processed batch 580/844
# Processed batch 581/844
# Processed batch 582/844
# Processed batch 583/844
# Processed batch 584/844
# Processed batch 585/844
# Processed batch 586/844
# Processed batch 587/844
# Processed batch 588/844
# Processed batch 589/844
# Processed batch 590/844
# Processed batch 591/844
# Processed batch 592/844
# Processed batch 593/844
# Processed batch 594/844
# Processed batch 595/844
# Processed batch 596/844
# Processed batch 597/844
# Processed batch 598/844
# Processed batch 599/844
# Processed batch 600/844
# Processed batch 601/844
# Processed batch 602/844
# Processed batch 603/844
# Processed batch 604/844
# Processed batch 605/844
# Processed batch 606/844
# Processed batch 607/844
# Processed batch 608/844
# Processed batch 609/844
# Processed batch 610/844
# Processed batch 611/844
# Processed batch 612/844
# Processed batch 613/844
# Processed batch 614/844
# Processed batch 615/844
# Processed batch 616/844
# Processed batch 617/844
# Processed batch 618/844
# Processed batch 619/844
# Processed batch 620/844
# Processed batch 621/844
# Processed batch 622/844
# Processed batch 623/844
# Processed batch 624/844
# Processed batch 625/844
# Processed batch 626/844
# Processed batch 627/844
# Processed batch 628/844
# Processed batch 629/844
# Processed batch 630/844
# Processed batch 631/844
# Processed batch 632/844
# Processed batch 633/844
# Processed batch 634/844
# Processed batch 635/844
# Processed batch 636/844
# Processed batch 637/844
# Processed batch 638/844
# Processed batch 639/844
# Processed batch 640/844
# Processed batch 641/844
# Processed batch 642/844
# Processed batch 643/844
# Processed batch 644/844
# Processed batch 645/844
# Processed batch 646/844
# Processed batch 647/844
# Processed batch 648/844
# Processed batch 649/844
# Processed batch 650/844
# Processed batch 651/844
# Processed batch 652/844
# Processed batch 653/844
# Processed batch 654/844
# Processed batch 655/844
# Processed batch 656/844
# Processed batch 657/844
# Processed batch 658/844
# Processed batch 659/844
# Processed batch 660/844
# Processed batch 661/844
# Processed batch 662/844
# Processed batch 663/844
# Processed batch 664/844
# Processed batch 665/844
# Processed batch 666/844
# Processed batch 667/844
# Processed batch 668/844
# Processed batch 669/844
# Processed batch 670/844
# Processed batch 671/844
# Processed batch 672/844
# Processed batch 673/844
# Processed batch 674/844
# Processed batch 675/844
# Processed batch 676/844
# Processed batch 677/844
# Processed batch 678/844
# Processed batch 679/844
# Processed batch 680/844
# Processed batch 681/844
# Processed batch 682/844
# Processed batch 683/844
# Processed batch 684/844
# Processed batch 685/844
# Processed batch 686/844
# Processed batch 687/844
# Processed batch 688/844
# Processed batch 689/844
# Processed batch 690/844
# Processed batch 691/844
# Processed batch 692/844
# Processed batch 693/844
# Processed batch 694/844
# Processed batch 695/844
# Processed batch 696/844
# Processed batch 697/844
# Processed batch 698/844
# Processed batch 699/844
# Processed batch 700/844
# Processed batch 701/844
# Processed batch 702/844
# Processed batch 703/844
# Processed batch 704/844
# Processed batch 705/844
# Processed batch 706/844
# Processed batch 707/844
# Processed batch 708/844
# Processed batch 709/844
# Processed batch 710/844
# Processed batch 711/844
# Processed batch 712/844
# Processed batch 713/844
# Processed batch 714/844
# Processed batch 715/844
# Processed batch 716/844
# Processed batch 717/844
# Processed batch 718/844
# Processed batch 719/844
# Processed batch 720/844
# Processed batch 721/844
# Processed batch 722/844
# Processed batch 723/844
# Processed batch 724/844
# Processed batch 725/844
# Processed batch 726/844
# Processed batch 727/844
# Processed batch 728/844
# Processed batch 729/844
# Processed batch 730/844
# Processed batch 731/844
# Processed batch 732/844
# Processed batch 733/844
# Processed batch 734/844
# Processed batch 735/844
# Processed batch 736/844
# Processed batch 737/844
# Processed batch 738/844
# Processed batch 739/844
# Processed batch 740/844
# Processed batch 741/844
# Processed batch 742/844
# Processed batch 743/844
# Processed batch 744/844
# Processed batch 745/844
# Processed batch 746/844
# Processed batch 747/844
# Processed batch 748/844
# Processed batch 749/844
# Processed batch 750/844
# Processed batch 751/844
# Processed batch 752/844
# Processed batch 753/844
# Processed batch 754/844
# Processed batch 755/844
# Processed batch 756/844
# Processed batch 757/844
# Processed batch 758/844
# Processed batch 759/844
# Processed batch 760/844
# Processed batch 761/844
# Processed batch 762/844
# Processed batch 763/844
# Processed batch 764/844
# Processed batch 765/844
# Processed batch 766/844
# Processed batch 767/844
# Processed batch 768/844
# Processed batch 769/844
# Processed batch 770/844
# Processed batch 771/844
# Processed batch 772/844
# Processed batch 773/844
# Processed batch 774/844
# Processed batch 775/844
# Processed batch 776/844
# Processed batch 777/844
# Processed batch 778/844
# Processed batch 779/844
# Processed batch 780/844
# Processed batch 781/844
# Processed batch 782/844
# Processed batch 783/844
# Processed batch 784/844
# Processed batch 785/844
# Processed batch 786/844
# Processed batch 787/844
# Processed batch 788/844
# Processed batch 789/844
# Processed batch 790/844
# Processed batch 791/844
# Processed batch 792/844
# Processed batch 793/844
# Processed batch 794/844
# Processed batch 795/844
# Processed batch 796/844
# Processed batch 797/844
# Processed batch 798/844
# Processed batch 799/844
# Processed batch 800/844
# Processed batch 801/844
# Processed batch 802/844
# Processed batch 803/844
# Processed batch 804/844
# Processed batch 805/844
# Processed batch 806/844
# Processed batch 807/844
# Processed batch 808/844
# Processed batch 809/844
# Processed batch 810/844
# Processed batch 811/844
# Processed batch 812/844
# Processed batch 813/844
# Processed batch 814/844
# Processed batch 815/844
# Processed batch 816/844
# Processed batch 817/844
# Processed batch 818/844
# Processed batch 819/844
# Processed batch 820/844
# Processed batch 821/844
# Processed batch 822/844
# Processed batch 823/844
# Processed batch 824/844
# Processed batch 825/844
# Processed batch 826/844
# Processed batch 827/844
# Processed batch 828/844
# Processed batch 829/844
# Processed batch 830/844
# Processed batch 831/844
# Processed batch 832/844
# Processed batch 833/844
# Processed batch 834/844
# Processed batch 835/844
# Processed batch 836/844
# Processed batch 837/844
# Processed batch 838/844
# Processed batch 839/844
# Processed batch 840/844
# Processed batch 841/844
# Processed batch 842/844
# Processed batch 843/844
# Processed batch 844/844
# Modified MNIST dataset saved to /home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE6.pt

# %%
import pickle

# Load the sampled RGB values in one line
sampled_values = pickle.load(open("/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/Sampled_Values/Mni/t2e7_mni.pkl", "rb"))
print("Sampled RGB values loaded successfully!")

output_dir = "/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE7.pt"
apply_samples_to_dataset(train_loader, sampled_values, top_22_coords, output_dir)
# Out:
# Sampled RGB values loaded successfully!
# Processed batch 1/844
# Processed batch 2/844
# Processed batch 3/844
# Processed batch 4/844
# Processed batch 5/844
# Processed batch 6/844
# Processed batch 7/844
# Processed batch 8/844
# Processed batch 9/844
# Processed batch 10/844
# Processed batch 11/844
# Processed batch 12/844
# Processed batch 13/844
# Processed batch 14/844
# Processed batch 15/844
# Processed batch 16/844
# Processed batch 17/844
# Processed batch 18/844
# Processed batch 19/844
# Processed batch 20/844
# Processed batch 21/844
# Processed batch 22/844
# Processed batch 23/844
# Processed batch 24/844
# Processed batch 25/844
# Processed batch 26/844
# Processed batch 27/844
# Processed batch 28/844
# Processed batch 29/844
# Processed batch 30/844
# Processed batch 31/844
# Processed batch 32/844
# Processed batch 33/844
# Processed batch 34/844
# Processed batch 35/844
# Processed batch 36/844
# Processed batch 37/844
# Processed batch 38/844
# Processed batch 39/844
# Processed batch 40/844
# Processed batch 41/844
# Processed batch 42/844
# Processed batch 43/844
# Processed batch 44/844
# Processed batch 45/844
# Processed batch 46/844
# Processed batch 47/844
# Processed batch 48/844
# Processed batch 49/844
# Processed batch 50/844
# Processed batch 51/844
# Processed batch 52/844
# Processed batch 53/844
# Processed batch 54/844
# Processed batch 55/844
# Processed batch 56/844
# Processed batch 57/844
# Processed batch 58/844
# Processed batch 59/844
# Processed batch 60/844
# Processed batch 61/844
# Processed batch 62/844
# Processed batch 63/844
# Processed batch 64/844
# Processed batch 65/844
# Processed batch 66/844
# Processed batch 67/844
# Processed batch 68/844
# Processed batch 69/844
# Processed batch 70/844
# Processed batch 71/844
# Processed batch 72/844
# Processed batch 73/844
# Processed batch 74/844
# Processed batch 75/844
# Processed batch 76/844
# Processed batch 77/844
# Processed batch 78/844
# Processed batch 79/844
# Processed batch 80/844
# Processed batch 81/844
# Processed batch 82/844
# Processed batch 83/844
# Processed batch 84/844
# Processed batch 85/844
# Processed batch 86/844
# Processed batch 87/844
# Processed batch 88/844
# Processed batch 89/844
# Processed batch 90/844
# Processed batch 91/844
# Processed batch 92/844
# Processed batch 93/844
# Processed batch 94/844
# Processed batch 95/844
# Processed batch 96/844
# Processed batch 97/844
# Processed batch 98/844
# Processed batch 99/844
# Processed batch 100/844
# Processed batch 101/844
# Processed batch 102/844
# Processed batch 103/844
# Processed batch 104/844
# Processed batch 105/844
# Processed batch 106/844
# Processed batch 107/844
# Processed batch 108/844
# Processed batch 109/844
# Processed batch 110/844
# Processed batch 111/844
# Processed batch 112/844
# Processed batch 113/844
# Processed batch 114/844
# Processed batch 115/844
# Processed batch 116/844
# Processed batch 117/844
# Processed batch 118/844
# Processed batch 119/844
# Processed batch 120/844
# Processed batch 121/844
# Processed batch 122/844
# Processed batch 123/844
# Processed batch 124/844
# Processed batch 125/844
# Processed batch 126/844
# Processed batch 127/844
# Processed batch 128/844
# Processed batch 129/844
# Processed batch 130/844
# Processed batch 131/844
# Processed batch 132/844
# Processed batch 133/844
# Processed batch 134/844
# Processed batch 135/844
# Processed batch 136/844
# Processed batch 137/844
# Processed batch 138/844
# Processed batch 139/844
# Processed batch 140/844
# Processed batch 141/844
# Processed batch 142/844
# Processed batch 143/844
# Processed batch 144/844
# Processed batch 145/844
# Processed batch 146/844
# Processed batch 147/844
# Processed batch 148/844
# Processed batch 149/844
# Processed batch 150/844
# Processed batch 151/844
# Processed batch 152/844
# Processed batch 153/844
# Processed batch 154/844
# Processed batch 155/844
# Processed batch 156/844
# Processed batch 157/844
# Processed batch 158/844
# Processed batch 159/844
# Processed batch 160/844
# Processed batch 161/844
# Processed batch 162/844
# Processed batch 163/844
# Processed batch 164/844
# Processed batch 165/844
# Processed batch 166/844
# Processed batch 167/844
# Processed batch 168/844
# Processed batch 169/844
# Processed batch 170/844
# Processed batch 171/844
# Processed batch 172/844
# Processed batch 173/844
# Processed batch 174/844
# Processed batch 175/844
# Processed batch 176/844
# Processed batch 177/844
# Processed batch 178/844
# Processed batch 179/844
# Processed batch 180/844
# Processed batch 181/844
# Processed batch 182/844
# Processed batch 183/844
# Processed batch 184/844
# Processed batch 185/844
# Processed batch 186/844
# Processed batch 187/844
# Processed batch 188/844
# Processed batch 189/844
# Processed batch 190/844
# Processed batch 191/844
# Processed batch 192/844
# Processed batch 193/844
# Processed batch 194/844
# Processed batch 195/844
# Processed batch 196/844
# Processed batch 197/844
# Processed batch 198/844
# Processed batch 199/844
# Processed batch 200/844
# Processed batch 201/844
# Processed batch 202/844
# Processed batch 203/844
# Processed batch 204/844
# Processed batch 205/844
# Processed batch 206/844
# Processed batch 207/844
# Processed batch 208/844
# Processed batch 209/844
# Processed batch 210/844
# Processed batch 211/844
# Processed batch 212/844
# Processed batch 213/844
# Processed batch 214/844
# Processed batch 215/844
# Processed batch 216/844
# Processed batch 217/844
# Processed batch 218/844
# Processed batch 219/844
# Processed batch 220/844
# Processed batch 221/844
# Processed batch 222/844
# Processed batch 223/844
# Processed batch 224/844
# Processed batch 225/844
# Processed batch 226/844
# Processed batch 227/844
# Processed batch 228/844
# Processed batch 229/844
# Processed batch 230/844
# Processed batch 231/844
# Processed batch 232/844
# Processed batch 233/844
# Processed batch 234/844
# Processed batch 235/844
# Processed batch 236/844
# Processed batch 237/844
# Processed batch 238/844
# Processed batch 239/844
# Processed batch 240/844
# Processed batch 241/844
# Processed batch 242/844
# Processed batch 243/844
# Processed batch 244/844
# Processed batch 245/844
# Processed batch 246/844
# Processed batch 247/844
# Processed batch 248/844
# Processed batch 249/844
# Processed batch 250/844
# Processed batch 251/844
# Processed batch 252/844
# Processed batch 253/844
# Processed batch 254/844
# Processed batch 255/844
# Processed batch 256/844
# Processed batch 257/844
# Processed batch 258/844
# Processed batch 259/844
# Processed batch 260/844
# Processed batch 261/844
# Processed batch 262/844
# Processed batch 263/844
# Processed batch 264/844
# Processed batch 265/844
# Processed batch 266/844
# Processed batch 267/844
# Processed batch 268/844
# Processed batch 269/844
# Processed batch 270/844
# Processed batch 271/844
# Processed batch 272/844
# Processed batch 273/844
# Processed batch 274/844
# Processed batch 275/844
# Processed batch 276/844
# Processed batch 277/844
# Processed batch 278/844
# Processed batch 279/844
# Processed batch 280/844
# Processed batch 281/844
# Processed batch 282/844
# Processed batch 283/844
# Processed batch 284/844
# Processed batch 285/844
# Processed batch 286/844
# Processed batch 287/844
# Processed batch 288/844
# Processed batch 289/844
# Processed batch 290/844
# Processed batch 291/844
# Processed batch 292/844
# Processed batch 293/844
# Processed batch 294/844
# Processed batch 295/844
# Processed batch 296/844
# Processed batch 297/844
# Processed batch 298/844
# Processed batch 299/844
# Processed batch 300/844
# Processed batch 301/844
# Processed batch 302/844
# Processed batch 303/844
# Processed batch 304/844
# Processed batch 305/844
# Processed batch 306/844
# Processed batch 307/844
# Processed batch 308/844
# Processed batch 309/844
# Processed batch 310/844
# Processed batch 311/844
# Processed batch 312/844
# Processed batch 313/844
# Processed batch 314/844
# Processed batch 315/844
# Processed batch 316/844
# Processed batch 317/844
# Processed batch 318/844
# Processed batch 319/844
# Processed batch 320/844
# Processed batch 321/844
# Processed batch 322/844
# Processed batch 323/844
# Processed batch 324/844
# Processed batch 325/844
# Processed batch 326/844
# Processed batch 327/844
# Processed batch 328/844
# Processed batch 329/844
# Processed batch 330/844
# Processed batch 331/844
# Processed batch 332/844
# Processed batch 333/844
# Processed batch 334/844
# Processed batch 335/844
# Processed batch 336/844
# Processed batch 337/844
# Processed batch 338/844
# Processed batch 339/844
# Processed batch 340/844
# Processed batch 341/844
# Processed batch 342/844
# Processed batch 343/844
# Processed batch 344/844
# Processed batch 345/844
# Processed batch 346/844
# Processed batch 347/844
# Processed batch 348/844
# Processed batch 349/844
# Processed batch 350/844
# Processed batch 351/844
# Processed batch 352/844
# Processed batch 353/844
# Processed batch 354/844
# Processed batch 355/844
# Processed batch 356/844
# Processed batch 357/844
# Processed batch 358/844
# Processed batch 359/844
# Processed batch 360/844
# Processed batch 361/844
# Processed batch 362/844
# Processed batch 363/844
# Processed batch 364/844
# Processed batch 365/844
# Processed batch 366/844
# Processed batch 367/844
# Processed batch 368/844
# Processed batch 369/844
# Processed batch 370/844
# Processed batch 371/844
# Processed batch 372/844
# Processed batch 373/844
# Processed batch 374/844
# Processed batch 375/844
# Processed batch 376/844
# Processed batch 377/844
# Processed batch 378/844
# Processed batch 379/844
# Processed batch 380/844
# Processed batch 381/844
# Processed batch 382/844
# Processed batch 383/844
# Processed batch 384/844
# Processed batch 385/844
# Processed batch 386/844
# Processed batch 387/844
# Processed batch 388/844
# Processed batch 389/844
# Processed batch 390/844
# Processed batch 391/844
# Processed batch 392/844
# Processed batch 393/844
# Processed batch 394/844
# Processed batch 395/844
# Processed batch 396/844
# Processed batch 397/844
# Processed batch 398/844
# Processed batch 399/844
# Processed batch 400/844
# Processed batch 401/844
# Processed batch 402/844
# Processed batch 403/844
# Processed batch 404/844
# Processed batch 405/844
# Processed batch 406/844
# Processed batch 407/844
# Processed batch 408/844
# Processed batch 409/844
# Processed batch 410/844
# Processed batch 411/844
# Processed batch 412/844
# Processed batch 413/844
# Processed batch 414/844
# Processed batch 415/844
# Processed batch 416/844
# Processed batch 417/844
# Processed batch 418/844
# Processed batch 419/844
# Processed batch 420/844
# Processed batch 421/844
# Processed batch 422/844
# Processed batch 423/844
# Processed batch 424/844
# Processed batch 425/844
# Processed batch 426/844
# Processed batch 427/844
# Processed batch 428/844
# Processed batch 429/844
# Processed batch 430/844
# Processed batch 431/844
# Processed batch 432/844
# Processed batch 433/844
# Processed batch 434/844
# Processed batch 435/844
# Processed batch 436/844
# Processed batch 437/844
# Processed batch 438/844
# Processed batch 439/844
# Processed batch 440/844
# Processed batch 441/844
# Processed batch 442/844
# Processed batch 443/844
# Processed batch 444/844
# Processed batch 445/844
# Processed batch 446/844
# Processed batch 447/844
# Processed batch 448/844
# Processed batch 449/844
# Processed batch 450/844
# Processed batch 451/844
# Processed batch 452/844
# Processed batch 453/844
# Processed batch 454/844
# Processed batch 455/844
# Processed batch 456/844
# Processed batch 457/844
# Processed batch 458/844
# Processed batch 459/844
# Processed batch 460/844
# Processed batch 461/844
# Processed batch 462/844
# Processed batch 463/844
# Processed batch 464/844
# Processed batch 465/844
# Processed batch 466/844
# Processed batch 467/844
# Processed batch 468/844
# Processed batch 469/844
# Processed batch 470/844
# Processed batch 471/844
# Processed batch 472/844
# Processed batch 473/844
# Processed batch 474/844
# Processed batch 475/844
# Processed batch 476/844
# Processed batch 477/844
# Processed batch 478/844
# Processed batch 479/844
# Processed batch 480/844
# Processed batch 481/844
# Processed batch 482/844
# Processed batch 483/844
# Processed batch 484/844
# Processed batch 485/844
# Processed batch 486/844
# Processed batch 487/844
# Processed batch 488/844
# Processed batch 489/844
# Processed batch 490/844
# Processed batch 491/844
# Processed batch 492/844
# Processed batch 493/844
# Processed batch 494/844
# Processed batch 495/844
# Processed batch 496/844
# Processed batch 497/844
# Processed batch 498/844
# Processed batch 499/844
# Processed batch 500/844
# Processed batch 501/844
# Processed batch 502/844
# Processed batch 503/844
# Processed batch 504/844
# Processed batch 505/844
# Processed batch 506/844
# Processed batch 507/844
# Processed batch 508/844
# Processed batch 509/844
# Processed batch 510/844
# Processed batch 511/844
# Processed batch 512/844
# Processed batch 513/844
# Processed batch 514/844
# Processed batch 515/844
# Processed batch 516/844
# Processed batch 517/844
# Processed batch 518/844
# Processed batch 519/844
# Processed batch 520/844
# Processed batch 521/844
# Processed batch 522/844
# Processed batch 523/844
# Processed batch 524/844
# Processed batch 525/844
# Processed batch 526/844
# Processed batch 527/844
# Processed batch 528/844
# Processed batch 529/844
# Processed batch 530/844
# Processed batch 531/844
# Processed batch 532/844
# Processed batch 533/844
# Processed batch 534/844
# Processed batch 535/844
# Processed batch 536/844
# Processed batch 537/844
# Processed batch 538/844
# Processed batch 539/844
# Processed batch 540/844
# Processed batch 541/844
# Processed batch 542/844
# Processed batch 543/844
# Processed batch 544/844
# Processed batch 545/844
# Processed batch 546/844
# Processed batch 547/844
# Processed batch 548/844
# Processed batch 549/844
# Processed batch 550/844
# Processed batch 551/844
# Processed batch 552/844
# Processed batch 553/844
# Processed batch 554/844
# Processed batch 555/844
# Processed batch 556/844
# Processed batch 557/844
# Processed batch 558/844
# Processed batch 559/844
# Processed batch 560/844
# Processed batch 561/844
# Processed batch 562/844
# Processed batch 563/844
# Processed batch 564/844
# Processed batch 565/844
# Processed batch 566/844
# Processed batch 567/844
# Processed batch 568/844
# Processed batch 569/844
# Processed batch 570/844
# Processed batch 571/844
# Processed batch 572/844
# Processed batch 573/844
# Processed batch 574/844
# Processed batch 575/844
# Processed batch 576/844
# Processed batch 577/844
# Processed batch 578/844
# Processed batch 579/844
# Processed batch 580/844
# Processed batch 581/844
# Processed batch 582/844
# Processed batch 583/844
# Processed batch 584/844
# Processed batch 585/844
# Processed batch 586/844
# Processed batch 587/844
# Processed batch 588/844
# Processed batch 589/844
# Processed batch 590/844
# Processed batch 591/844
# Processed batch 592/844
# Processed batch 593/844
# Processed batch 594/844
# Processed batch 595/844
# Processed batch 596/844
# Processed batch 597/844
# Processed batch 598/844
# Processed batch 599/844
# Processed batch 600/844
# Processed batch 601/844
# Processed batch 602/844
# Processed batch 603/844
# Processed batch 604/844
# Processed batch 605/844
# Processed batch 606/844
# Processed batch 607/844
# Processed batch 608/844
# Processed batch 609/844
# Processed batch 610/844
# Processed batch 611/844
# Processed batch 612/844
# Processed batch 613/844
# Processed batch 614/844
# Processed batch 615/844
# Processed batch 616/844
# Processed batch 617/844
# Processed batch 618/844
# Processed batch 619/844
# Processed batch 620/844
# Processed batch 621/844
# Processed batch 622/844
# Processed batch 623/844
# Processed batch 624/844
# Processed batch 625/844
# Processed batch 626/844
# Processed batch 627/844
# Processed batch 628/844
# Processed batch 629/844
# Processed batch 630/844
# Processed batch 631/844
# Processed batch 632/844
# Processed batch 633/844
# Processed batch 634/844
# Processed batch 635/844
# Processed batch 636/844
# Processed batch 637/844
# Processed batch 638/844
# Processed batch 639/844
# Processed batch 640/844
# Processed batch 641/844
# Processed batch 642/844
# Processed batch 643/844
# Processed batch 644/844
# Processed batch 645/844
# Processed batch 646/844
# Processed batch 647/844
# Processed batch 648/844
# Processed batch 649/844
# Processed batch 650/844
# Processed batch 651/844
# Processed batch 652/844
# Processed batch 653/844
# Processed batch 654/844
# Processed batch 655/844
# Processed batch 656/844
# Processed batch 657/844
# Processed batch 658/844
# Processed batch 659/844
# Processed batch 660/844
# Processed batch 661/844
# Processed batch 662/844
# Processed batch 663/844
# Processed batch 664/844
# Processed batch 665/844
# Processed batch 666/844
# Processed batch 667/844
# Processed batch 668/844
# Processed batch 669/844
# Processed batch 670/844
# Processed batch 671/844
# Processed batch 672/844
# Processed batch 673/844
# Processed batch 674/844
# Processed batch 675/844
# Processed batch 676/844
# Processed batch 677/844
# Processed batch 678/844
# Processed batch 679/844
# Processed batch 680/844
# Processed batch 681/844
# Processed batch 682/844
# Processed batch 683/844
# Processed batch 684/844
# Processed batch 685/844
# Processed batch 686/844
# Processed batch 687/844
# Processed batch 688/844
# Processed batch 689/844
# Processed batch 690/844
# Processed batch 691/844
# Processed batch 692/844
# Processed batch 693/844
# Processed batch 694/844
# Processed batch 695/844
# Processed batch 696/844
# Processed batch 697/844
# Processed batch 698/844
# Processed batch 699/844
# Processed batch 700/844
# Processed batch 701/844
# Processed batch 702/844
# Processed batch 703/844
# Processed batch 704/844
# Processed batch 705/844
# Processed batch 706/844
# Processed batch 707/844
# Processed batch 708/844
# Processed batch 709/844
# Processed batch 710/844
# Processed batch 711/844
# Processed batch 712/844
# Processed batch 713/844
# Processed batch 714/844
# Processed batch 715/844
# Processed batch 716/844
# Processed batch 717/844
# Processed batch 718/844
# Processed batch 719/844
# Processed batch 720/844
# Processed batch 721/844
# Processed batch 722/844
# Processed batch 723/844
# Processed batch 724/844
# Processed batch 725/844
# Processed batch 726/844
# Processed batch 727/844
# Processed batch 728/844
# Processed batch 729/844
# Processed batch 730/844
# Processed batch 731/844
# Processed batch 732/844
# Processed batch 733/844
# Processed batch 734/844
# Processed batch 735/844
# Processed batch 736/844
# Processed batch 737/844
# Processed batch 738/844
# Processed batch 739/844
# Processed batch 740/844
# Processed batch 741/844
# Processed batch 742/844
# Processed batch 743/844
# Processed batch 744/844
# Processed batch 745/844
# Processed batch 746/844
# Processed batch 747/844
# Processed batch 748/844
# Processed batch 749/844
# Processed batch 750/844
# Processed batch 751/844
# Processed batch 752/844
# Processed batch 753/844
# Processed batch 754/844
# Processed batch 755/844
# Processed batch 756/844
# Processed batch 757/844
# Processed batch 758/844
# Processed batch 759/844
# Processed batch 760/844
# Processed batch 761/844
# Processed batch 762/844
# Processed batch 763/844
# Processed batch 764/844
# Processed batch 765/844
# Processed batch 766/844
# Processed batch 767/844
# Processed batch 768/844
# Processed batch 769/844
# Processed batch 770/844
# Processed batch 771/844
# Processed batch 772/844
# Processed batch 773/844
# Processed batch 774/844
# Processed batch 775/844
# Processed batch 776/844
# Processed batch 777/844
# Processed batch 778/844
# Processed batch 779/844
# Processed batch 780/844
# Processed batch 781/844
# Processed batch 782/844
# Processed batch 783/844
# Processed batch 784/844
# Processed batch 785/844
# Processed batch 786/844
# Processed batch 787/844
# Processed batch 788/844
# Processed batch 789/844
# Processed batch 790/844
# Processed batch 791/844
# Processed batch 792/844
# Processed batch 793/844
# Processed batch 794/844
# Processed batch 795/844
# Processed batch 796/844
# Processed batch 797/844
# Processed batch 798/844
# Processed batch 799/844
# Processed batch 800/844
# Processed batch 801/844
# Processed batch 802/844
# Processed batch 803/844
# Processed batch 804/844
# Processed batch 805/844
# Processed batch 806/844
# Processed batch 807/844
# Processed batch 808/844
# Processed batch 809/844
# Processed batch 810/844
# Processed batch 811/844
# Processed batch 812/844
# Processed batch 813/844
# Processed batch 814/844
# Processed batch 815/844
# Processed batch 816/844
# Processed batch 817/844
# Processed batch 818/844
# Processed batch 819/844
# Processed batch 820/844
# Processed batch 821/844
# Processed batch 822/844
# Processed batch 823/844
# Processed batch 824/844
# Processed batch 825/844
# Processed batch 826/844
# Processed batch 827/844
# Processed batch 828/844
# Processed batch 829/844
# Processed batch 830/844
# Processed batch 831/844
# Processed batch 832/844
# Processed batch 833/844
# Processed batch 834/844
# Processed batch 835/844
# Processed batch 836/844
# Processed batch 837/844
# Processed batch 838/844
# Processed batch 839/844
# Processed batch 840/844
# Processed batch 841/844
# Processed batch 842/844
# Processed batch 843/844
# Processed batch 844/844
# Modified MNIST dataset saved to /home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE7.pt

# %%
import pickle

# Load the sampled RGB values in one line
sampled_values = pickle.load(open("/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/Sampled_Values/Mni/t2e8_mni.pkl", "rb"))
print("Sampled RGB values loaded successfully!")

output_dir = "/home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE8.pt"
apply_samples_to_dataset(train_loader, sampled_values, top_22_coords, output_dir)
# Out:
# Sampled RGB values loaded successfully!
# Processed batch 1/844
# Processed batch 2/844
# Processed batch 3/844
# Processed batch 4/844
# Processed batch 5/844
# Processed batch 6/844
# Processed batch 7/844
# Processed batch 8/844
# Processed batch 9/844
# Processed batch 10/844
# Processed batch 11/844
# Processed batch 12/844
# Processed batch 13/844
# Processed batch 14/844
# Processed batch 15/844
# Processed batch 16/844
# Processed batch 17/844
# Processed batch 18/844
# Processed batch 19/844
# Processed batch 20/844
# Processed batch 21/844
# Processed batch 22/844
# Processed batch 23/844
# Processed batch 24/844
# Processed batch 25/844
# Processed batch 26/844
# Processed batch 27/844
# Processed batch 28/844
# Processed batch 29/844
# Processed batch 30/844
# Processed batch 31/844
# Processed batch 32/844
# Processed batch 33/844
# Processed batch 34/844
# Processed batch 35/844
# Processed batch 36/844
# Processed batch 37/844
# Processed batch 38/844
# Processed batch 39/844
# Processed batch 40/844
# Processed batch 41/844
# Processed batch 42/844
# Processed batch 43/844
# Processed batch 44/844
# Processed batch 45/844
# Processed batch 46/844
# Processed batch 47/844
# Processed batch 48/844
# Processed batch 49/844
# Processed batch 50/844
# Processed batch 51/844
# Processed batch 52/844
# Processed batch 53/844
# Processed batch 54/844
# Processed batch 55/844
# Processed batch 56/844
# Processed batch 57/844
# Processed batch 58/844
# Processed batch 59/844
# Processed batch 60/844
# Processed batch 61/844
# Processed batch 62/844
# Processed batch 63/844
# Processed batch 64/844
# Processed batch 65/844
# Processed batch 66/844
# Processed batch 67/844
# Processed batch 68/844
# Processed batch 69/844
# Processed batch 70/844
# Processed batch 71/844
# Processed batch 72/844
# Processed batch 73/844
# Processed batch 74/844
# Processed batch 75/844
# Processed batch 76/844
# Processed batch 77/844
# Processed batch 78/844
# Processed batch 79/844
# Processed batch 80/844
# Processed batch 81/844
# Processed batch 82/844
# Processed batch 83/844
# Processed batch 84/844
# Processed batch 85/844
# Processed batch 86/844
# Processed batch 87/844
# Processed batch 88/844
# Processed batch 89/844
# Processed batch 90/844
# Processed batch 91/844
# Processed batch 92/844
# Processed batch 93/844
# Processed batch 94/844
# Processed batch 95/844
# Processed batch 96/844
# Processed batch 97/844
# Processed batch 98/844
# Processed batch 99/844
# Processed batch 100/844
# Processed batch 101/844
# Processed batch 102/844
# Processed batch 103/844
# Processed batch 104/844
# Processed batch 105/844
# Processed batch 106/844
# Processed batch 107/844
# Processed batch 108/844
# Processed batch 109/844
# Processed batch 110/844
# Processed batch 111/844
# Processed batch 112/844
# Processed batch 113/844
# Processed batch 114/844
# Processed batch 115/844
# Processed batch 116/844
# Processed batch 117/844
# Processed batch 118/844
# Processed batch 119/844
# Processed batch 120/844
# Processed batch 121/844
# Processed batch 122/844
# Processed batch 123/844
# Processed batch 124/844
# Processed batch 125/844
# Processed batch 126/844
# Processed batch 127/844
# Processed batch 128/844
# Processed batch 129/844
# Processed batch 130/844
# Processed batch 131/844
# Processed batch 132/844
# Processed batch 133/844
# Processed batch 134/844
# Processed batch 135/844
# Processed batch 136/844
# Processed batch 137/844
# Processed batch 138/844
# Processed batch 139/844
# Processed batch 140/844
# Processed batch 141/844
# Processed batch 142/844
# Processed batch 143/844
# Processed batch 144/844
# Processed batch 145/844
# Processed batch 146/844
# Processed batch 147/844
# Processed batch 148/844
# Processed batch 149/844
# Processed batch 150/844
# Processed batch 151/844
# Processed batch 152/844
# Processed batch 153/844
# Processed batch 154/844
# Processed batch 155/844
# Processed batch 156/844
# Processed batch 157/844
# Processed batch 158/844
# Processed batch 159/844
# Processed batch 160/844
# Processed batch 161/844
# Processed batch 162/844
# Processed batch 163/844
# Processed batch 164/844
# Processed batch 165/844
# Processed batch 166/844
# Processed batch 167/844
# Processed batch 168/844
# Processed batch 169/844
# Processed batch 170/844
# Processed batch 171/844
# Processed batch 172/844
# Processed batch 173/844
# Processed batch 174/844
# Processed batch 175/844
# Processed batch 176/844
# Processed batch 177/844
# Processed batch 178/844
# Processed batch 179/844
# Processed batch 180/844
# Processed batch 181/844
# Processed batch 182/844
# Processed batch 183/844
# Processed batch 184/844
# Processed batch 185/844
# Processed batch 186/844
# Processed batch 187/844
# Processed batch 188/844
# Processed batch 189/844
# Processed batch 190/844
# Processed batch 191/844
# Processed batch 192/844
# Processed batch 193/844
# Processed batch 194/844
# Processed batch 195/844
# Processed batch 196/844
# Processed batch 197/844
# Processed batch 198/844
# Processed batch 199/844
# Processed batch 200/844
# Processed batch 201/844
# Processed batch 202/844
# Processed batch 203/844
# Processed batch 204/844
# Processed batch 205/844
# Processed batch 206/844
# Processed batch 207/844
# Processed batch 208/844
# Processed batch 209/844
# Processed batch 210/844
# Processed batch 211/844
# Processed batch 212/844
# Processed batch 213/844
# Processed batch 214/844
# Processed batch 215/844
# Processed batch 216/844
# Processed batch 217/844
# Processed batch 218/844
# Processed batch 219/844
# Processed batch 220/844
# Processed batch 221/844
# Processed batch 222/844
# Processed batch 223/844
# Processed batch 224/844
# Processed batch 225/844
# Processed batch 226/844
# Processed batch 227/844
# Processed batch 228/844
# Processed batch 229/844
# Processed batch 230/844
# Processed batch 231/844
# Processed batch 232/844
# Processed batch 233/844
# Processed batch 234/844
# Processed batch 235/844
# Processed batch 236/844
# Processed batch 237/844
# Processed batch 238/844
# Processed batch 239/844
# Processed batch 240/844
# Processed batch 241/844
# Processed batch 242/844
# Processed batch 243/844
# Processed batch 244/844
# Processed batch 245/844
# Processed batch 246/844
# Processed batch 247/844
# Processed batch 248/844
# Processed batch 249/844
# Processed batch 250/844
# Processed batch 251/844
# Processed batch 252/844
# Processed batch 253/844
# Processed batch 254/844
# Processed batch 255/844
# Processed batch 256/844
# Processed batch 257/844
# Processed batch 258/844
# Processed batch 259/844
# Processed batch 260/844
# Processed batch 261/844
# Processed batch 262/844
# Processed batch 263/844
# Processed batch 264/844
# Processed batch 265/844
# Processed batch 266/844
# Processed batch 267/844
# Processed batch 268/844
# Processed batch 269/844
# Processed batch 270/844
# Processed batch 271/844
# Processed batch 272/844
# Processed batch 273/844
# Processed batch 274/844
# Processed batch 275/844
# Processed batch 276/844
# Processed batch 277/844
# Processed batch 278/844
# Processed batch 279/844
# Processed batch 280/844
# Processed batch 281/844
# Processed batch 282/844
# Processed batch 283/844
# Processed batch 284/844
# Processed batch 285/844
# Processed batch 286/844
# Processed batch 287/844
# Processed batch 288/844
# Processed batch 289/844
# Processed batch 290/844
# Processed batch 291/844
# Processed batch 292/844
# Processed batch 293/844
# Processed batch 294/844
# Processed batch 295/844
# Processed batch 296/844
# Processed batch 297/844
# Processed batch 298/844
# Processed batch 299/844
# Processed batch 300/844
# Processed batch 301/844
# Processed batch 302/844
# Processed batch 303/844
# Processed batch 304/844
# Processed batch 305/844
# Processed batch 306/844
# Processed batch 307/844
# Processed batch 308/844
# Processed batch 309/844
# Processed batch 310/844
# Processed batch 311/844
# Processed batch 312/844
# Processed batch 313/844
# Processed batch 314/844
# Processed batch 315/844
# Processed batch 316/844
# Processed batch 317/844
# Processed batch 318/844
# Processed batch 319/844
# Processed batch 320/844
# Processed batch 321/844
# Processed batch 322/844
# Processed batch 323/844
# Processed batch 324/844
# Processed batch 325/844
# Processed batch 326/844
# Processed batch 327/844
# Processed batch 328/844
# Processed batch 329/844
# Processed batch 330/844
# Processed batch 331/844
# Processed batch 332/844
# Processed batch 333/844
# Processed batch 334/844
# Processed batch 335/844
# Processed batch 336/844
# Processed batch 337/844
# Processed batch 338/844
# Processed batch 339/844
# Processed batch 340/844
# Processed batch 341/844
# Processed batch 342/844
# Processed batch 343/844
# Processed batch 344/844
# Processed batch 345/844
# Processed batch 346/844
# Processed batch 347/844
# Processed batch 348/844
# Processed batch 349/844
# Processed batch 350/844
# Processed batch 351/844
# Processed batch 352/844
# Processed batch 353/844
# Processed batch 354/844
# Processed batch 355/844
# Processed batch 356/844
# Processed batch 357/844
# Processed batch 358/844
# Processed batch 359/844
# Processed batch 360/844
# Processed batch 361/844
# Processed batch 362/844
# Processed batch 363/844
# Processed batch 364/844
# Processed batch 365/844
# Processed batch 366/844
# Processed batch 367/844
# Processed batch 368/844
# Processed batch 369/844
# Processed batch 370/844
# Processed batch 371/844
# Processed batch 372/844
# Processed batch 373/844
# Processed batch 374/844
# Processed batch 375/844
# Processed batch 376/844
# Processed batch 377/844
# Processed batch 378/844
# Processed batch 379/844
# Processed batch 380/844
# Processed batch 381/844
# Processed batch 382/844
# Processed batch 383/844
# Processed batch 384/844
# Processed batch 385/844
# Processed batch 386/844
# Processed batch 387/844
# Processed batch 388/844
# Processed batch 389/844
# Processed batch 390/844
# Processed batch 391/844
# Processed batch 392/844
# Processed batch 393/844
# Processed batch 394/844
# Processed batch 395/844
# Processed batch 396/844
# Processed batch 397/844
# Processed batch 398/844
# Processed batch 399/844
# Processed batch 400/844
# Processed batch 401/844
# Processed batch 402/844
# Processed batch 403/844
# Processed batch 404/844
# Processed batch 405/844
# Processed batch 406/844
# Processed batch 407/844
# Processed batch 408/844
# Processed batch 409/844
# Processed batch 410/844
# Processed batch 411/844
# Processed batch 412/844
# Processed batch 413/844
# Processed batch 414/844
# Processed batch 415/844
# Processed batch 416/844
# Processed batch 417/844
# Processed batch 418/844
# Processed batch 419/844
# Processed batch 420/844
# Processed batch 421/844
# Processed batch 422/844
# Processed batch 423/844
# Processed batch 424/844
# Processed batch 425/844
# Processed batch 426/844
# Processed batch 427/844
# Processed batch 428/844
# Processed batch 429/844
# Processed batch 430/844
# Processed batch 431/844
# Processed batch 432/844
# Processed batch 433/844
# Processed batch 434/844
# Processed batch 435/844
# Processed batch 436/844
# Processed batch 437/844
# Processed batch 438/844
# Processed batch 439/844
# Processed batch 440/844
# Processed batch 441/844
# Processed batch 442/844
# Processed batch 443/844
# Processed batch 444/844
# Processed batch 445/844
# Processed batch 446/844
# Processed batch 447/844
# Processed batch 448/844
# Processed batch 449/844
# Processed batch 450/844
# Processed batch 451/844
# Processed batch 452/844
# Processed batch 453/844
# Processed batch 454/844
# Processed batch 455/844
# Processed batch 456/844
# Processed batch 457/844
# Processed batch 458/844
# Processed batch 459/844
# Processed batch 460/844
# Processed batch 461/844
# Processed batch 462/844
# Processed batch 463/844
# Processed batch 464/844
# Processed batch 465/844
# Processed batch 466/844
# Processed batch 467/844
# Processed batch 468/844
# Processed batch 469/844
# Processed batch 470/844
# Processed batch 471/844
# Processed batch 472/844
# Processed batch 473/844
# Processed batch 474/844
# Processed batch 475/844
# Processed batch 476/844
# Processed batch 477/844
# Processed batch 478/844
# Processed batch 479/844
# Processed batch 480/844
# Processed batch 481/844
# Processed batch 482/844
# Processed batch 483/844
# Processed batch 484/844
# Processed batch 485/844
# Processed batch 486/844
# Processed batch 487/844
# Processed batch 488/844
# Processed batch 489/844
# Processed batch 490/844
# Processed batch 491/844
# Processed batch 492/844
# Processed batch 493/844
# Processed batch 494/844
# Processed batch 495/844
# Processed batch 496/844
# Processed batch 497/844
# Processed batch 498/844
# Processed batch 499/844
# Processed batch 500/844
# Processed batch 501/844
# Processed batch 502/844
# Processed batch 503/844
# Processed batch 504/844
# Processed batch 505/844
# Processed batch 506/844
# Processed batch 507/844
# Processed batch 508/844
# Processed batch 509/844
# Processed batch 510/844
# Processed batch 511/844
# Processed batch 512/844
# Processed batch 513/844
# Processed batch 514/844
# Processed batch 515/844
# Processed batch 516/844
# Processed batch 517/844
# Processed batch 518/844
# Processed batch 519/844
# Processed batch 520/844
# Processed batch 521/844
# Processed batch 522/844
# Processed batch 523/844
# Processed batch 524/844
# Processed batch 525/844
# Processed batch 526/844
# Processed batch 527/844
# Processed batch 528/844
# Processed batch 529/844
# Processed batch 530/844
# Processed batch 531/844
# Processed batch 532/844
# Processed batch 533/844
# Processed batch 534/844
# Processed batch 535/844
# Processed batch 536/844
# Processed batch 537/844
# Processed batch 538/844
# Processed batch 539/844
# Processed batch 540/844
# Processed batch 541/844
# Processed batch 542/844
# Processed batch 543/844
# Processed batch 544/844
# Processed batch 545/844
# Processed batch 546/844
# Processed batch 547/844
# Processed batch 548/844
# Processed batch 549/844
# Processed batch 550/844
# Processed batch 551/844
# Processed batch 552/844
# Processed batch 553/844
# Processed batch 554/844
# Processed batch 555/844
# Processed batch 556/844
# Processed batch 557/844
# Processed batch 558/844
# Processed batch 559/844
# Processed batch 560/844
# Processed batch 561/844
# Processed batch 562/844
# Processed batch 563/844
# Processed batch 564/844
# Processed batch 565/844
# Processed batch 566/844
# Processed batch 567/844
# Processed batch 568/844
# Processed batch 569/844
# Processed batch 570/844
# Processed batch 571/844
# Processed batch 572/844
# Processed batch 573/844
# Processed batch 574/844
# Processed batch 575/844
# Processed batch 576/844
# Processed batch 577/844
# Processed batch 578/844
# Processed batch 579/844
# Processed batch 580/844
# Processed batch 581/844
# Processed batch 582/844
# Processed batch 583/844
# Processed batch 584/844
# Processed batch 585/844
# Processed batch 586/844
# Processed batch 587/844
# Processed batch 588/844
# Processed batch 589/844
# Processed batch 590/844
# Processed batch 591/844
# Processed batch 592/844
# Processed batch 593/844
# Processed batch 594/844
# Processed batch 595/844
# Processed batch 596/844
# Processed batch 597/844
# Processed batch 598/844
# Processed batch 599/844
# Processed batch 600/844
# Processed batch 601/844
# Processed batch 602/844
# Processed batch 603/844
# Processed batch 604/844
# Processed batch 605/844
# Processed batch 606/844
# Processed batch 607/844
# Processed batch 608/844
# Processed batch 609/844
# Processed batch 610/844
# Processed batch 611/844
# Processed batch 612/844
# Processed batch 613/844
# Processed batch 614/844
# Processed batch 615/844
# Processed batch 616/844
# Processed batch 617/844
# Processed batch 618/844
# Processed batch 619/844
# Processed batch 620/844
# Processed batch 621/844
# Processed batch 622/844
# Processed batch 623/844
# Processed batch 624/844
# Processed batch 625/844
# Processed batch 626/844
# Processed batch 627/844
# Processed batch 628/844
# Processed batch 629/844
# Processed batch 630/844
# Processed batch 631/844
# Processed batch 632/844
# Processed batch 633/844
# Processed batch 634/844
# Processed batch 635/844
# Processed batch 636/844
# Processed batch 637/844
# Processed batch 638/844
# Processed batch 639/844
# Processed batch 640/844
# Processed batch 641/844
# Processed batch 642/844
# Processed batch 643/844
# Processed batch 644/844
# Processed batch 645/844
# Processed batch 646/844
# Processed batch 647/844
# Processed batch 648/844
# Processed batch 649/844
# Processed batch 650/844
# Processed batch 651/844
# Processed batch 652/844
# Processed batch 653/844
# Processed batch 654/844
# Processed batch 655/844
# Processed batch 656/844
# Processed batch 657/844
# Processed batch 658/844
# Processed batch 659/844
# Processed batch 660/844
# Processed batch 661/844
# Processed batch 662/844
# Processed batch 663/844
# Processed batch 664/844
# Processed batch 665/844
# Processed batch 666/844
# Processed batch 667/844
# Processed batch 668/844
# Processed batch 669/844
# Processed batch 670/844
# Processed batch 671/844
# Processed batch 672/844
# Processed batch 673/844
# Processed batch 674/844
# Processed batch 675/844
# Processed batch 676/844
# Processed batch 677/844
# Processed batch 678/844
# Processed batch 679/844
# Processed batch 680/844
# Processed batch 681/844
# Processed batch 682/844
# Processed batch 683/844
# Processed batch 684/844
# Processed batch 685/844
# Processed batch 686/844
# Processed batch 687/844
# Processed batch 688/844
# Processed batch 689/844
# Processed batch 690/844
# Processed batch 691/844
# Processed batch 692/844
# Processed batch 693/844
# Processed batch 694/844
# Processed batch 695/844
# Processed batch 696/844
# Processed batch 697/844
# Processed batch 698/844
# Processed batch 699/844
# Processed batch 700/844
# Processed batch 701/844
# Processed batch 702/844
# Processed batch 703/844
# Processed batch 704/844
# Processed batch 705/844
# Processed batch 706/844
# Processed batch 707/844
# Processed batch 708/844
# Processed batch 709/844
# Processed batch 710/844
# Processed batch 711/844
# Processed batch 712/844
# Processed batch 713/844
# Processed batch 714/844
# Processed batch 715/844
# Processed batch 716/844
# Processed batch 717/844
# Processed batch 718/844
# Processed batch 719/844
# Processed batch 720/844
# Processed batch 721/844
# Processed batch 722/844
# Processed batch 723/844
# Processed batch 724/844
# Processed batch 725/844
# Processed batch 726/844
# Processed batch 727/844
# Processed batch 728/844
# Processed batch 729/844
# Processed batch 730/844
# Processed batch 731/844
# Processed batch 732/844
# Processed batch 733/844
# Processed batch 734/844
# Processed batch 735/844
# Processed batch 736/844
# Processed batch 737/844
# Processed batch 738/844
# Processed batch 739/844
# Processed batch 740/844
# Processed batch 741/844
# Processed batch 742/844
# Processed batch 743/844
# Processed batch 744/844
# Processed batch 745/844
# Processed batch 746/844
# Processed batch 747/844
# Processed batch 748/844
# Processed batch 749/844
# Processed batch 750/844
# Processed batch 751/844
# Processed batch 752/844
# Processed batch 753/844
# Processed batch 754/844
# Processed batch 755/844
# Processed batch 756/844
# Processed batch 757/844
# Processed batch 758/844
# Processed batch 759/844
# Processed batch 760/844
# Processed batch 761/844
# Processed batch 762/844
# Processed batch 763/844
# Processed batch 764/844
# Processed batch 765/844
# Processed batch 766/844
# Processed batch 767/844
# Processed batch 768/844
# Processed batch 769/844
# Processed batch 770/844
# Processed batch 771/844
# Processed batch 772/844
# Processed batch 773/844
# Processed batch 774/844
# Processed batch 775/844
# Processed batch 776/844
# Processed batch 777/844
# Processed batch 778/844
# Processed batch 779/844
# Processed batch 780/844
# Processed batch 781/844
# Processed batch 782/844
# Processed batch 783/844
# Processed batch 784/844
# Processed batch 785/844
# Processed batch 786/844
# Processed batch 787/844
# Processed batch 788/844
# Processed batch 789/844
# Processed batch 790/844
# Processed batch 791/844
# Processed batch 792/844
# Processed batch 793/844
# Processed batch 794/844
# Processed batch 795/844
# Processed batch 796/844
# Processed batch 797/844
# Processed batch 798/844
# Processed batch 799/844
# Processed batch 800/844
# Processed batch 801/844
# Processed batch 802/844
# Processed batch 803/844
# Processed batch 804/844
# Processed batch 805/844
# Processed batch 806/844
# Processed batch 807/844
# Processed batch 808/844
# Processed batch 809/844
# Processed batch 810/844
# Processed batch 811/844
# Processed batch 812/844
# Processed batch 813/844
# Processed batch 814/844
# Processed batch 815/844
# Processed batch 816/844
# Processed batch 817/844
# Processed batch 818/844
# Processed batch 819/844
# Processed batch 820/844
# Processed batch 821/844
# Processed batch 822/844
# Processed batch 823/844
# Processed batch 824/844
# Processed batch 825/844
# Processed batch 826/844
# Processed batch 827/844
# Processed batch 828/844
# Processed batch 829/844
# Processed batch 830/844
# Processed batch 831/844
# Processed batch 832/844
# Processed batch 833/844
# Processed batch 834/844
# Processed batch 835/844
# Processed batch 836/844
# Processed batch 837/844
# Processed batch 838/844
# Processed batch 839/844
# Processed batch 840/844
# Processed batch 841/844
# Processed batch 842/844
# Processed batch 843/844
# Processed batch 844/844
# Modified MNIST dataset saved to /home/j597s263/scratch/j597s263/Datasets/Defense/Conv/ConvMniE8.pt
