# %%
############CONV CIFAR############

import matplotlib.pyplot as plt

# Data for ConvCIF
epsilon = [2, 3, 4, 5, 6, 7, 8]
attack_accuracy = [9.01, 8.71, 8.21, 8.31, 8.01, 8.41, 8.71]
clean_accuracy = [88.53, 88.62, 88.61, 88.54, 88.60, 88.53, 88.95]
base_accuracy = 89.30
attack_before_defense = 99.60

# Plot
plt.figure(figsize=(10, 6))
plt.axhline(y=base_accuracy, color='blue', linestyle='--', label='Baseline Clean Accuracy (89.30%)')
plt.axhline(y=attack_before_defense, color='red', linestyle='--', label='Baseline Attack Success Rate (99.60%)')
plt.plot(epsilon, attack_accuracy, marker='o', color='orange', label='Attack Dataset Accuracy (Post-Defense)', linestyle='-')
plt.plot(epsilon, clean_accuracy, marker='o', color='green', label='Clean Dataset Accuracy (Post-Defense)', linestyle='-')
plt.scatter(epsilon, attack_accuracy, color='orange')
plt.scatter(epsilon, clean_accuracy, color='green')

# Labels and legend
plt.xlabel(r'$\bf{\epsilon}$', fontsize=16)
plt.ylabel(r'$\bf{Accuracy}$ (%)', fontsize=12)
plt.yticks(range(0, 101, 5))  # Set y-axis ticks from 0 to 100 with intervals of 5
plt.legend()

# Save and show plot
plt.savefig('ConvCifPlot.png', dpi=2000, bbox_inches='tight')
plt.show()

# %%
############CONV Image############

import matplotlib.pyplot as plt

# Data for ConvImg
epsilon = [2, 3, 4, 5, 6, 7, 8]
attack_accuracy = [15.34, 14.18, 13.97, 14.29, 14.71, 13.86, 14.71]
clean_accuracy = [85.64, 85.85, 86.37, 85.85, 86.06, 86.16, 85.32]
base_accuracy = 87.21
attack_before_defense = 97.35

# Plot
plt.figure(figsize=(10, 6))
plt.axhline(y=base_accuracy, color='blue', linestyle='--', label='Baseline Clean Accuracy (87.21%)')
plt.axhline(y=attack_before_defense, color='red', linestyle='--', label='Baseline Attack Success Rate (97.35%)')
plt.plot(epsilon, attack_accuracy, marker='o', color='orange', label='Attack Dataset Accuracy (Post-Defense)', linestyle='-')
plt.plot(epsilon, clean_accuracy, marker='o', color='green', label='Clean Dataset Accuracy (Post-Defense)', linestyle='-')
plt.scatter(epsilon, attack_accuracy, color='orange')
plt.scatter(epsilon, clean_accuracy, color='green')

# Labels and legend
plt.xlabel(r'$\bf{\epsilon}$', fontsize=16)
plt.ylabel(r'$\bf{Accuracy}$ (%)', fontsize=12)
plt.yticks(range(0, 101, 5))  # Set y-axis ticks from 0 to 100 with intervals of 5
plt.legend()

# Save and show plot
plt.savefig('ConvImgPlot.png', dpi=2000, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResImg
epsilon = [2, 3, 4, 5, 6, 7, 8]
attack_accuracy = [18.34, 16.08, 16.61, 17.14, 16.40, 18.20, 16.08]
clean_accuracy = [80.43, 78.93, 78.51, 78.93, 78.83, 78.72, 78.51]
base_accuracy = 81.87
attack_before_defense = 88.89

# Plot
plt.figure(figsize=(10, 6))
plt.axhline(y=base_accuracy, color='blue', linestyle='--', label='Baseline Clean Accuracy (81.87%)')
plt.axhline(y=attack_before_defense, color='red', linestyle='--', label='Baseline Attack Success Rate (88.89%)')
plt.plot(epsilon, attack_accuracy, marker='o', color='orange', label='Attack Dataset Accuracy (Post-Defense)', linestyle='-')
plt.plot(epsilon, clean_accuracy, marker='o', color='green', label='Clean Dataset Accuracy (Post-Defense)', linestyle='-')
plt.scatter(epsilon, attack_accuracy, color='orange')
plt.scatter(epsilon, clean_accuracy, color='green')

# Labels and legend
plt.xlabel(r'$\bf{\epsilon}$', fontsize=16)
plt.ylabel(r'$\bf{Accuracy}$ (%)', fontsize=12)
plt.yticks(range(0, 101, 5))  # Set y-axis ticks from 0 to 100 with intervals of 5
plt.legend()

# Save and show plot
plt.savefig('ResImgPlot.png', dpi=2000, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for ResCif
epsilon = [2, 3, 4, 5, 6, 7, 8]
attack_accuracy = [11.54, 9.91, 10.31, 8.51, 9.91, 9.71, 10.31]
clean_accuracy = [88.13, 88.33, 88.33, 88.16, 88.45, 88.32, 88.47]
base_accuracy = 88.34
attack_before_defense = 99.10

# Plot
plt.figure(figsize=(10, 6))
plt.axhline(y=base_accuracy, color='blue', linestyle='--', label='Baseline Clean Accuracy (88.34%)')
plt.axhline(y=attack_before_defense, color='red', linestyle='--', label='Baseline Attack Success Rate (99.10%)')
plt.plot(epsilon, attack_accuracy, marker='o', color='orange', label='Attack Dataset Accuracy (Post-Defense)', linestyle='-')
plt.plot(epsilon, clean_accuracy, marker='o', color='green', label='Clean Dataset Accuracy (Post-Defense)', linestyle='-')
plt.scatter(epsilon, attack_accuracy, color='orange')
plt.scatter(epsilon, clean_accuracy, color='green')

# Labels and legend
plt.xlabel(r'$\bf{\epsilon}$', fontsize=16)
plt.ylabel(r'$\bf{Accuracy}$ (%)', fontsize=12)
plt.yticks(range(0, 101, 5))  # Set y-axis ticks from 0 to 100 with intervals of 5
plt.legend()

# Save and show plot
plt.savefig('ResCifPlot.png', dpi=2000, bbox_inches='tight')
plt.show()

# %%
epsilon = [2, 3, 4, 5, 6, 7, 8]
attack_accuracy = [9.01, 8.71, 8.21, 8.31, 8.01, 8.41, 8.71]
base_accuracy = 89.30

attack_before_defense = [87.76, 87.64, 88.08]  # SHAP, LIME, IG

plt.figure(figsize=(10, 6))

plt.axhline(y=base_accuracy, color='blue', linestyle='--', label='Baseline Accuracy (89.30%)')

# Attack Success Rate before DP (SHAP, LIME, IG)
plt.axhline(y=87.76, color='darkred', linestyle='--', label='Attack Success Rate - SHAP (87.76%)')
plt.axhline(y=87.64, color='red', linestyle='--', label='Attack Success Rate - LIME (87.64%)')
plt.axhline(y=88.08, color='lightcoral', linestyle='--', label='Attack Success Rate - IG (88.08%)')

# Attack Success Rate after DP
plt.plot(epsilon, attack_accuracy, marker='o', color='green', linestyle='-', label=r'Attack Success Rate after DP vs $\epsilon$')
plt.scatter(epsilon, attack_accuracy, color='green')

# Labels and legend
plt.xlabel(r'$\epsilon$', fontsize=14)  # Using LaTeX for epsilon symbol
plt.ylabel('Accuracy (%)', fontsize=12)
plt.yticks(range(0, 101, 5))  # Set y-axis ticks from 0 to 100 with intervals of 5
plt.legend()

plt.savefig('ConvCifPlot.png', dpi=2000, bbox_inches='tight')
plt.show()

# %%
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader, Subset
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.amp import GradScaler, autocast
import os
import random
from torch.utils.data import DataLoader, SubsetRandomSampler

# %%
import torch
import numpy as np
import random
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset

# Set random seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Define dataset root directory
data_dir = '/home/j597s263/scratch/j597s263/Datasets/TinyImage/tiny-imagenet-200/'

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor()
])

# Load Tiny ImageNet dataset
train_dataset = datasets.ImageFolder(root=f'{data_dir}/train', transform=transform)
test_dataset = datasets.ImageFolder(root=f'{data_dir}/val', transform=transform)

# Get dataset size and number of classes
num_train = len(train_dataset)
num_classes = len(train_dataset.classes)

# Create a dictionary mapping class indices to sample indices
class_to_indices = {i: [] for i in range(num_classes)}
for idx, (_, label) in enumerate(train_dataset.samples):
    class_to_indices[label].append(idx)

# Select a fixed number of attack samples per class
attack_indices = []
num_per_class = (num_train // 10) // num_classes  # 10% of dataset, evenly across classes
for class_idx, indices in class_to_indices.items():
    indices = np.array(indices)  # Convert to NumPy array before shuffling
    np.random.shuffle(indices)   # Shuffle indices with fixed seed
    attack_indices.extend(indices[:num_per_class])

# Remaining samples for training
remaining_indices = list(set(range(num_train)) - set(attack_indices))

# Create subsets instead of samplers
train_subset = Subset(train_dataset, remaining_indices)
attack_subset = Subset(train_dataset, attack_indices)

# Create a generator for shuffling with fixed seed
g = torch.Generator()
g.manual_seed(SEED)

# Create DataLoaders with shuffle enabled and fixed random seed
train_loader = DataLoader(train_subset, batch_size=256, shuffle=True, generator=g)  
attack_loader = DataLoader(attack_subset, batch_size=256, shuffle=True, generator=g)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=True, generator=g)  # Shuffle test data

# Print dataset sizes
print(f"Number of training samples: {len(remaining_indices)}")
print(f"Number of attack samples: {len(attack_indices)}")
print(f"Number of test samples: {len(test_dataset)}")
# Out:
# Number of training samples: 90000
# Number of attack samples: 10000
# Number of test samples: 10000

# %%
from collections import Counter

# Function to count label occurrences in a DataLoader
def get_label_distribution(loader):
    label_counts = Counter()
    for _, labels in loader:
        label_counts.update(labels.tolist())  # Convert tensor labels to list
    return label_counts

# Get label distributions for each DataLoader
train_distribution = get_label_distribution(train_loader)
attack_distribution = get_label_distribution(attack_loader)
test_distribution = get_label_distribution(test_loader)

# Print label distributions
print("Train Dataset Label Distribution:")
print(dict(train_distribution))

print("\nAttack Dataset Label Distribution:")
print(dict(attack_distribution))

print("\nTest Dataset Label Distribution:")
print(dict(test_distribution))
# Out:
# Train Dataset Label Distribution:
# ...
