# %%
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader, Subset
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.amp import GradScaler, autocast
import os
import random
from torch.utils.data import DataLoader, SubsetRandomSampler
from collections import Counter

# %%
import torch
import numpy as np
from torch.utils.data import DataLoader, Subset
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import random

# Define dataset root directory
mnist_root = '/home/j597s263/scratch/j597s263/Datasets/MNIST'

random.seed(42)
torch.manual_seed(42)
np.random.seed(42)

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor()
])

train_dataset = datasets.MNIST(root=mnist_root, transform=transform, train=True, download=False)
test_dataset = datasets.MNIST(root=mnist_root, transform=transform, train=False, download=False)

train_indices = list(range(len(train_dataset)))
random.shuffle(train_indices)  

split_idx = int(0.9 * len(train_indices))  
train_indices, attack_indices = train_indices[:split_idx], train_indices[split_idx:]

train_data = Subset(train_dataset, train_indices)
attack_data = Subset(train_dataset, attack_indices)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True)  # Shuffle within batches
attack_loader = DataLoader(attack_data, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

print(f"Total training samples: {len(train_dataset)}")
print(f"Training samples after split: {len(train_data)}")
print(f"Attack samples: {len(attack_data)}")
print(f"Testing samples: {len(test_dataset)}")
# Out:
# Total training samples: 60000
# Training samples after split: 54000
# Attack samples: 6000
# Testing samples: 10000

# %%
import torch.nn as nn

# Residual block
class Residual(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x):
        return self.fn(x) + x

# ConvMixer model with hard-coded parameters
def ConvMixer():
    dim = 256          # Embedding dimension
    depth = 8          # Number of ConvMixer blocks
    kernel_size = 5    # Kernel size for depthwise convolution
    patch_size = 4     # Patch size for initial convolution
    n_classes = 200    # CIFAR-10 has 10 classes

    return nn.Sequential(
        nn.Conv2d(1, dim, kernel_size=patch_size, stride=patch_size),
        nn.GELU(),
        nn.BatchNorm2d(dim),
        *[nn.Sequential(
                Residual(nn.Sequential(
                    nn.Conv2d(dim, dim, kernel_size, groups=dim, padding="same"),
                    nn.GELU(),
                    nn.BatchNorm2d(dim)
                )),
                nn.Conv2d(dim, dim, kernel_size=1),
                nn.GELU(),
                nn.BatchNorm2d(dim)
        ) for _ in range(depth)],
        nn.AdaptiveAvgPool2d((1, 1)),
        nn.Flatten(),
        nn.Linear(dim, n_classes)
    )

# %%
# Load the model
import torch

# Define the path to the model
device = "cuda" 

# Load the model
model = torch.load('/home/j597s263/scratch/j597s263/Models/ConvModels/Base/ConvMNIBase.mod', weights_only=False, map_location="cuda")
model = model.to(device)
model.eval()  

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
import torch
import numpy as np
from captum.attr import IntegratedGradients
import os

# Ensure the model is in evaluation mode and on the correct device
device = 'cuda'
model.to(device)
model.eval()

# Define the Integrated Gradients method
ig = IntegratedGradients(model)

# Function to compute and save explanations as .npy
def compute_and_save_explanations_with_labels(data_loader, save_dir):
    """
    Compute Integrated Gradient explanations for all images in the dataset and save as .npy files.

    Args:
        data_loader (DataLoader): DataLoader for the dataset to explain.
        save_dir (str): Directory to save the explanations as .npy files.
    """
    os.makedirs(save_dir, exist_ok=True)  # Ensure the directory exists

    for batch_idx, (images, labels) in enumerate(data_loader):
        images, labels = images.to(device), labels.to(device)

        # Compute attributions using IG
        attributions, delta = ig.attribute(
            inputs=images,
            target=labels,  # Use ground-truth labels for explanations
            baselines=torch.zeros_like(images).to(device),  # Baseline: black image
            return_convergence_delta=True,
            n_steps = 10
        )

        # Save explanations for each image in the batch
        for i in range(images.size(0)):
            label = labels[i].item()  # Get the label as an integer
            explanation = attributions[i].cpu().numpy()  # Shape: (1, 224, 224)

            # Create a label array of shape (1, 224, 224)
            label_array = np.full((1, explanation.shape[1], explanation.shape[2]), label, dtype=np.float32)

            # Concatenate label and explanation to shape (2, 224, 224) (for grayscale images)
            explanation_with_label = np.concatenate([label_array, explanation], axis=0)

            # Save as .npy
            save_path = os.path.join(save_dir, f"explanation_{batch_idx * images.size(0) + i}.npy")
            np.save(save_path, explanation_with_label)

        print(f"Processed batch {batch_idx + 1}/{len(data_loader)}")

    print(f"Explanations saved to {save_dir}")
    
# Define the directory to save explanations
save_dir = "/home/j597s263/scratch/j597s263/Datasets/Explanation_values/Conv/IG_ConvMNI"

# Compute and save explanations
compute_and_save_explanations_with_labels(attack_loader, save_dir)
# Out:
# Processed batch 1/375
# Processed batch 2/375
# Processed batch 3/375
# Processed batch 4/375
# Processed batch 5/375
# Processed batch 6/375
# Processed batch 7/375
# Processed batch 8/375
# Processed batch 9/375
# Processed batch 10/375
# Processed batch 11/375
# Processed batch 12/375
# Processed batch 13/375
# Processed batch 14/375
# Processed batch 15/375
# Processed batch 16/375
# Processed batch 17/375
# Processed batch 18/375
# Processed batch 19/375
# Processed batch 20/375
# Processed batch 21/375
# Processed batch 22/375
# Processed batch 23/375
# Processed batch 24/375
# Processed batch 25/375
# Processed batch 26/375
# Processed batch 27/375
# Processed batch 28/375
# Processed batch 29/375
# Processed batch 30/375
# Processed batch 31/375
# Processed batch 32/375
# Processed batch 33/375
# Processed batch 34/375
# Processed batch 35/375
# Processed batch 36/375
# Processed batch 37/375
# Processed batch 38/375
# Processed batch 39/375
# Processed batch 40/375
# Processed batch 41/375
# Processed batch 42/375
# Processed batch 43/375
# Processed batch 44/375
# Processed batch 45/375
# Processed batch 46/375
# Processed batch 47/375
# Processed batch 48/375
# Processed batch 49/375
# Processed batch 50/375
# Processed batch 51/375
# Processed batch 52/375
# Processed batch 53/375
# Processed batch 54/375
# Processed batch 55/375
# Processed batch 56/375
# Processed batch 57/375
# Processed batch 58/375
# Processed batch 59/375
# Processed batch 60/375
# Processed batch 61/375
# Processed batch 62/375
# Processed batch 63/375
# Processed batch 64/375
# Processed batch 65/375
# Processed batch 66/375
# Processed batch 67/375
# Processed batch 68/375
# Processed batch 69/375
# Processed batch 70/375
# Processed batch 71/375
# Processed batch 72/375
# Processed batch 73/375
# Processed batch 74/375
# Processed batch 75/375
# Processed batch 76/375
# Processed batch 77/375
# Processed batch 78/375
# Processed batch 79/375
# Processed batch 80/375
# Processed batch 81/375
# Processed batch 82/375
# Processed batch 83/375
# Processed batch 84/375
# Processed batch 85/375
# Processed batch 86/375
# Processed batch 87/375
# Processed batch 88/375
# Processed batch 89/375
# Processed batch 90/375
# Processed batch 91/375
# Processed batch 92/375
# Processed batch 93/375
# Processed batch 94/375
# Processed batch 95/375
# Processed batch 96/375
# Processed batch 97/375
# Processed batch 98/375
# Processed batch 99/375
# Processed batch 100/375
# Processed batch 101/375
# Processed batch 102/375
# Processed batch 103/375
# Processed batch 104/375
# Processed batch 105/375
# Processed batch 106/375
# Processed batch 107/375
# Processed batch 108/375
# Processed batch 109/375
# Processed batch 110/375
# Processed batch 111/375
# Processed batch 112/375
# Processed batch 113/375
# Processed batch 114/375
# Processed batch 115/375
# Processed batch 116/375
# Processed batch 117/375
# Processed batch 118/375
# Processed batch 119/375
# Processed batch 120/375
# Processed batch 121/375
# Processed batch 122/375
# Processed batch 123/375
# Processed batch 124/375
# Processed batch 125/375
# Processed batch 126/375
# Processed batch 127/375
# Processed batch 128/375
# Processed batch 129/375
# Processed batch 130/375
# Processed batch 131/375
# Processed batch 132/375
# Processed batch 133/375
# Processed batch 134/375
# Processed batch 135/375
# Processed batch 136/375
# Processed batch 137/375
# Processed batch 138/375
# Processed batch 139/375
# Processed batch 140/375
# Processed batch 141/375
# Processed batch 142/375
# Processed batch 143/375
# Processed batch 144/375
# Processed batch 145/375
# Processed batch 146/375
# Processed batch 147/375
# Processed batch 148/375
# Processed batch 149/375
# Processed batch 150/375
# Processed batch 151/375
# Processed batch 152/375
# Processed batch 153/375
# Processed batch 154/375
# Processed batch 155/375
# Processed batch 156/375
# Processed batch 157/375
# Processed batch 158/375
# Processed batch 159/375
# Processed batch 160/375
# Processed batch 161/375
# Processed batch 162/375
# Processed batch 163/375
# Processed batch 164/375
# Processed batch 165/375
# Processed batch 166/375
# Processed batch 167/375
# Processed batch 168/375
# Processed batch 169/375
# Processed batch 170/375
# Processed batch 171/375
# Processed batch 172/375
# Processed batch 173/375
# Processed batch 174/375
# Processed batch 175/375
# Processed batch 176/375
# Processed batch 177/375
# Processed batch 178/375
# Processed batch 179/375
# Processed batch 180/375
# Processed batch 181/375
# Processed batch 182/375
# Processed batch 183/375
# Processed batch 184/375
# Processed batch 185/375
# Processed batch 186/375
# Processed batch 187/375
# Processed batch 188/375
# Processed batch 189/375
# Processed batch 190/375
# Processed batch 191/375
# Processed batch 192/375
# Processed batch 193/375
# Processed batch 194/375
# Processed batch 195/375
# Processed batch 196/375
# Processed batch 197/375
# Processed batch 198/375
# Processed batch 199/375
# Processed batch 200/375
# Processed batch 201/375
# Processed batch 202/375
# Processed batch 203/375
# Processed batch 204/375
# Processed batch 205/375
# Processed batch 206/375
# Processed batch 207/375
# Processed batch 208/375
# Processed batch 209/375
# Processed batch 210/375
# Processed batch 211/375
# Processed batch 212/375
# Processed batch 213/375
# Processed batch 214/375
# Processed batch 215/375
# Processed batch 216/375
# Processed batch 217/375
# Processed batch 218/375
# Processed batch 219/375
# Processed batch 220/375
# Processed batch 221/375
# Processed batch 222/375
# Processed batch 223/375
# Processed batch 224/375
# Processed batch 225/375
# Processed batch 226/375
# Processed batch 227/375
# Processed batch 228/375
# Processed batch 229/375
# Processed batch 230/375
# Processed batch 231/375
# Processed batch 232/375
# Processed batch 233/375
# Processed batch 234/375
# Processed batch 235/375
# Processed batch 236/375
# Processed batch 237/375
# Processed batch 238/375
# Processed batch 239/375
# Processed batch 240/375
# Processed batch 241/375
# Processed batch 242/375
# Processed batch 243/375
# Processed batch 244/375
# Processed batch 245/375
# Processed batch 246/375
# Processed batch 247/375
# Processed batch 248/375
# Processed batch 249/375
# Processed batch 250/375
# Processed batch 251/375
# Processed batch 252/375
# Processed batch 253/375
# Processed batch 254/375
# Processed batch 255/375
# Processed batch 256/375
# Processed batch 257/375
# Processed batch 258/375
# Processed batch 259/375
# Processed batch 260/375
# Processed batch 261/375
# Processed batch 262/375
# Processed batch 263/375
# Processed batch 264/375
# Processed batch 265/375
# Processed batch 266/375
# Processed batch 267/375
# Processed batch 268/375
# Processed batch 269/375
# Processed batch 270/375
# Processed batch 271/375
# Processed batch 272/375
# Processed batch 273/375
# Processed batch 274/375
# Processed batch 275/375
# Processed batch 276/375
# Processed batch 277/375
# Processed batch 278/375
# Processed batch 279/375
# Processed batch 280/375
# Processed batch 281/375
# Processed batch 282/375
# Processed batch 283/375
# Processed batch 284/375
# Processed batch 285/375
# Processed batch 286/375
# Processed batch 287/375
# Processed batch 288/375
# Processed batch 289/375
# Processed batch 290/375
# Processed batch 291/375
# Processed batch 292/375
# Processed batch 293/375
# Processed batch 294/375
# Processed batch 295/375
# Processed batch 296/375
# Processed batch 297/375
# Processed batch 298/375
# Processed batch 299/375
# Processed batch 300/375
# Processed batch 301/375
# Processed batch 302/375
# Processed batch 303/375
# Processed batch 304/375
# Processed batch 305/375
# Processed batch 306/375
# Processed batch 307/375
# Processed batch 308/375
# Processed batch 309/375
# Processed batch 310/375
# Processed batch 311/375
# Processed batch 312/375
# Processed batch 313/375
# Processed batch 314/375
# Processed batch 315/375
# Processed batch 316/375
# Processed batch 317/375
# Processed batch 318/375
# Processed batch 319/375
# Processed batch 320/375
# Processed batch 321/375
# Processed batch 322/375
# Processed batch 323/375
# Processed batch 324/375
# Processed batch 325/375
# Processed batch 326/375
# Processed batch 327/375
# Processed batch 328/375
# Processed batch 329/375
# Processed batch 330/375
# Processed batch 331/375
# Processed batch 332/375
# Processed batch 333/375
# Processed batch 334/375
# Processed batch 335/375
# Processed batch 336/375
# Processed batch 337/375
# Processed batch 338/375
# Processed batch 339/375
# Processed batch 340/375
# Processed batch 341/375
# Processed batch 342/375
# Processed batch 343/375
# Processed batch 344/375
# Processed batch 345/375
# Processed batch 346/375
# Processed batch 347/375
# Processed batch 348/375
# Processed batch 349/375
# Processed batch 350/375
# Processed batch 351/375
# Processed batch 352/375
# Processed batch 353/375
# Processed batch 354/375
# Processed batch 355/375
# Processed batch 356/375
# Processed batch 357/375
# Processed batch 358/375
# Processed batch 359/375
# Processed batch 360/375
# Processed batch 361/375
# Processed batch 362/375
# Processed batch 363/375
# Processed batch 364/375
# Processed batch 365/375
# Processed batch 366/375
# Processed batch 367/375
# Processed batch 368/375
# Processed batch 369/375
# Processed batch 370/375
# Processed batch 371/375
# Processed batch 372/375
# Processed batch 373/375
# Processed batch 374/375
# Processed batch 375/375
# Explanations saved to /home/j597s263/scratch/j597s263/Datasets/Explanation_values/Conv/IG_ConvMNI
